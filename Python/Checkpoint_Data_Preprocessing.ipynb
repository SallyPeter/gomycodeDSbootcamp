# %% [markdown]
# <a href="https://colab.research.google.com/github/SallyPeter/gomycodeDSbootcamp/blob/main/Python/Checkpoint_Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Instructions**
#
# 1. Load the dataset, display the ten first lines, store the results in a variable called 'client_0_bills'.
# 2. What is the data type of the 'client_0_bills' variable ?
# 3. Display the general information of the dataset and try to answer the following questions :
# 4. How many rows and columns do we have in this dataset ?
# 5. How many categorical features are present in the dataset ?
# 6. How much memory space does the dataset consume ?
# 7. Inspect the dataset for potential missing values.
# 8. Select your strategy to handle missing values, and tell us why you had made that choice.
# 9. Run a descriptive analysis on numeric features (columns).
# Select the bills records for the client with an id ='train_Client_0', using 2 methods.
# 10. Transform the 'counter_type' feature to a numeric variable using the encoder of your choice.
# 11. Delete the 'counter_statue' feature from the Dataframe

# %% [markdown]
# *This code uses the data STEG_BILLING_HISTORY.csv*

# %%
import pandas as pd

# %%
# Load the dataset, display the ten first lines, store the results in a variable called 'client_0_bills'.
data = pd.read_csv('STEG_BILLING_HISTORY.csv')

client_0_bills = data.head(10)
# Out:
# <ipython-input-2-cc4ed85e76b2>:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('STEG_BILLING_HISTORY.csv')

# %%
# What is the data type of the 'client_0_bills' variable ?
type(client_0_bills)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# It is a pandas DataFrame

# %%
# Display the general information of the dataset and try to answer the following questions :
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2615629 entries, 0 to 2615628
# Data columns (total 16 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   client_id             object
#  1   invoice_date          object
#  2   tarif_type            int64
#  3   counter_number        float64
#  4   counter_statue        object
#  5   counter_code          int64
#  6   reading_remarque      float64
#  7   counter_coefficient   float64
#  8   consommation_level_1  float64
#  9   consommation_level_2  float64
#  10  consommation_level_3  float64
#  11  consommation_level_4  float64
#  12  old_index             float64
#  13  new_index             float64
#  14  months_number         float64
#  15  counter_type          object
# dtypes: float64(10), int64(2), object(4)
# memory usage: 319.3+ MB

# %%
# How many rows and columns do we have in this dataset ?
data.shape
# Out:
# (2615629, 16)

# %% [markdown]
# Data has over 2.6 million rows of data and 16 columns

# %%
# How many categorical features are present in the dataset ?
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2615629 entries, 0 to 2615628
# Data columns (total 16 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   client_id             object
#  1   invoice_date          object
#  2   tarif_type            int64
#  3   counter_number        float64
#  4   counter_statue        object
#  5   counter_code          int64
#  6   reading_remarque      float64
#  7   counter_coefficient   float64
#  8   consommation_level_1  float64
#  9   consommation_level_2  float64
#  10  consommation_level_3  float64
#  11  consommation_level_4  float64
#  12  old_index             float64
#  13  new_index             float64
#  14  months_number         float64
#  15  counter_type          object
# dtypes: float64(10), int64(2), object(4)
# memory usage: 319.3+ MB

# %% [markdown]
# From the .info() method, data has 4 categorical features
#
#
# ### How much memory space does the dataset consume?
#
# 319.3MB

# %%
# Inspect the dataset for potential missing values.
data.isnull().sum()
# Out:
# client_id                  0
# invoice_date               0
# tarif_type                 0
# counter_number            23
# counter_statue             0
# counter_code               0
# reading_remarque        2611
# counter_coefficient        1
# consommation_level_1       1
# consommation_level_2       1
# consommation_level_3       1
# consommation_level_4       1
# old_index                  1
# new_index                  1
# months_number              1
# counter_type               1
# dtype: int64

# %% [markdown]
# The features with missing values are 'counter_number', 'reading_remarque', 'counter_coefficient', the consommation features, old and new index, 'months_number' and 'counter_type' with 'reading_remarque having the most missing values.

# %%
# Select your strategy to handle missing values, and tell us why you had made that choice.

# %% [markdown]
# I choose to drop the missing values as 2611 is less than 1% of the records in the data. Droping it has liitle to no effect to the dataset

# %%
data = data.dropna(subset=['reading_remarque', 'counter_number', 'counter_coefficient', 'consommation_level_1', 'consommation_level_2', 'consommation_level_3', 'consommation_level_4',
                                                        'old_index', 'new_index', 'months_number', 'counter_type'])

data.isnull().sum()
# Out:
# client_id               0
# invoice_date            0
# tarif_type              0
# counter_number          0
# counter_statue          0
# counter_code            0
# reading_remarque        0
# counter_coefficient     0
# consommation_level_1    0
# consommation_level_2    0
# consommation_level_3    0
# consommation_level_4    0
# old_index               0
# new_index               0
# months_number           0
# counter_type            0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2612994 entries, 0 to 2615627
# Data columns (total 16 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   client_id             object
#  1   invoice_date          object
#  2   tarif_type            int64
#  3   counter_number        float64
#  4   counter_statue        object
#  5   counter_code          int64
#  6   reading_remarque      float64
#  7   counter_coefficient   float64
#  8   consommation_level_1  float64
#  9   consommation_level_2  float64
#  10  consommation_level_3  float64
#  11  consommation_level_4  float64
#  12  old_index             float64
#  13  new_index             float64
#  14  months_number         float64
#  15  counter_type          object
# dtypes: float64(10), int64(2), object(4)
# memory usage: 338.9+ MB

# %%
# Run a descriptive analysis on numeric features (columns).
num_col = data.select_dtypes(include='number')

num_col.describe()
# Out:
#          tarif_type  counter_number  counter_code  reading_remarque  \
# count  2.612994e+06    2.612994e+06  2.612994e+06      2.612994e+06
# mean   2.009691e+01    1.220926e+11  1.729026e+02      7.320786e+00
# std    1.346245e+01    1.651865e+12  1.339192e+02      1.641789e+00
# min    8.000000e+00    0.000000e+00  0.000000e+00      6.000000e+00
# 25%    1.100000e+01    1.211750e+05  5.000000e+00      6.000000e+00
# 50%    1.100000e+01    4.949180e+05  2.030000e+02      8.000000e+00
# 75%    4.000000e+01    1.115336e+06  2.070000e+02      9.000000e+00
# max    4.500000e+01    2.798115e+13  6.000000e+02      4.130000e+02
#
#        counter_coefficient  consommation_level_1  consommation_level_2  \
# count         2.612994e+06          2.612994e+06          2.612994e+06
# mean          1.003320e+00          4.114430e+02          1.089441e+02
# std           3.434935e-01          8.523503e+02          1.043448e+03
# ...

# %%
data.columns
# Out:
# Index(['client_id', 'invoice_date', 'tarif_type', 'counter_number',
#        'counter_statue', 'counter_code', 'reading_remarque',
#        'counter_coefficient', 'consommation_level_1', 'consommation_level_2',
#        'consommation_level_3', 'consommation_level_4', 'old_index',
#        'new_index', 'months_number', 'counter_type'],
#       dtype='object')

# %%
# Select the bills records for the client with an id ='train_Client_0', using 2 methods.

# Method 1

data[data.client_id == 'train_Client_0']
# Out:
#          client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0   train_Client_0   2014-03-24          11       1335667.0              0
# 1   train_Client_0   2013-03-29          11       1335667.0              0
# 2   train_Client_0   2015-03-23          11       1335667.0              0
# 3   train_Client_0   2015-07-13          11       1335667.0              0
# 4   train_Client_0   2016-11-17          11       1335667.0              0
# 5   train_Client_0   2017-07-17          11       1335667.0              0
# 6   train_Client_0   2018-12-07          11       1335667.0              0
# 7   train_Client_0   2019-03-19          11       1335667.0              0
# 8   train_Client_0   2011-07-22          11       1335667.0              0
# 9   train_Client_0   2011-11-22          11       1335667.0              0
# 10  train_Client_0   2008-11-25          11       1335667.0              0
# ...

# %%
# Method 2

data.loc[data.client_id == 'train_Client_0']
# Out:
#          client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0   train_Client_0   2014-03-24          11       1335667.0              0
# 1   train_Client_0   2013-03-29          11       1335667.0              0
# 2   train_Client_0   2015-03-23          11       1335667.0              0
# 3   train_Client_0   2015-07-13          11       1335667.0              0
# 4   train_Client_0   2016-11-17          11       1335667.0              0
# 5   train_Client_0   2017-07-17          11       1335667.0              0
# 6   train_Client_0   2018-12-07          11       1335667.0              0
# 7   train_Client_0   2019-03-19          11       1335667.0              0
# 8   train_Client_0   2011-07-22          11       1335667.0              0
# 9   train_Client_0   2011-11-22          11       1335667.0              0
# 10  train_Client_0   2008-11-25          11       1335667.0              0
# ...

# %%
data.head()
# Out:
#         client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0              0
# 1  train_Client_0   2013-03-29          11       1335667.0              0
# 2  train_Client_0   2015-03-23          11       1335667.0              0
# 3  train_Client_0   2015-07-13          11       1335667.0              0
# 4  train_Client_0   2016-11-17          11       1335667.0              0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# 0           203               8.0                  1.0                  82.0
# 1           203               6.0                  1.0                1200.0
# 2           203               8.0                  1.0                 123.0
# 3           207               8.0                  1.0                 102.0
# 4           207               9.0                  1.0                 572.0
#
# ...

# %%
data.counter_type.unique()
# Out:
# array(['ELEC', 'GAZ'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Transform the 'counter_type' feature to a numeric variable using the encoder of your choice.
le = LabelEncoder()

data.counter_type = le.fit_transform(data.counter_type)

data.head()
# Out:
#         client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0              0
# 1  train_Client_0   2013-03-29          11       1335667.0              0
# 2  train_Client_0   2015-03-23          11       1335667.0              0
# 3  train_Client_0   2015-07-13          11       1335667.0              0
# 4  train_Client_0   2016-11-17          11       1335667.0              0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# 0           203               8.0                  1.0                  82.0
# 1           203               6.0                  1.0                1200.0
# 2           203               8.0                  1.0                 123.0
# 3           207               8.0                  1.0                 102.0
# 4           207               9.0                  1.0                 572.0
#
# ...

# %%
# Delete the 'counter_statue' feature from the Dataframe

data.drop('counter_statue', axis=1, inplace=True)

data.head()
# Out:
#         client_id invoice_date  tarif_type  counter_number  counter_code  \
# 0  train_Client_0   2014-03-24          11       1335667.0           203
# 1  train_Client_0   2013-03-29          11       1335667.0           203
# 2  train_Client_0   2015-03-23          11       1335667.0           203
# 3  train_Client_0   2015-07-13          11       1335667.0           207
# 4  train_Client_0   2016-11-17          11       1335667.0           207
#
#    reading_remarque  counter_coefficient  consommation_level_1  \
# 0               8.0                  1.0                  82.0
# 1               6.0                  1.0                1200.0
# 2               8.0                  1.0                 123.0
# 3               8.0                  1.0                 102.0
# 4               9.0                  1.0                 572.0
#
#    consommation_level_2  consommation_level_3  consommation_level_4  \
# 0                   0.0                   0.0                   0.0
# ...
