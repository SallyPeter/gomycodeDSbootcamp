# %% [markdown]
# <a href="https://colab.research.google.com/github/SallyPeter/gomycodeDSbootcamp/blob/main/ML/Support_vector_machines_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# What You're Aiming For
#
# In this checkpoint, we are going to work on the 'Electric Vehicle Data' dataset that was provided by Kaggle as part of the Electric Vehicle Price Prediction competition.
#
# Dataset description: This dataset contains information on the Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs) that are currently registered with the Washington State Department of Licensing (DOL). This dataset was introduced as part of an official invitation-based competition on Kaggle. Our SVM model should answer the question "This is my car's model & make, along with a few other parameters, what price can this vehicle be brought or sold?”
#
# ➡️ Dataset link
#
# https://i.imgur.com/IpuCW3s.jpg
#
# ➡️Columns explanation

# %% [markdown]
# **Instructions**
#
# - Import you data and perform basic data exploration phase
#   - Display general information about the dataset
#   - Create a pandas profiling reports to gain insights into the dataset
#   - Handle Missing and corrupted values
#   - Remove duplicates, if they exist
#   - Handle outliers, if they exist
#   - Encode categorical features
# - Select your target variable and the features
# - Split your dataset to training and test sets
# - Build and train an SVM model on the training set
# - Assess your model performance on the test set using relevant evaluation metrics
# - Discuss with your cohort alternative ways to improve your model performance

# %%
import pandas as pd
import numpy as np
from sklearn import svm
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# Import you data and perform basic data exploration phase
data = pd.read_csv("Electric_cars_dataset.csv")
data.head()
# Out:
#         ID  VIN (1-10)     County        City State  ZIP Code  Model Year  \
# 0  EV33174  5YJ3E1EC6L  Snohomish    LYNNWOOD    WA   98037.0      2020.0
# 1  EV40247  JN1AZ0CP8B     Skagit  BELLINGHAM    WA   98229.0      2011.0
# 2  EV12248  WBY1Z2C56F     Pierce      TACOMA    WA   98422.0      2015.0
# 3  EV55713  1G1RD6E44D       King     REDMOND    WA   98053.0      2013.0
# 4  EV28799  1G1FY6S05K     Pierce    PUYALLUP    WA   98375.0      2019.0
#
#         Make    Model                   Electric Vehicle Type  \
# 0      TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 1     NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 2        BMW       I3          Battery Electric Vehicle (BEV)
# 3  CHEVROLET     VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 4  CHEVROLET  BOLT EV          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             308
# 1           Clean Alternative Fuel Vehicle Eligible              73
# 2           Clean Alternative Fuel Vehicle Eligible              81
# 3           Clean Alternative Fuel Vehicle Eligible              38
# 4           Clean Alternative Fuel Vehicle Eligible             238
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  32.0       109821694
# 1          0                  40.0       137375528
# 2          0                  27.0       150627382
# 3          0                  45.0       258766301
# 4          0                  25.0       296998138
#
#                 Vehicle Location  \
# 0   POINT (-122.287614 47.83874)
# 1  POINT (-122.414936 48.709388)
# 2  POINT (-122.396286 47.293138)
# 3  POINT (-122.024951 47.670286)
# 4  POINT (-122.321062 47.103797)
#
#                                     Electric Utility Expected Price ($1k)
# 0                             PUGET SOUND ENERGY INC                   50
# 1                             PUGET SOUND ENERGY INC                   15
# 2  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...                   18
# 3      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)                 33.9
# 4  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...                41.78

# %%
data.shape
# Out:
# (64353, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64353 entries, 0 to 64352
# Data columns (total 18 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   ID                                                 64353 non-null  object
#  1   VIN (1-10)                                         64353 non-null  object
#  2   County                                             64349 non-null  object
#  3   City                                               64344 non-null  object
#  4   State                                              64342 non-null  object
#  5   ZIP Code                                           64347 non-null  float64
#  6   Model Year                                         64346 non-null  float64
#  7   Make                                               64349 non-null  object
#  8   Model                                              64340 non-null  object
#  9   Electric Vehicle Type                              64353 non-null  object
#  10  Clean Alternative Fuel Vehicle (CAFV) Eligibility  64353 non-null  object
#  11  Electric Range                                     64353 non-null  int64
#  12  Base MSRP                                          64353 non-null  int64
#  13  Legislative District                               64184 non-null  float64
#  14  DOL Vehicle ID                                     64353 non-null  int64
#  15  Vehicle Location                                   63843 non-null  object
#  16  Electric Utility                                   63631 non-null  object
#  17  Expected Price ($1k)                               64353 non-null  object
# dtypes: float64(3), int64(3), object(12)
# memory usage: 8.8+ MB

# %% [markdown]
# ## Data Cleaning Part

# %% [markdown]
# First, we notice the Expected Price column is an object whereas it should be numeric

# %%
data['Expected Price ($1k)'].value_counts().sort_index()
# Out:
# Expected Price ($1k)
# 0           2
# 10         19
# 10.042    169
# 102       445
# 102.4       8
#          ...
# 90        611
# 95         77
# 96        105
# 98.4       89
# N/         13
# Name: count, Length: 210, dtype: int64

# %% [markdown]
# This is caused by some missing data with values as 'N/'.
#
# This would be replaced by the mean value of cars in the same vehicle type and Clean Alternative Fuel Vehicle eligibility

# %%
data[data['Expected Price ($1k)'] == 'N/']
# Out:
#             ID  VIN (1-10)     County               City State  ZIP Code  \
# 2714   EV35011  1FMCU0LZ4N       King       YARROW POINT    WA   98004.0
# 4081   EV55301  1FMCU0KZ4N     Island         OAK HARBOR    WA   98277.0
# 13866  EV20774  1FMCU0LZ2N  Jefferson        PORT LUDLOW    WA   98365.0
# 14787  EV21204  1FMCU0KZ2N      Clark              CAMAS    WA   98607.0
# 16164  EV68630  1FMCU0KZ9N       King           BELLEVUE    WA   98006.0
# 22827  EV51468  1FMCU0KZ3N       King            SEATTLE    WA   98103.0
# 26799  EV42602  1FMCU0EZ0N     Pierce         GIG HARBOR    WA   98332.0
# 28511  EV51868  1FMCU0KZ1N      Clark              CAMAS    WA   98607.0
# 31081  EV41495  1FMCU0EZ4N     Pierce             TACOMA    WA   98444.0
# 37957  EV35977  1FMCU0LZ5N      Clark          VANCOUVER    WA   98662.0
# 43801  EV31216  1FMCU0LZXN     Kitsap  BAINBRIDGE ISLAND    WA   98110.0
# 52689  EV30051  1FMCU0KZ9N     Benton           RICHLAND    WA   99352.0
# 58008  EV59640  1FMCU0EZ7N     Pierce        BONNEY LAKE    WA   98391.0
#
#        Model Year  Make Model                   Electric Vehicle Type  \
# 2714       2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 4081       2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 13866      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 14787      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 16164      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 22827      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 26799      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 28511      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 31081      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 37957      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 43801      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 52689      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 58008      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
#
#       Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 2714            Clean Alternative Fuel Vehicle Eligible              38
# 4081            Clean Alternative Fuel Vehicle Eligible              38
# 13866           Clean Alternative Fuel Vehicle Eligible              38
# 14787           Clean Alternative Fuel Vehicle Eligible              38
# 16164           Clean Alternative Fuel Vehicle Eligible              38
# 22827           Clean Alternative Fuel Vehicle Eligible              38
# 26799           Clean Alternative Fuel Vehicle Eligible              38
# 28511           Clean Alternative Fuel Vehicle Eligible              38
# 31081           Clean Alternative Fuel Vehicle Eligible              38
# 37957           Clean Alternative Fuel Vehicle Eligible              38
# 43801           Clean Alternative Fuel Vehicle Eligible              38
# 52689           Clean Alternative Fuel Vehicle Eligible              38
# 58008           Clean Alternative Fuel Vehicle Eligible              38
#
#        Base MSRP  Legislative District  DOL Vehicle ID  \
# 2714           0                  48.0       192602371
# 4081           0                  10.0       193046381
# 13866          0                  24.0       190318901
# 14787          0                  18.0       195263764
# 16164          0                  41.0       187155314
# 22827          0                  36.0       192317646
# 26799          0                  26.0       195845597
# 28511          0                  18.0       192539574
# 31081          0                  29.0       192962717
# 37957          0                  49.0       193422764
# 43801          0                  23.0       193742608
# 52689          0                   8.0       193482684
# 58008          0                  31.0       193129653
#
#                     Vehicle Location  \
# 2714   POINT (-122.203169 47.619011)
# 4081    POINT (-122.63841 48.310313)
# 13866   POINT (-122.69441 47.905058)
# 14787  POINT (-122.408498 45.620943)
# 16164  POINT (-122.151342 47.560192)
# 22827  POINT (-122.343577 47.672491)
# 26799   POINT (-122.599454 47.36582)
# 28511  POINT (-122.408498 45.620943)
# 31081    POINT (-122.447791 47.1543)
# 37957  POINT (-122.576308 45.677838)
# 43801  POINT (-122.534497 47.643688)
# 52689  POINT (-119.285025 46.247465)
# 58008  POINT (-122.170798 47.184615)
#
#                                         Electric Utility Expected Price ($1k)
# 2714       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)                   N/
# 4081                              PUGET SOUND ENERGY INC                   N/
# 13866  BONNEVILLE POWER ADMINISTRATION||PUGET SOUND E...                   N/
# 14787  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...                   N/
# 16164      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)                   N/
# 22827       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)                   N/
# 26799  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...                   N/
# 28511  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...                   N/
# 31081  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...                   N/
# 37957  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...                   N/
# 43801                             PUGET SOUND ENERGY INC                   N/
# 52689  BONNEVILLE POWER ADMINISTRATION||CITY OF RICHL...                   N/
# 58008      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)                   N/

# %%
ford = data.loc[(data['Electric Vehicle Type'] == 'Plug-in Hybrid Electric Vehicle (PHEV)') &
 (data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] == 'Clean Alternative Fuel Vehicle Eligible') & (data['Make'] == 'FORD') & (data['Expected Price ($1k)'] != 'N/')]['Expected Price ($1k)'].astype(int)

ford.mean()
# Out:
# 26.0

# %%
data['Expected Price ($1k)'] = data['Expected Price ($1k)'].replace('N/', str(ford.mean()))

data['Expected Price ($1k)'].value_counts().sort_index()
# Out:
# Expected Price ($1k)
# 0           2
# 10         19
# 10.042    169
# 102       445
# 102.4       8
#          ...
# 9.079      51
# 90        611
# 95         77
# 96        105
# 98.4       89
# Name: count, Length: 210, dtype: int64

# %% [markdown]
# Next, we convert the entire column to a float

# %%
data['Expected Price ($1k)'] = data['Expected Price ($1k)'].astype(float)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64353 entries, 0 to 64352
# Data columns (total 18 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   ID                                                 64353 non-null  object
#  1   VIN (1-10)                                         64353 non-null  object
#  2   County                                             64349 non-null  object
#  3   City                                               64344 non-null  object
#  4   State                                              64342 non-null  object
#  5   ZIP Code                                           64347 non-null  float64
#  6   Model Year                                         64346 non-null  float64
#  7   Make                                               64349 non-null  object
#  8   Model                                              64340 non-null  object
#  9   Electric Vehicle Type                              64353 non-null  object
#  10  Clean Alternative Fuel Vehicle (CAFV) Eligibility  64353 non-null  object
#  11  Electric Range                                     64353 non-null  int64
#  12  Base MSRP                                          64353 non-null  int64
#  13  Legislative District                               64184 non-null  float64
#  14  DOL Vehicle ID                                     64353 non-null  int64
#  15  Vehicle Location                                   63843 non-null  object
#  16  Electric Utility                                   63631 non-null  object
#  17  Expected Price ($1k)                               64353 non-null  float64
# dtypes: float64(4), int64(3), object(11)
# memory usage: 8.8+ MB

# %%
cat_col = data.select_dtypes(include='object')
cat_col.describe()
# Out:
#              ID  VIN (1-10) County     City  State   Make    Model  \
# count     64353       64353  64349    64344  64342  64349    64340
# unique    64353        5644    139      544     38     34      107
# top     EV33174  5YJYGDEE9M   King  SEATTLE     WA  TESLA  MODEL 3
# freq          1         340  33552    11887  64168  27903    13138
#
#                  Electric Vehicle Type  \
# count                            64353
# unique                               2
# top     Battery Electric Vehicle (BEV)
# freq                             47869
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  \
# count                                              64353
# unique                                                 3
# top              Clean Alternative Fuel Vehicle Eligible
# freq                                               39948
#
#                      Vehicle Location  \
# count                           63843
# unique                            668
# top     POINT (-122.122018 47.678465)
# freq                             1712
#
#                                      Electric Utility
# count                                           63631
# unique                                             68
# top     PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# freq                                            22555

# %%
num_col = data.select_dtypes(include='number')
num_col.describe()
# Out:
#            ZIP Code    Model Year  Electric Range      Base MSRP  \
# count  64347.000000  64346.000000    64353.000000   64353.000000
# mean   98143.452888   2018.186212      106.948985    2524.990754
# std     2856.064329      2.726742      104.093919   12402.895104
# min      745.000000   1993.000000        0.000000       0.000000
# 25%    98052.000000   2017.000000       14.000000       0.000000
# 50%    98121.000000   2018.000000       73.000000       0.000000
# 75%    98370.000000   2021.000000      215.000000       0.000000
# max    99701.000000   2022.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  Expected Price ($1k)
# count          64184.000000    6.435300e+04          64353.000000
# mean              29.951904    1.972905e+08             45.444041
# std               14.661124    1.069466e+08             24.727252
# min                0.000000    4.385000e+03              0.000000
# 25%               19.000000    1.372865e+08             22.857000
# 50%               34.000000    1.753776e+08             40.000000
# 75%               43.000000    2.299039e+08             65.900000
# max               49.000000    4.789346e+08           1100.000000

# %%
data.isnull().sum()
# Out:
# ID                                                     0
# VIN (1-10)                                             0
# County                                                 4
# City                                                   9
# State                                                 11
# ZIP Code                                               6
# Model Year                                             7
# Make                                                   4
# Model                                                 13
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 169
# DOL Vehicle ID                                         0
# Vehicle Location                                     510
# Electric Utility                                     722
# Expected Price ($1k)                                   0
# dtype: int64

# %% [markdown]
# Next, the location cordinate is split into logitude and latitude

# %%
# r, cord = data['Vehicle Location'][1].replace("POINT", " ").strip(' ()').split(' ')


data['Longitude'] = data['Vehicle Location'].str.replace("POINT", " ").str.strip(' ()').str.split(' ', expand=True)[0]
data['Latitude'] = data['Vehicle Location'].str.replace("POINT", " ").str.strip(' ()').str.split(' ', expand=True)[1]

data.head()
# Out:
#         ID  VIN (1-10)     County        City State  ZIP Code  Model Year  \
# 0  EV33174  5YJ3E1EC6L  Snohomish    LYNNWOOD    WA   98037.0      2020.0
# 1  EV40247  JN1AZ0CP8B     Skagit  BELLINGHAM    WA   98229.0      2011.0
# 2  EV12248  WBY1Z2C56F     Pierce      TACOMA    WA   98422.0      2015.0
# 3  EV55713  1G1RD6E44D       King     REDMOND    WA   98053.0      2013.0
# 4  EV28799  1G1FY6S05K     Pierce    PUYALLUP    WA   98375.0      2019.0
#
#         Make    Model                   Electric Vehicle Type  \
# 0      TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 1     NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 2        BMW       I3          Battery Electric Vehicle (BEV)
# 3  CHEVROLET     VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 4  CHEVROLET  BOLT EV          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             308
# 1           Clean Alternative Fuel Vehicle Eligible              73
# 2           Clean Alternative Fuel Vehicle Eligible              81
# 3           Clean Alternative Fuel Vehicle Eligible              38
# 4           Clean Alternative Fuel Vehicle Eligible             238
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  32.0       109821694
# 1          0                  40.0       137375528
# 2          0                  27.0       150627382
# 3          0                  45.0       258766301
# 4          0                  25.0       296998138
#
#                 Vehicle Location  \
# 0   POINT (-122.287614 47.83874)
# 1  POINT (-122.414936 48.709388)
# 2  POINT (-122.396286 47.293138)
# 3  POINT (-122.024951 47.670286)
# 4  POINT (-122.321062 47.103797)
#
#                                     Electric Utility  Expected Price ($1k)  \
# 0                             PUGET SOUND ENERGY INC                 50.00
# 1                             PUGET SOUND ENERGY INC                 15.00
# 2  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...                 18.00
# 3      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)                 33.90
# 4  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...                 41.78
#
#      Longitude   Latitude
# 0  -122.287614   47.83874
# 1  -122.414936  48.709388
# 2  -122.396286  47.293138
# 3  -122.024951  47.670286
# 4  -122.321062  47.103797

# %% [markdown]
# Next, we look into filling the missing values in the State column

# %%
data[data.State.isna()]
# Out:
#           ID  VIN (1-10)     County               City State  ZIP Code  \
# 820    EV235  1N4AZ0CP8E  Snohomish            EDMONDS   NaN   98020.0
# 2520   EV237  1N4AZ1CP6J  Anchorage            CHUGIAK   NaN   99567.0
# 6358   EV232  KNDJP3AE3J   Thurston              LACEY   NaN   98503.0
# 35043  EV229  1N4AZ1CP1L  Snohomish            BOTHELL   NaN   98012.0
# 35276  EV238  1N4AZ0CP8D       King            SEATTLE   NaN   98107.0
# 35944  EV230  5YJYGDEFXL     Kitsap  BAINBRIDGE ISLAND   NaN   98110.0
# 41173  EV231  5YJSA1E20G     Yakima             YAKIMA   NaN   98901.0
# 45990  EV228  1N4AZ0CP2D       King             VASHON   NaN   98070.0
# 52823  EV234  KNDCC3LGXL     Kitsap          BREMERTON   NaN   98310.0
# 54532  EV233  3FA6P0SU2G   Thurston              LACEY   NaN   98516.0
# 61735  EV239  3C3CFFGE3F       King            SEATTLE   NaN   98118.0
#
#        Model Year    Make    Model                   Electric Vehicle Type  \
# 820        2014.0  NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 2520       2018.0  NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 6358       2018.0     KIA  SOUL EV          Battery Electric Vehicle (BEV)
# 35043      2020.0  NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 35276      2013.0  NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 35944      2020.0   TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 41173      2016.0   TESLA  MODEL S          Battery Electric Vehicle (BEV)
# 45990      2013.0  NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 52823      2020.0     KIA     NIRO          Battery Electric Vehicle (BEV)
# 54532      2016.0    FORD   FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
# 61735      2015.0    FIAT      500          Battery Electric Vehicle (BEV)
#
#       Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 820             Clean Alternative Fuel Vehicle Eligible              84
# 2520            Clean Alternative Fuel Vehicle Eligible             151
# 6358            Clean Alternative Fuel Vehicle Eligible             111
# 35043           Clean Alternative Fuel Vehicle Eligible             149
# 35276           Clean Alternative Fuel Vehicle Eligible              75
# 35944           Clean Alternative Fuel Vehicle Eligible             291
# 41173           Clean Alternative Fuel Vehicle Eligible             210
# 45990           Clean Alternative Fuel Vehicle Eligible              75
# 52823           Clean Alternative Fuel Vehicle Eligible             239
# 54532             Not eligible due to low battery range              19
# 61735           Clean Alternative Fuel Vehicle Eligible              87
#
#        Base MSRP  Legislative District  DOL Vehicle ID  \
# 820            0                  32.0       109001532
# 2520           0                   NaN       311948836
# 6358       33950                   2.0       135658435
# 35043          0                   1.0       141325628
# 35276          0                  43.0       212078681
# 35944          0                  23.0       107236958
# 41173          0                  15.0       196516400
# 45990          0                  34.0       252897970
# 52823          0                  23.0       152551234
# 54532          0                  22.0       111939852
# 61735          0                  37.0       304339605
#
#                     Vehicle Location  \
# 820    POINT (-122.370709 47.801416)
# 2520    POINT (-149.425108 61.41463)
# 6358     POINT (-122.80237 47.02499)
# 35043  POINT (-122.201515 47.843376)
# 35276                            NaN
# 35944  POINT (-122.534497 47.643688)
# 41173  POINT (-120.441155 46.626077)
# 45990  POINT (-122.469161 47.415443)
# 52823  POINT (-122.623208 47.590898)
# 54532  POINT (-122.781876 47.089772)
# 61735   POINT (-122.275593 47.54055)
#
#                                     Electric Utility  Expected Price ($1k)  \
# 820                           PUGET SOUND ENERGY INC                19.000
# 2520                                             NaN                21.000
# 6358                          PUGET SOUND ENERGY INC                16.251
# 35043                         PUGET SOUND ENERGY INC                40.000
# 35276   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)                18.000
# 35944                         PUGET SOUND ENERGY INC                72.000
# 41173                                            NaN                65.000
# 45990  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)                18.000
# 52823                         PUGET SOUND ENERGY INC                33.000
# 54532                         PUGET SOUND ENERGY INC                20.000
# 61735   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)                10.042
#
#          Longitude   Latitude
# 820    -122.370709  47.801416
# 2520   -149.425108   61.41463
# 6358    -122.80237   47.02499
# 35043  -122.201515  47.843376
# 35276          NaN        NaN
# 35944  -122.534497  47.643688
# 41173  -120.441155  46.626077
# 45990  -122.469161  47.415443
# 52823  -122.623208  47.590898
# 54532  -122.781876  47.089772
# 61735  -122.275593   47.54055

# %%
data[data['ZIP Code'] == 98020.0]['State'].unique()
# Out:
# array(['WA', nan], dtype=object)

# %% [markdown]
# We do this by creating a dictionary of zipcodes, where the values are the states the zipcodes belong to.

# %%
# data.State.fillna(" ", inplace=True)
# data['ZIP Code'] = data['ZIP Code'].astype(str)

zip_state = {}

for each in np.array(data[['ZIP Code', 'State']]):
  if (not np.isnan(each[0]))  & (each[1] in ['WA', 'NC', 'CA','PA', 'IL', 'AE', 'NM', 'NY', 'MD', 'AP',  'VA', 'HI', 'CT', 'GA', 'TN', 'TX', 'DC', 'MS', 'RI', 'NE', 'NV', 'IN', 'WY', 'NJ', 'DE', 'KS', 'AK', 'OR', 'FL', 'PR', 'MA', 'MO', 'SD', 'MT', 'UT', 'LA', 'WI', 'AZ']) :
    # zip_state.add(tuple(each))
    zip_state[each[0]] = each[1]

# %% [markdown]
# The missing values are filled by mapping the zipcodes to the states

# %%
data['State'] = data['State'].fillna(data['ZIP Code'].map(zip_state))

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64353 entries, 0 to 64352
# Data columns (total 20 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   ID                                                 64353 non-null  object
#  1   VIN (1-10)                                         64353 non-null  object
#  2   County                                             64349 non-null  object
#  3   City                                               64344 non-null  object
#  4   State                                              64352 non-null  object
#  5   ZIP Code                                           64347 non-null  float64
#  6   Model Year                                         64346 non-null  float64
#  7   Make                                               64349 non-null  object
#  8   Model                                              64340 non-null  object
#  9   Electric Vehicle Type                              64353 non-null  object
#  10  Clean Alternative Fuel Vehicle (CAFV) Eligibility  64353 non-null  object
#  11  Electric Range                                     64353 non-null  int64
#  12  Base MSRP                                          64353 non-null  int64
#  13  Legislative District                               64184 non-null  float64
#  14  DOL Vehicle ID                                     64353 non-null  int64
#  15  Vehicle Location                                   63843 non-null  object
#  16  Electric Utility                                   63631 non-null  object
#  17  Expected Price ($1k)                               64353 non-null  float64
#  18  Longitude                                          63843 non-null  object
#  19  Latitude                                           63843 non-null  object
# dtypes: float64(4), int64(3), object(13)
# memory usage: 9.8+ MB

# %% [markdown]
# This resolves all of the missing values in the State column except for one where the zip code occured only once. An option to resolve this could be using the long and lat to calculate the distance and assign this record to the state group nearest to it. As this is only one record, this might not be exactly necessary.

# %%
data[data['State'].isna()]
# Out:
#          ID  VIN (1-10)     County     City State  ZIP Code  Model Year  \
# 2520  EV237  1N4AZ1CP6J  Anchorage  CHUGIAK   NaN   99567.0      2018.0
#
#         Make Model           Electric Vehicle Type  \
# 2520  NISSAN  LEAF  Battery Electric Vehicle (BEV)
#
#      Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 2520           Clean Alternative Fuel Vehicle Eligible             151
#
#       Base MSRP  Legislative District  DOL Vehicle ID  \
# 2520          0                   NaN       311948836
#
#                   Vehicle Location Electric Utility  Expected Price ($1k)  \
# 2520  POINT (-149.425108 61.41463)              NaN                  21.0
#
#         Longitude  Latitude
# 2520  -149.425108  61.41463

# %%
data[data['ZIP Code'] == 99567.0]
# Out:
#          ID  VIN (1-10)     County     City State  ZIP Code  Model Year  \
# 2520  EV237  1N4AZ1CP6J  Anchorage  CHUGIAK   NaN   99567.0      2018.0
#
#         Make Model           Electric Vehicle Type  \
# 2520  NISSAN  LEAF  Battery Electric Vehicle (BEV)
#
#      Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 2520           Clean Alternative Fuel Vehicle Eligible             151
#
#       Base MSRP  Legislative District  DOL Vehicle ID  \
# 2520          0                   NaN       311948836
#
#                   Vehicle Location Electric Utility  Expected Price ($1k)  \
# 2520  POINT (-149.425108 61.41463)              NaN                  21.0
#
#         Longitude  Latitude
# 2520  -149.425108  61.41463

# %%
data.isna().sum()
# Out:
# ID                                                     0
# VIN (1-10)                                             0
# County                                                 4
# City                                                   9
# State                                                  1
# ZIP Code                                               6
# Model Year                                             7
# Make                                                   4
# Model                                                 13
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 169
# DOL Vehicle ID                                         0
# Vehicle Location                                     510
# Electric Utility                                     722
# Expected Price ($1k)                                   0
# Longitude                                            510
# Latitude                                             510
# dtype: int64

# %% [markdown]
# Following this, we fill na for city using the zip code as seen earlier

# %%
zip_city = {}

for each in np.array(data[['ZIP Code', 'City']]):
  if (not np.isnan(each[0]))  :
    # zip_state.add(tuple(each))
    zip_city[each[0]] = each[1]



data['City'] = data['City'].fillna(data['ZIP Code'].map(zip_city))
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64353 entries, 0 to 64352
# Data columns (total 20 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   ID                                                 64353 non-null  object
#  1   VIN (1-10)                                         64353 non-null  object
#  2   County                                             64349 non-null  object
#  3   City                                               64353 non-null  object
#  4   State                                              64352 non-null  object
#  5   ZIP Code                                           64347 non-null  float64
#  6   Model Year                                         64346 non-null  float64
#  7   Make                                               64349 non-null  object
#  8   Model                                              64340 non-null  object
#  9   Electric Vehicle Type                              64353 non-null  object
#  10  Clean Alternative Fuel Vehicle (CAFV) Eligibility  64353 non-null  object
#  11  Electric Range                                     64353 non-null  int64
#  12  Base MSRP                                          64353 non-null  int64
#  13  Legislative District                               64184 non-null  float64
#  14  DOL Vehicle ID                                     64353 non-null  int64
#  15  Vehicle Location                                   63843 non-null  object
#  16  Electric Utility                                   63631 non-null  object
#  17  Expected Price ($1k)                               64353 non-null  float64
#  18  Longitude                                          63843 non-null  object
#  19  Latitude                                           63843 non-null  object
# dtypes: float64(4), int64(3), object(13)
# memory usage: 9.8+ MB

# %% [markdown]
# Same goes for the County

# %%
zip_county = {}

for each in np.array(data[['ZIP Code', 'County']]):
  if (not np.isnan(each[0]))  :
    # zip_state.add(tuple(each))
    zip_county[each[0]] = each[1]



data['County'] = data['County'].fillna(data['ZIP Code'].map(zip_county))
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64353 entries, 0 to 64352
# Data columns (total 20 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   ID                                                 64353 non-null  object
#  1   VIN (1-10)                                         64353 non-null  object
#  2   County                                             64349 non-null  object
#  3   City                                               64353 non-null  object
#  4   State                                              64352 non-null  object
#  5   ZIP Code                                           64347 non-null  float64
#  6   Model Year                                         64346 non-null  float64
#  7   Make                                               64349 non-null  object
#  8   Model                                              64340 non-null  object
#  9   Electric Vehicle Type                              64353 non-null  object
#  10  Clean Alternative Fuel Vehicle (CAFV) Eligibility  64353 non-null  object
#  11  Electric Range                                     64353 non-null  int64
#  12  Base MSRP                                          64353 non-null  int64
#  13  Legislative District                               64184 non-null  float64
#  14  DOL Vehicle ID                                     64353 non-null  int64
#  15  Vehicle Location                                   63843 non-null  object
#  16  Electric Utility                                   63631 non-null  object
#  17  Expected Price ($1k)                               64353 non-null  float64
#  18  Longitude                                          63843 non-null  object
#  19  Latitude                                           63843 non-null  object
# dtypes: float64(4), int64(3), object(13)
# memory usage: 9.8+ MB

# %% [markdown]
# We notice some records in County appeared only once in the dataset, the zipcode and the State is also uncommon appearing only once in the dataet.
#
# This records would later be removed as other columns which may be useful for our analysis are missing

# %%
data[data['County'].isna()]
# Out:
#             ID  VIN (1-10) County City State  ZIP Code  Model Year       Make  \
# 2195   EV45994  5YJ3E1EB1J    NaN  APO    AE    9751.0      2018.0      TESLA
# 5913   EV39990  1C4JJXR67M    NaN  FPO    AP   96349.0      2021.0       JEEP
# 40262   EV7503  1G1RA6E49F    NaN  FPO    AP   96678.0      2015.0  CHEVROLET
# 52218     EV69  1FADP5FU6H    NaN  FPO    AP   96662.0      2017.0       FORD
#
#           Model                   Electric Vehicle Type  \
# 2195    MODEL 3          Battery Electric Vehicle (BEV)
# 5913   WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 40262      VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 52218     C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
#
#       Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 2195            Clean Alternative Fuel Vehicle Eligible             215
# 5913              Not eligible due to low battery range              21
# 40262           Clean Alternative Fuel Vehicle Eligible              38
# 52218             Not eligible due to low battery range              20
#
#        Base MSRP  Legislative District  DOL Vehicle ID Vehicle Location  \
# 2195           0                   NaN       475911509              NaN
# 5913           0                   NaN       187228030              NaN
# 40262          0                   NaN       232819723              NaN
# 52218          0                   NaN       138149357              NaN
#
#       Electric Utility  Expected Price ($1k) Longitude Latitude
# 2195               NaN                  69.0       NaN      NaN
# 5913               NaN                  40.0       NaN      NaN
# 40262              NaN                  18.5       NaN      NaN
# 52218              NaN                  21.0       NaN      NaN

# %% [markdown]
# We alo try to fill the legislative district using the same technique

# %%
zip_ld = {}

for each in np.array(data[['ZIP Code', 'Legislative District']]):
  if (not np.isnan(each[0]))  & (not np.isnan(each[1]))  :
    # zip_state.add(tuple(each))
    zip_ld[each[0]] = each[1]



data['Legislative District'] = data['Legislative District'].fillna(data['ZIP Code'].map(zip_ld))
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64353 entries, 0 to 64352
# Data columns (total 20 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   ID                                                 64353 non-null  object
#  1   VIN (1-10)                                         64353 non-null  object
#  2   County                                             64349 non-null  object
#  3   City                                               64353 non-null  object
#  4   State                                              64352 non-null  object
#  5   ZIP Code                                           64347 non-null  float64
#  6   Model Year                                         64346 non-null  float64
#  7   Make                                               64349 non-null  object
#  8   Model                                              64340 non-null  object
#  9   Electric Vehicle Type                              64353 non-null  object
#  10  Clean Alternative Fuel Vehicle (CAFV) Eligibility  64353 non-null  object
#  11  Electric Range                                     64353 non-null  int64
#  12  Base MSRP                                          64353 non-null  int64
#  13  Legislative District                               64184 non-null  float64
#  14  DOL Vehicle ID                                     64353 non-null  int64
#  15  Vehicle Location                                   63843 non-null  object
#  16  Electric Utility                                   63631 non-null  object
#  17  Expected Price ($1k)                               64353 non-null  float64
#  18  Longitude                                          63843 non-null  object
#  19  Latitude                                           63843 non-null  object
# dtypes: float64(4), int64(3), object(13)
# memory usage: 9.8+ MB

# %%
zip_ld = {}

for each in np.array(data[['ZIP Code', 'Legislative District']]):
  if (not np.isnan(each[0]))  & (not np.isnan(each[1]))  :
    # zip_state.add(tuple(each))
    zip_ld[each[0]] = each[1]



data['Legislative District'] = data['Legislative District'].fillna(data['ZIP Code'].map(zip_ld))
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64353 entries, 0 to 64352
# Data columns (total 20 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   ID                                                 64353 non-null  object
#  1   VIN (1-10)                                         64353 non-null  object
#  2   County                                             64349 non-null  object
#  3   City                                               64353 non-null  object
#  4   State                                              64352 non-null  object
#  5   ZIP Code                                           64347 non-null  float64
#  6   Model Year                                         64346 non-null  float64
#  7   Make                                               64349 non-null  object
#  8   Model                                              64340 non-null  object
#  9   Electric Vehicle Type                              64353 non-null  object
#  10  Clean Alternative Fuel Vehicle (CAFV) Eligibility  64353 non-null  object
#  11  Electric Range                                     64353 non-null  int64
#  12  Base MSRP                                          64353 non-null  int64
#  13  Legislative District                               64184 non-null  float64
#  14  DOL Vehicle ID                                     64353 non-null  int64
#  15  Vehicle Location                                   63843 non-null  object
#  16  Electric Utility                                   63631 non-null  object
#  17  Expected Price ($1k)                               64353 non-null  float64
#  18  Longitude                                          63843 non-null  object
#  19  Latitude                                           63843 non-null  object
# dtypes: float64(4), int64(3), object(13)
# memory usage: 9.8+ MB

# %% [markdown]
# This does not really fill in the missing data as expected.

# %%
data[data['Legislative District'].isna()]
# Out:
#             ID  VIN (1-10)           County             City State  ZIP Code  \
# 85     EV91250  1FTFW1ED3M       Cumberland     FAYETTEVILLE    NC   28311.0
# 787     EV3014  KNDCD3LD6N            Marin       SAN RAFAEL    CA   94901.0
# 1465   EV68073  3FMTK3SU9M       Montgomery  FORT WASHINGTON    PA   19034.0
# 1830   EV18703  5YJ3E1EB3J             Lake    HIGHLAND PARK    IL   60035.0
# 2195   EV45994  5YJ3E1EB1J              NaN              APO    AE    9751.0
# ...        ...         ...              ...              ...   ...       ...
# 61614  EV33766  1G1RC6E48B   Prince William       WOODBRIDGE    VA   22191.0
# 63329  EV16543  5YJ3E1EB0J  Alexandria City       ALEXANDRIA    VA   22301.0
# 63772  EV74159  5YJ3E1EBXK        Frederick        FREDERICK    MD   21704.0
# 64151  EV43314  2C4RC1N72J     Anne Arundel         PASADENA    MD   21122.0
# 64170  EV25189  5YJ3E1EA1M        San Diego      CHULA VISTA    CA   91913.0
#
#        Model Year       Make     Model  \
# 85         2021.0       FORD     F-150
# 787        2022.0        KIA      NIRO
# 1465       2021.0       FORD    MACH-E
# 1830       2018.0      TESLA   MODEL 3
# 2195       2018.0      TESLA   MODEL 3
# ...           ...        ...       ...
# 61614      2011.0  CHEVROLET      VOLT
# 63329      2018.0      TESLA   MODEL 3
# 63772      2019.0      TESLA   MODEL 3
# 64151      2018.0   CHRYSLER  PACIFICA
# 64170      2021.0      TESLA   MODEL 3
#
#                         Electric Vehicle Type  \
# 85             Battery Electric Vehicle (BEV)
# 787    Plug-in Hybrid Electric Vehicle (PHEV)
# 1465           Battery Electric Vehicle (BEV)
# 1830           Battery Electric Vehicle (BEV)
# 2195           Battery Electric Vehicle (BEV)
# ...                                       ...
# 61614  Plug-in Hybrid Electric Vehicle (PHEV)
# 63329          Battery Electric Vehicle (BEV)
# 63772          Battery Electric Vehicle (BEV)
# 64151  Plug-in Hybrid Electric Vehicle (PHEV)
# 64170          Battery Electric Vehicle (BEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 85     Eligibility unknown as battery range has not b...               0
# 787                Not eligible due to low battery range              26
# 1465   Eligibility unknown as battery range has not b...               0
# 1830             Clean Alternative Fuel Vehicle Eligible             215
# 2195             Clean Alternative Fuel Vehicle Eligible             215
# ...                                                  ...             ...
# 61614            Clean Alternative Fuel Vehicle Eligible              35
# 63329            Clean Alternative Fuel Vehicle Eligible             215
# 63772            Clean Alternative Fuel Vehicle Eligible             220
# 64151            Clean Alternative Fuel Vehicle Eligible              33
# 64170  Eligibility unknown as battery range has not b...               0
#
#        Base MSRP  Legislative District  DOL Vehicle ID  \
# 85             0                   NaN       148274808
# 787            0                   NaN       181521700
# 1465           0                   NaN       172153180
# 1830           0                   NaN       128455015
# 2195           0                   NaN       475911509
# ...          ...                   ...             ...
# 61614          0                   NaN       144232399
# 63329          0                   NaN       261314294
# 63772          0                   NaN       114252337
# 64151          0                   NaN       269209055
# 64170          0                   NaN       151035818
#
#                     Vehicle Location Electric Utility  Expected Price ($1k)  \
# 85      POINT (-78.891986 35.143971)              NaN                 43.00
# 787     POINT (-122.51209 37.973771)              NaN                 24.69
# 1465    POINT (-75.204534 40.135618)              NaN                 42.80
# 1830    POINT (-87.808789 42.182578)              NaN                 69.00
# 2195                             NaN              NaN                 69.00
# ...                              ...              ...                   ...
# 61614   POINT (-77.272331 38.627945)              NaN                  7.00
# 63329   POINT (-77.059798 38.819698)              NaN                 69.00
# 63772   POINT (-77.368491 39.354463)              NaN                 57.00
# 64151   POINT (-76.514013 39.124897)              NaN                 30.00
# 64170  POINT (-116.986172 32.631992)              NaN                 64.00
#
#          Longitude   Latitude
# 85      -78.891986  35.143971
# 787     -122.51209  37.973771
# 1465    -75.204534  40.135618
# 1830    -87.808789  42.182578
# 2195           NaN        NaN
# ...            ...        ...
# 61614   -77.272331  38.627945
# 63329   -77.059798  38.819698
# 63772   -77.368491  39.354463
# 64151   -76.514013  39.124897
# 64170  -116.986172  32.631992
#
# [169 rows x 20 columns]

# %% [markdown]
# We also use same format to fill missing values in the Electric Utility column

# %%
# data[data['Electric Utility'].isna()]

zip_eu = {}

for each in np.array(data[['ZIP Code', 'Electric Utility']]):
  if (not np.isnan(each[0])) & (not pd.isna(each[1]))  :
    # zip_state.add(tuple(each))
    zip_eu[each[0]] = each[1]

data['Electric Utility'] = data['Electric Utility'].fillna(data['ZIP Code'].map(zip_eu))
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64353 entries, 0 to 64352
# Data columns (total 20 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   ID                                                 64353 non-null  object
#  1   VIN (1-10)                                         64353 non-null  object
#  2   County                                             64349 non-null  object
#  3   City                                               64353 non-null  object
#  4   State                                              64352 non-null  object
#  5   ZIP Code                                           64347 non-null  float64
#  6   Model Year                                         64346 non-null  float64
#  7   Make                                               64349 non-null  object
#  8   Model                                              64340 non-null  object
#  9   Electric Vehicle Type                              64353 non-null  object
#  10  Clean Alternative Fuel Vehicle (CAFV) Eligibility  64353 non-null  object
#  11  Electric Range                                     64353 non-null  int64
#  12  Base MSRP                                          64353 non-null  int64
#  13  Legislative District                               64184 non-null  float64
#  14  DOL Vehicle ID                                     64353 non-null  int64
#  15  Vehicle Location                                   63843 non-null  object
#  16  Electric Utility                                   63975 non-null  object
#  17  Expected Price ($1k)                               64353 non-null  float64
#  18  Longitude                                          63843 non-null  object
#  19  Latitude                                           63843 non-null  object
# dtypes: float64(4), int64(3), object(13)
# memory usage: 9.8+ MB

# %%
data.isna().sum()
# Out:
# ID                                                     0
# VIN (1-10)                                             0
# County                                                 4
# City                                                   0
# State                                                  1
# ZIP Code                                               6
# Model Year                                             7
# Make                                                   4
# Model                                                 13
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 169
# DOL Vehicle ID                                         0
# Vehicle Location                                     510
# Electric Utility                                     378
# Expected Price ($1k)                                   0
# Longitude                                            510
# Latitude                                             510
# dtype: int64

# %%
data[data.Model.isna()]
# Out:
#             ID  VIN (1-10)     County               City State  ZIP Code  \
# 2714   EV35011  1FMCU0LZ4N       King       YARROW POINT    WA   98004.0
# 4081   EV55301  1FMCU0KZ4N     Island         OAK HARBOR    WA   98277.0
# 13866  EV20774  1FMCU0LZ2N  Jefferson        PORT LUDLOW    WA   98365.0
# 14787  EV21204  1FMCU0KZ2N      Clark              CAMAS    WA   98607.0
# 16164  EV68630  1FMCU0KZ9N       King           BELLEVUE    WA   98006.0
# 22827  EV51468  1FMCU0KZ3N       King            SEATTLE    WA   98103.0
# 26799  EV42602  1FMCU0EZ0N     Pierce         GIG HARBOR    WA   98332.0
# 28511  EV51868  1FMCU0KZ1N      Clark              CAMAS    WA   98607.0
# 31081  EV41495  1FMCU0EZ4N     Pierce             TACOMA    WA   98444.0
# 37957  EV35977  1FMCU0LZ5N      Clark          VANCOUVER    WA   98662.0
# 43801  EV31216  1FMCU0LZXN     Kitsap  BAINBRIDGE ISLAND    WA   98110.0
# 52689  EV30051  1FMCU0KZ9N     Benton           RICHLAND    WA   99352.0
# 58008  EV59640  1FMCU0EZ7N     Pierce        BONNEY LAKE    WA   98391.0
#
#        Model Year  Make Model                   Electric Vehicle Type  \
# 2714       2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 4081       2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 13866      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 14787      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 16164      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 22827      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 26799      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 28511      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 31081      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 37957      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 43801      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 52689      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
# 58008      2022.0  FORD   NaN  Plug-in Hybrid Electric Vehicle (PHEV)
#
#       Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 2714            Clean Alternative Fuel Vehicle Eligible              38
# 4081            Clean Alternative Fuel Vehicle Eligible              38
# 13866           Clean Alternative Fuel Vehicle Eligible              38
# 14787           Clean Alternative Fuel Vehicle Eligible              38
# 16164           Clean Alternative Fuel Vehicle Eligible              38
# 22827           Clean Alternative Fuel Vehicle Eligible              38
# 26799           Clean Alternative Fuel Vehicle Eligible              38
# 28511           Clean Alternative Fuel Vehicle Eligible              38
# 31081           Clean Alternative Fuel Vehicle Eligible              38
# 37957           Clean Alternative Fuel Vehicle Eligible              38
# 43801           Clean Alternative Fuel Vehicle Eligible              38
# 52689           Clean Alternative Fuel Vehicle Eligible              38
# 58008           Clean Alternative Fuel Vehicle Eligible              38
#
#        Base MSRP  Legislative District  DOL Vehicle ID  \
# 2714           0                  48.0       192602371
# 4081           0                  10.0       193046381
# 13866          0                  24.0       190318901
# 14787          0                  18.0       195263764
# 16164          0                  41.0       187155314
# 22827          0                  36.0       192317646
# 26799          0                  26.0       195845597
# 28511          0                  18.0       192539574
# 31081          0                  29.0       192962717
# 37957          0                  49.0       193422764
# 43801          0                  23.0       193742608
# 52689          0                   8.0       193482684
# 58008          0                  31.0       193129653
#
#                     Vehicle Location  \
# 2714   POINT (-122.203169 47.619011)
# 4081    POINT (-122.63841 48.310313)
# 13866   POINT (-122.69441 47.905058)
# 14787  POINT (-122.408498 45.620943)
# 16164  POINT (-122.151342 47.560192)
# 22827  POINT (-122.343577 47.672491)
# 26799   POINT (-122.599454 47.36582)
# 28511  POINT (-122.408498 45.620943)
# 31081    POINT (-122.447791 47.1543)
# 37957  POINT (-122.576308 45.677838)
# 43801  POINT (-122.534497 47.643688)
# 52689  POINT (-119.285025 46.247465)
# 58008  POINT (-122.170798 47.184615)
#
#                                         Electric Utility  \
# 2714       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 4081                              PUGET SOUND ENERGY INC
# 13866  BONNEVILLE POWER ADMINISTRATION||PUGET SOUND E...
# 14787  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...
# 16164      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 22827       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 26799  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...
# 28511  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...
# 31081  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...
# 37957  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...
# 43801                             PUGET SOUND ENERGY INC
# 52689  BONNEVILLE POWER ADMINISTRATION||CITY OF RICHL...
# 58008      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
#
#        Expected Price ($1k)    Longitude   Latitude
# 2714                   26.0  -122.203169  47.619011
# 4081                   26.0   -122.63841  48.310313
# 13866                  26.0   -122.69441  47.905058
# 14787                  26.0  -122.408498  45.620943
# 16164                  26.0  -122.151342  47.560192
# 22827                  26.0  -122.343577  47.672491
# 26799                  26.0  -122.599454   47.36582
# 28511                  26.0  -122.408498  45.620943
# 31081                  26.0  -122.447791    47.1543
# 37957                  26.0  -122.576308  45.677838
# 43801                  26.0  -122.534497  47.643688
# 52689                  26.0  -119.285025  46.247465
# 58008                  26.0  -122.170798  47.184615

# %% [markdown]
# Next, we fill the missing values in the Model column using the mapping to the zip codes

# %%
# cdata = data.copy()

ford_zip = list(data[data.Model.isna()]['ZIP Code'])

# for each in ford_zip:
#   data['Model'] =

for zip_code in ford_zip:
    mode_model = data[(data['ZIP Code'] == zip_code) & (data['Make'] == 'FORD')]['Model'].mode()
    if not mode_model.empty:
        data.loc[(data['ZIP Code'] == zip_code) & (data['Make'] == 'FORD') & (data['Model'].isna()), 'Model'] = mode_model[0]



# data[(data['ZIP Code']==98004.0) & (data['Make']=='FORD')]['Model'].mode()

data[data.Model.isna()]
# Out:
# Empty DataFrame
# Columns: [ID, VIN (1-10), County, City, State, ZIP Code, Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID, Vehicle Location, Electric Utility, Expected Price ($1k), Longitude, Latitude]
# Index: []

# %%
data.isna().sum()
# Out:
# ID                                                     0
# VIN (1-10)                                             0
# County                                                 4
# City                                                   0
# State                                                  1
# ZIP Code                                               6
# Model Year                                             7
# Make                                                   4
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 169
# DOL Vehicle ID                                         0
# Vehicle Location                                     510
# Electric Utility                                     378
# Expected Price ($1k)                                   0
# Longitude                                            510
# Latitude                                             510
# dtype: int64

# %% [markdown]
# Then we drop the records with missing values in the County Column

# %%
data.drop(data[data.County.isna()].index, inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64349 entries, 0 to 64352
# Data columns (total 20 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   ID                                                 64349 non-null  object
#  1   VIN (1-10)                                         64349 non-null  object
#  2   County                                             64349 non-null  object
#  3   City                                               64349 non-null  object
#  4   State                                              64348 non-null  object
#  5   ZIP Code                                           64343 non-null  float64
#  6   Model Year                                         64342 non-null  float64
#  7   Make                                               64345 non-null  object
#  8   Model                                              64349 non-null  object
#  9   Electric Vehicle Type                              64349 non-null  object
#  10  Clean Alternative Fuel Vehicle (CAFV) Eligibility  64349 non-null  object
#  11  Electric Range                                     64349 non-null  int64
#  12  Base MSRP                                          64349 non-null  int64
#  13  Legislative District                               64184 non-null  float64
#  14  DOL Vehicle ID                                     64349 non-null  int64
#  15  Vehicle Location                                   63843 non-null  object
#  16  Electric Utility                                   63975 non-null  object
#  17  Expected Price ($1k)                               64349 non-null  float64
#  18  Longitude                                          63843 non-null  object
#  19  Latitude                                           63843 non-null  object
# dtypes: float64(4), int64(3), object(13)
# memory usage: 10.3+ MB

# %% [markdown]
# We also drop records without a vehicle location

# %%
data = data.drop(data[data['Vehicle Location'].isna()].index)
# data.info()
# data.isna().sum()

# %%
data.isna().sum()
# Out:
# ID                                                     0
# VIN (1-10)                                             0
# County                                                 0
# City                                                   0
# State                                                  1
# ZIP Code                                               4
# Model Year                                             7
# Make                                                   4
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 165
# DOL Vehicle ID                                         0
# Vehicle Location                                       0
# Electric Utility                                     374
# Expected Price ($1k)                                   0
# Longitude                                              0
# Latitude                                               0
# dtype: int64

# %% [markdown]
# We drop the records with missing Zip Codes

# %%
# data.drop(data['Electric Utility'].isna().index, inplace=True)
data = data.drop(data[data['ZIP Code'].isna()].index)
data.isna().sum()
# Out:
# ID                                                     0
# VIN (1-10)                                             0
# County                                                 0
# City                                                   0
# State                                                  1
# ZIP Code                                               0
# Model Year                                             7
# Make                                                   4
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 165
# DOL Vehicle ID                                         0
# Vehicle Location                                       0
# Electric Utility                                     374
# Expected Price ($1k)                                   0
# Longitude                                              0
# Latitude                                               0
# dtype: int64

# %% [markdown]
# We fill the Make column using the mapping technique between Make and Model

# %%
# data[data['Model'] == 'LEAF']['Make'].mode()


make_model = {}

for each in np.array(data[['Model', 'Make']]):
  if each[0] :
    if each[1]:
    # zip_state.add(tuple(each))
      make_model[each[0]] = each[1]


data['Make'] = data['Make'].fillna(data['Model'].map(make_model))
data.isna().sum()
# Out:
# ID                                                     0
# VIN (1-10)                                             0
# County                                                 0
# City                                                   0
# State                                                  1
# ZIP Code                                               0
# Model Year                                             7
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 165
# DOL Vehicle ID                                         0
# Vehicle Location                                       0
# Electric Utility                                     374
# Expected Price ($1k)                                   0
# Longitude                                              0
# Latitude                                               0
# dtype: int64

# %% [markdown]
# Next, we fill the missing values in the Model Year column

# %%
# cdata[(cdata['ZIP Code'] == 98004.0) & (cdata['Make'] == 'FORD')]['Model'].mode()

data[data['Model Year'].isna()]
# Out:
#           ID  VIN (1-10)     County            City State  ZIP Code  \
# 18618  EV258  KMHE34L17G    Spokane  SPOKANE VALLEY    WA   99016.0
# 34663  EV255  5YJ3E1EB6K       King         SEATTLE    WA   98115.0
# 35578  EV250  5YJSA1CP9D      Clark       VANCOUVER    WA   98683.0
# 50803  EV252  5YJYGDEF0L     Chelan       WENATCHEE    WA   98801.0
# 54860  EV249  WAUTPBFF2G  Snohomish         EDMONDS    WA   98026.0
# 59409  EV256  5YJ3E1EB0M      Clark           CAMAS    WA   98607.0
# 62552  EV253  5YJ3E1EA2M       King         SEATTLE    WA   98144.0
#
#        Model Year     Make                  Model  \
# 18618         NaN  HYUNDAI  SONATA PLUG-IN HYBRID
# 34663         NaN    TESLA                MODEL 3
# 35578         NaN    TESLA                MODEL S
# 50803         NaN    TESLA                MODEL Y
# 54860         NaN     AUDI                     A3
# 59409         NaN    TESLA                MODEL 3
# 62552         NaN    TESLA                MODEL 3
#
#                         Electric Vehicle Type  \
# 18618  Plug-in Hybrid Electric Vehicle (PHEV)
# 34663          Battery Electric Vehicle (BEV)
# 35578          Battery Electric Vehicle (BEV)
# 50803          Battery Electric Vehicle (BEV)
# 54860  Plug-in Hybrid Electric Vehicle (PHEV)
# 59409          Battery Electric Vehicle (BEV)
# 62552          Battery Electric Vehicle (BEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 18618              Not eligible due to low battery range              27
# 34663            Clean Alternative Fuel Vehicle Eligible             220
# 35578            Clean Alternative Fuel Vehicle Eligible             208
# 50803            Clean Alternative Fuel Vehicle Eligible             291
# 54860              Not eligible due to low battery range              16
# 59409  Eligibility unknown as battery range has not b...               0
# 62552  Eligibility unknown as battery range has not b...               0
#
#        Base MSRP  Legislative District  DOL Vehicle ID  \
# 18618      34600                   4.0       476776030
# 34663          0                  46.0       192220731
# 35578      69900                  17.0       193870848
# 50803          0                  12.0       127404371
# 54860          0                  21.0       165842008
# 59409          0                  18.0       169660508
# 62552          0                  37.0       150168735
#
#                     Vehicle Location  \
# 18618  POINT (-117.152872 47.645579)
# 34663  POINT (-122.297534 47.685291)
# 35578  POINT (-122.510748 45.603727)
# 50803  POINT (-120.336499 47.425146)
# 54860  POINT (-122.333046 47.829439)
# 59409  POINT (-122.408498 45.620943)
# 62552   POINT (-122.30033 47.585339)
#
#                                         Electric Utility  \
# 18618  BONNEVILLE POWER ADMINISTRATION||AVISTA CORP||...
# 34663       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 35578  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...
# 50803                          PUD NO 1 OF CHELAN COUNTY
# 54860                             PUGET SOUND ENERGY INC
# 59409  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...
# 62552       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
#
#        Expected Price ($1k)    Longitude   Latitude
# 18618                16.365  -117.152872  47.645579
# 34663                57.000  -122.297534  47.685291
# 35578                33.890  -122.510748  45.603727
# 50803                72.000  -120.336499  47.425146
# 54860                18.860  -122.333046  47.829439
# 59409                64.000  -122.408498  45.620943
# 62552                64.000   -122.30033  47.585339

# %%
data[(data['Make']== 'HYUNDAI') & (data['Model'] == 'SONATA PLUG-IN HYBRID') & (data['City'] == 'SPOKANE VALLEY')]['Model Year'].mode()
# Out:
# 0    2016.0
# Name: Model Year, dtype: float64

# %%
zip_mmy = {}

for each in np.array(data[['Make', 'Model', 'City', 'Model Year']]):
  key = str(each[0]) + str(each[1]) + str(each[2])
  zip_mmy[key] = each[3]


data['key'] = data['Make'].astype(str) + data['Model'].astype(str) + data['City'].astype(str)
data['Model Year'] = data['Model Year'].fillna(data['key'].map(zip_mmy))

data['Model Year'] = data['Model Year'].fillna(data['key'].mode())
data.isna().sum()
# Out:
# <ipython-input-39-938e9f888e64>:11: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Model Year'] = data['Model Year'].fillna(data['key'].mode())
# ID                                                     0
# VIN (1-10)                                             0
# County                                                 0
# City                                                   0
# State                                                  1
# ZIP Code                                               0
# Model Year                                             1
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 165
# DOL Vehicle ID                                         0
# Vehicle Location                                       0
# Electric Utility                                     374
# Expected Price ($1k)                                   0
# Longitude                                              0
# Latitude                                               0
# key                                                    0
# dtype: int64

# %% [markdown]
# Lastly we drop the records with missing values in the legislative District column

# %%
data = data.drop(data[data['Legislative District'].isna()].index)
data.isna().sum()
# Out:
# ID                                                     0
# VIN (1-10)                                             0
# County                                                 0
# City                                                   0
# State                                                  0
# ZIP Code                                               0
# Model Year                                             1
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                   0
# DOL Vehicle ID                                         0
# Vehicle Location                                       0
# Electric Utility                                     209
# Expected Price ($1k)                                   0
# Longitude                                              0
# Latitude                                               0
# key                                                    0
# dtype: int64

# %%
make = list(data[data['Electric Utility'].isna()]['Make'])
model = list(data[data['Electric Utility'].isna()]['Model'])

make_model = [f"{m} {mo}" for m, mo in zip(make, model)]

# for each in ford_zip:
#   data['Model'] =

for each in make_model:
    mode_model = data[(data['Make'] == each.split(" ", 1)[0]) & (data['Model'] ==each.split(" ", 1)[1])]['Electric Utility'].mode()
    if not mode_model.empty:
        data.loc[(data['Make'] == each.split(" ", 1)[0]) & (data['Model'] == each.split(" ", 1)[1]) & (data['Electric Utility'].isna()), 'Electric Utility'] = mode_model[0]



# data[(data['ZIP Code']==98004.0) & (data['Make']=='FORD')]['Model'].mode()

data[data['Electric Utility'].isna()]
# Out:
# Empty DataFrame
# Columns: [ID, VIN (1-10), County, City, State, ZIP Code, Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID, Vehicle Location, Electric Utility, Expected Price ($1k), Longitude, Latitude, key]
# Index: []
#
# [0 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63674 entries, 0 to 64352
# Data columns (total 21 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   ID                                                 63674 non-null  object
#  1   VIN (1-10)                                         63674 non-null  object
#  2   County                                             63674 non-null  object
#  3   City                                               63674 non-null  object
#  4   State                                              63674 non-null  object
#  5   ZIP Code                                           63674 non-null  float64
#  6   Model Year                                         63673 non-null  float64
#  7   Make                                               63674 non-null  object
#  8   Model                                              63674 non-null  object
#  9   Electric Vehicle Type                              63674 non-null  object
#  10  Clean Alternative Fuel Vehicle (CAFV) Eligibility  63674 non-null  object
#  11  Electric Range                                     63674 non-null  int64
#  12  Base MSRP                                          63674 non-null  int64
#  13  Legislative District                               63674 non-null  float64
#  14  DOL Vehicle ID                                     63674 non-null  int64
#  15  Vehicle Location                                   63674 non-null  object
#  16  Electric Utility                                   63674 non-null  object
#  17  Expected Price ($1k)                               63674 non-null  float64
#  18  Longitude                                          63674 non-null  object
#  19  Latitude                                           63674 non-null  object
#  20  key                                                63674 non-null  object
# dtypes: float64(4), int64(3), object(14)
# memory usage: 10.7+ MB

# %%
data.drop('key', axis = 1, inplace=True)

# %%
data.head(2).T
# Out:
#                                                                                          0  \
# ID                                                                                 EV33174
# VIN (1-10)                                                                      5YJ3E1EC6L
# County                                                                           Snohomish
# City                                                                              LYNNWOOD
# State                                                                                   WA
# ZIP Code                                                                           98037.0
# Model Year                                                                          2020.0
# Make                                                                                 TESLA
# Model                                                                              MODEL 3
# Electric Vehicle Type                                       Battery Electric Vehicle (BEV)
# Clean Alternative Fuel Vehicle (CAFV) Eligibility  Clean Alternative Fuel Vehicle Eligible
# Electric Range                                                                         308
# Base MSRP                                                                                0
# Legislative District                                                                  32.0
# DOL Vehicle ID                                                                   109821694
# Vehicle Location                                              POINT (-122.287614 47.83874)
# Electric Utility                                                    PUGET SOUND ENERGY INC
# Expected Price ($1k)                                                                  50.0
# Longitude                                                                      -122.287614
# Latitude                                                                          47.83874
#
#                                                                                          1
# ID                                                                                 EV40247
# VIN (1-10)                                                                      JN1AZ0CP8B
# County                                                                              Skagit
# City                                                                            BELLINGHAM
# State                                                                                   WA
# ZIP Code                                                                           98229.0
# Model Year                                                                          2011.0
# Make                                                                                NISSAN
# Model                                                                                 LEAF
# Electric Vehicle Type                                       Battery Electric Vehicle (BEV)
# Clean Alternative Fuel Vehicle (CAFV) Eligibility  Clean Alternative Fuel Vehicle Eligible
# Electric Range                                                                          73
# Base MSRP                                                                                0
# Legislative District                                                                  40.0
# DOL Vehicle ID                                                                   137375528
# Vehicle Location                                             POINT (-122.414936 48.709388)
# Electric Utility                                                    PUGET SOUND ENERGY INC
# Expected Price ($1k)                                                                  15.0
# Longitude                                                                      -122.414936
# Latitude                                                                         48.709388

# %%
data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].unique()
# Out:
# array(['Clean Alternative Fuel Vehicle Eligible',
#        'Not eligible due to low battery range',
#        'Eligibility unknown as battery range has not been researched'],
#       dtype=object)

# %%
cafv = {'Clean Alternative Fuel Vehicle Eligible':0, 'Not eligible due to low battery range': 1, 'Eligibility unknown as battery range has not been researched': 2}
data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] = data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].map(cafv)
data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].unique()
# Out:
# array([0, 1, 2])

# %%
data['Electric Vehicle Type'].unique()
# Out:
# array(['Battery Electric Vehicle (BEV)',
#        'Plug-in Hybrid Electric Vehicle (PHEV)'], dtype=object)

# %%
evt = {'Battery Electric Vehicle (BEV)':0, 'Plug-in Hybrid Electric Vehicle (PHEV)':1}

data['Electric Vehicle Type'] = data['Electric Vehicle Type'].map(evt)

data['Electric Vehicle Type'].unique()
# Out:
# array([0, 1])

# %%
data['Electric Utility'].unique()
# Out:
# array(['PUGET SOUND ENERGY INC',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PENINSULA LIGHT COMPANY',
#        'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||ELMHURST MUTUAL POWER & LIGHT CO|PENINSULA LIGHT COMPANY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)',
#        'MODERN ELECTRIC WATER COMPANY',
#        'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PARKLAND LIGHT & WATER COMPANY|PENINSULA LIGHT COMPANY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF KLICKITAT COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD 1 OF SNOHOMISH COUNTY',
#        'PUD NO 1 OF DOUGLAS COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||PUGET SOUND ENERGY INC||PUD NO 1 OF JEFFERSON COUNTY',
#        'PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||LAKEVIEW LIGHT & POWER|PENINSULA LIGHT COMPANY',
#        'BONNEVILLE POWER ADMINISTRATION||AVISTA CORP||INLAND POWER & LIGHT COMPANY',
#        'BONNEVILLE POWER ADMINISTRATION||ORCAS POWER & LIGHT COOP',
#        'AVISTA CORP', 'PUD NO 2 OF GRANT COUNTY',
#        'PUD NO 1 OF WHATCOM COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF BENTON COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF COWLITZ COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF CENTRALIA - (WA)|CITY OF TACOMA - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF KITTITAS COUNTY',
#        'PUD NO 1 OF CHELAN COUNTY',
#        'CITY OF TACOMA - (WA)||TANNER ELECTRIC COOP',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PUD NO 1 OF LEWIS COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PUD NO 3 OF MASON COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF FRANKLIN COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||AVISTA CORP||BIG BEND ELECTRIC COOP, INC',
#        'BONNEVILLE POWER ADMINISTRATION||COLUMBIA RURAL ELEC ASSN, INC',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF RICHLAND - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF PORT ANGELES - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLALLAM COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF PACIFIC COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||AVISTA CORP||PUD NO 1 OF ASOTIN COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||TOWN OF RUSTON - (WA)|CITY OF TACOMA - (WA)||PENINSULA LIGHT COMPANY',
#        'CITY OF BLAINE - (WA)||PUD NO 1 OF WHATCOM COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||INLAND POWER & LIGHT COMPANY',
#        'BONNEVILLE POWER ADMINISTRATION||BENTON RURAL ELECTRIC ASSN',
#        'BONNEVILLE POWER ADMINISTRATION||VERA IRRIGATION DISTRICT #15',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF ELLENSBURG - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF FERRY COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF SKAMANIA CO',
#        'PUD NO 1 OF OKANOGAN COUNTY', 'OKANOGAN COUNTY ELEC COOP, INC',
#        'BONNEVILLE POWER ADMINISTRATION||TOWN OF STEILACOOM|CITY OF TACOMA - (WA)||PENINSULA LIGHT COMPANY',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||OHOP MUTUAL LIGHT COMPANY, INC|PENINSULA LIGHT COMPANY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLALLAM COUNTY|PUD NO 1 OF JEFFERSON COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF GRAYS HARBOR COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PUD NO 1 OF MASON COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF MILTON - (WA)|CITY OF TACOMA - (WA)',
#        'PUD NO 1 OF PEND OREILLE COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||TOWN OF EATONVILLE - (WA)|CITY OF TACOMA - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF MASON COUNTY|PUD NO 1 OF JEFFERSON COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||BENTON RURAL ELECTRIC ASSN|PENINSULA LIGHT COMPANY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF WAHKIAKUM COUNTY',
#        'CITY OF CHENEY - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF MCCLEARY - (WA)',
#        'CITY OF SUMAS - (WA)||PUD NO 1 OF WHATCOM COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||BIG BEND ELECTRIC COOP, INC',
#        'CITY OF CHEWELAH', 'CITY OF TACOMA - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF COULEE DAM - (WA)',
#        'PORTLAND GENERAL ELECTRIC CO',
#        'AVISTA CORP||INLAND POWER & LIGHT COMPANY',
#        'CITY OF SEATTLE - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF ASOTIN COUNTY||INLAND POWER & LIGHT COMPANY'],
#       dtype=object)

# %% [markdown]
# Replace the Electric Utility with the number of options each record has. This is seperated by || characters and the count represents the number of options each record has

# %%
data['Electric Utility'] = data['Electric Utility'].str.split("\|\|").apply(len)
data.head(2)
# Out:
#         ID  VIN (1-10)     County        City State  ZIP Code  Model Year  \
# 0  EV33174  5YJ3E1EC6L  Snohomish    LYNNWOOD    WA   98037.0      2020.0
# 1  EV40247  JN1AZ0CP8B     Skagit  BELLINGHAM    WA   98229.0      2011.0
#
#      Make    Model  Electric Vehicle Type  \
# 0   TESLA  MODEL 3                      0
# 1  NISSAN     LEAF                      0
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                                                  0             308
# 1                                                  0              73
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  32.0       109821694
# 1          0                  40.0       137375528
#
#                 Vehicle Location  Electric Utility  Expected Price ($1k)  \
# 0   POINT (-122.287614 47.83874)                 1                  50.0
# 1  POINT (-122.414936 48.709388)                 1                  15.0
#
#      Longitude   Latitude
# 0  -122.287614   47.83874
# 1  -122.414936  48.709388

# %%
c_count = dict(data.City.value_counts())

cities = {}

# Iterate through the city_data dictionary
for city, value in c_count.items():
  if value >=500:
    range_key = (value // 500) * 500
  else:
    range_key = 'Below 500'

    # Add the city to the corresponding range
  if range_key not in cities:
        cities[range_key] = []

  cities[range_key].append(city)

# %%
# cities.keys()
def map_city(city):
    for k, v in cities.items():
        if city in v:
            return city_key[k]
    return city_key['Below 500']


city_key = {11000: 0, 3000: 1, 2000: 2, 1500: 3, 1000:4, 500:5, 'Below 500':6}

data['City'] = data['City'].apply(map_city)

data.head()
# Out:
#         ID  VIN (1-10)     County  City State  ZIP Code  Model Year  \
# 0  EV33174  5YJ3E1EC6L  Snohomish     5    WA   98037.0      2020.0
# 1  EV40247  JN1AZ0CP8B     Skagit     4    WA   98229.0      2011.0
# 2  EV12248  WBY1Z2C56F     Pierce     4    WA   98422.0      2015.0
# 3  EV55713  1G1RD6E44D       King     2    WA   98053.0      2013.0
# 4  EV28799  1G1FY6S05K     Pierce     5    WA   98375.0      2019.0
#
#         Make    Model  Electric Vehicle Type  \
# 0      TESLA  MODEL 3                      0
# 1     NISSAN     LEAF                      0
# 2        BMW       I3                      0
# 3  CHEVROLET     VOLT                      1
# 4  CHEVROLET  BOLT EV                      0
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                                                  0             308
# 1                                                  0              73
# 2                                                  0              81
# 3                                                  0              38
# 4                                                  0             238
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  32.0       109821694
# 1          0                  40.0       137375528
# 2          0                  27.0       150627382
# 3          0                  45.0       258766301
# 4          0                  25.0       296998138
#
#                 Vehicle Location  Electric Utility  Expected Price ($1k)  \
# 0   POINT (-122.287614 47.83874)                 1                 50.00
# 1  POINT (-122.414936 48.709388)                 1                 15.00
# 2  POINT (-122.396286 47.293138)                 3                 18.00
# 3  POINT (-122.024951 47.670286)                 2                 33.90
# 4  POINT (-122.321062 47.103797)                 3                 41.78
#
#      Longitude   Latitude
# 0  -122.287614   47.83874
# 1  -122.414936  48.709388
# 2  -122.396286  47.293138
# 3  -122.024951  47.670286
# 4  -122.321062  47.103797

# %%
data.drop(data[data['Model'] == '$16.36K'].index, inplace = True)
data[data['Model'] == '$16.36K']
# Out:
# Empty DataFrame
# Columns: [ID, VIN (1-10), County, City, State, ZIP Code, Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID, Vehicle Location, Electric Utility, Expected Price ($1k), Longitude, Latitude]
# Index: []

# %%
le = LabelEncoder()


data['Make'] = le.fit_transform(data['Make'])
data['Model'] = le.fit_transform(data['Model'])

# %%
data['Longitude'] = pd.to_numeric(data['Longitude'], errors='coerce')
data['Latitude'] = pd.to_numeric(data['Latitude'], errors='coerce')

data.head()
# Out:
#         ID  VIN (1-10)     County  City State  ZIP Code  Model Year  Make  \
# 0  EV33174  5YJ3E1EC6L  Snohomish     5    WA   98037.0      2020.0    28
# 1  EV40247  JN1AZ0CP8B     Skagit     4    WA   98229.0      2011.0    22
# 2  EV12248  WBY1Z2C56F     Pierce     4    WA   98422.0      2015.0     3
# 3  EV55713  1G1RD6E44D       King     2    WA   98053.0      2013.0     5
# 4  EV28799  1G1FY6S05K     Pierce     5    WA   98375.0      2019.0     5
#
#    Model  Electric Vehicle Type  \
# 0     56                      0
# 1     52                      0
# 2     44                      0
# 3     95                      1
# 4     14                      0
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                                                  0             308
# 1                                                  0              73
# 2                                                  0              81
# 3                                                  0              38
# 4                                                  0             238
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  32.0       109821694
# 1          0                  40.0       137375528
# 2          0                  27.0       150627382
# 3          0                  45.0       258766301
# 4          0                  25.0       296998138
#
#                 Vehicle Location  Electric Utility  Expected Price ($1k)  \
# 0   POINT (-122.287614 47.83874)                 1                 50.00
# 1  POINT (-122.414936 48.709388)                 1                 15.00
# 2  POINT (-122.396286 47.293138)                 3                 18.00
# 3  POINT (-122.024951 47.670286)                 2                 33.90
# 4  POINT (-122.321062 47.103797)                 3                 41.78
#
#     Longitude   Latitude
# 0 -122.287614  47.838740
# 1 -122.414936  48.709388
# 2 -122.396286  47.293138
# 3 -122.024951  47.670286
# 4 -122.321062  47.103797

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63673 entries, 0 to 64352
# Data columns (total 20 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   ID                                                 63673 non-null  object
#  1   VIN (1-10)                                         63673 non-null  object
#  2   County                                             63673 non-null  object
#  3   City                                               63673 non-null  int64
#  4   State                                              63673 non-null  object
#  5   ZIP Code                                           63673 non-null  float64
#  6   Model Year                                         63672 non-null  float64
#  7   Make                                               63673 non-null  int64
#  8   Model                                              63673 non-null  int64
#  9   Electric Vehicle Type                              63673 non-null  int64
#  10  Clean Alternative Fuel Vehicle (CAFV) Eligibility  63673 non-null  int64
#  11  Electric Range                                     63673 non-null  int64
#  12  Base MSRP                                          63673 non-null  int64
#  13  Legislative District                               63673 non-null  float64
#  14  DOL Vehicle ID                                     63673 non-null  int64
#  15  Vehicle Location                                   63673 non-null  object
#  16  Electric Utility                                   63673 non-null  int64
#  17  Expected Price ($1k)                               63673 non-null  float64
#  18  Longitude                                          63673 non-null  float64
#  19  Latitude                                           63673 non-null  float64
# dtypes: float64(6), int64(9), object(5)
# memory usage: 10.2+ MB

# %%
data[data['Model Year'].isna()]
# Out:
#           ID  VIN (1-10)     County  City State  ZIP Code  Model Year  Make  \
# 54860  EV249  WAUTPBFF2G  Snohomish     5    WA   98026.0         NaN     0
#
#        Model  Electric Vehicle Type  \
# 54860      7                      1
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 54860                                                  1              16
#
#        Base MSRP  Legislative District  DOL Vehicle ID  \
# 54860          0                  21.0       165842008
#
#                     Vehicle Location  Electric Utility  Expected Price ($1k)  \
# 54860  POINT (-122.333046 47.829439)                 1                 18.86
#
#         Longitude   Latitude
# 54860 -122.333046  47.829439

# %%
data.loc[(data['County'] =='Snohomish') & (data['City'] == 5) & (data['Make'] == 0) & (data['Model'] == 7)]['Model Year'].mode()
# Out:
# 0    2017.0
# Name: Model Year, dtype: float64

# %%
data['Model Year'].fillna(2017)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63673 entries, 0 to 64352
# Data columns (total 20 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   ID                                                 63673 non-null  object
#  1   VIN (1-10)                                         63673 non-null  object
#  2   County                                             63673 non-null  object
#  3   City                                               63673 non-null  int64
#  4   State                                              63673 non-null  object
#  5   ZIP Code                                           63673 non-null  float64
#  6   Model Year                                         63672 non-null  float64
#  7   Make                                               63673 non-null  int64
#  8   Model                                              63673 non-null  int64
#  9   Electric Vehicle Type                              63673 non-null  int64
#  10  Clean Alternative Fuel Vehicle (CAFV) Eligibility  63673 non-null  int64
#  11  Electric Range                                     63673 non-null  int64
#  12  Base MSRP                                          63673 non-null  int64
#  13  Legislative District                               63673 non-null  float64
#  14  DOL Vehicle ID                                     63673 non-null  int64
#  15  Vehicle Location                                   63673 non-null  object
#  16  Electric Utility                                   63673 non-null  int64
#  17  Expected Price ($1k)                               63673 non-null  float64
#  18  Longitude                                          63673 non-null  float64
#  19  Latitude                                           63673 non-null  float64
# dtypes: float64(6), int64(9), object(5)
# memory usage: 10.2+ MB

# %%
data.dropna()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63673 entries, 0 to 64352
# Data columns (total 20 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   ID                                                 63673 non-null  object
#  1   VIN (1-10)                                         63673 non-null  object
#  2   County                                             63673 non-null  object
#  3   City                                               63673 non-null  int64
#  4   State                                              63673 non-null  object
#  5   ZIP Code                                           63673 non-null  float64
#  6   Model Year                                         63672 non-null  float64
#  7   Make                                               63673 non-null  int64
#  8   Model                                              63673 non-null  int64
#  9   Electric Vehicle Type                              63673 non-null  int64
#  10  Clean Alternative Fuel Vehicle (CAFV) Eligibility  63673 non-null  int64
#  11  Electric Range                                     63673 non-null  int64
#  12  Base MSRP                                          63673 non-null  int64
#  13  Legislative District                               63673 non-null  float64
#  14  DOL Vehicle ID                                     63673 non-null  int64
#  15  Vehicle Location                                   63673 non-null  object
#  16  Electric Utility                                   63673 non-null  int64
#  17  Expected Price ($1k)                               63673 non-null  float64
#  18  Longitude                                          63673 non-null  float64
#  19  Latitude                                           63673 non-null  float64
# dtypes: float64(6), int64(9), object(5)
# memory usage: 10.2+ MB

# %%
data.drop(index=54860, inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63672 entries, 0 to 64352
# Data columns (total 20 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   ID                                                 63672 non-null  object
#  1   VIN (1-10)                                         63672 non-null  object
#  2   County                                             63672 non-null  object
#  3   City                                               63672 non-null  int64
#  4   State                                              63672 non-null  object
#  5   ZIP Code                                           63672 non-null  float64
#  6   Model Year                                         63672 non-null  float64
#  7   Make                                               63672 non-null  int64
#  8   Model                                              63672 non-null  int64
#  9   Electric Vehicle Type                              63672 non-null  int64
#  10  Clean Alternative Fuel Vehicle (CAFV) Eligibility  63672 non-null  int64
#  11  Electric Range                                     63672 non-null  int64
#  12  Base MSRP                                          63672 non-null  int64
#  13  Legislative District                               63672 non-null  float64
#  14  DOL Vehicle ID                                     63672 non-null  int64
#  15  Vehicle Location                                   63672 non-null  object
#  16  Electric Utility                                   63672 non-null  int64
#  17  Expected Price ($1k)                               63672 non-null  float64
#  18  Longitude                                          63672 non-null  float64
#  19  Latitude                                           63672 non-null  float64
# dtypes: float64(6), int64(9), object(5)
# memory usage: 10.2+ MB

# %% [markdown]
# Finally, Clean data!!!

# %%
data.columns
# Out:
# Index(['ID', 'VIN (1-10)', 'County', 'City', 'State', 'ZIP Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', 'Expected Price ($1k)',
#        'Longitude', 'Latitude'],
#       dtype='object')

# %%
# Select your target variable and the features

x = data.drop(['ID', 'VIN (1-10)', 'County', 'State', 'ZIP Code', 'DOL Vehicle ID', 'Vehicle Location', 'Expected Price ($1k)'], axis=1)
y = data['Expected Price ($1k)']

# %%
x.head()
# Out:
#    City  Model Year  Make  Model  Electric Vehicle Type  \
# 0     5      2020.0    28     56                      0
# 1     4      2011.0    22     52                      0
# 2     4      2015.0     3     44                      0
# 3     2      2013.0     5     95                      1
# 4     5      2019.0     5     14                      0
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                                                  0             308
# 1                                                  0              73
# 2                                                  0              81
# 3                                                  0              38
# 4                                                  0             238
#
#    Base MSRP  Legislative District  Electric Utility   Longitude   Latitude
# 0          0                  32.0                 1 -122.287614  47.838740
# 1          0                  40.0                 1 -122.414936  48.709388
# 2          0                  27.0                 3 -122.396286  47.293138
# 3          0                  45.0                 2 -122.024951  47.670286
# 4          0                  25.0                 3 -122.321062  47.103797

# %%
y.head()
# Out:
# 0    50.00
# 1    15.00
# 2    18.00
# 3    33.90
# 4    41.78
# Name: Expected Price ($1k), dtype: float64

# %%
# Split your dataset to training and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44570 entries, 47095 to 22590
# Data columns (total 12 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   City                                               44570 non-null  int64
#  1   Model Year                                         44570 non-null  float64
#  2   Make                                               44570 non-null  int64
#  3   Model                                              44570 non-null  int64
#  4   Electric Vehicle Type                              44570 non-null  int64
#  5   Clean Alternative Fuel Vehicle (CAFV) Eligibility  44570 non-null  int64
#  6   Electric Range                                     44570 non-null  int64
#  7   Base MSRP                                          44570 non-null  int64
#  8   Legislative District                               44570 non-null  float64
#  9   Electric Utility                                   44570 non-null  int64
#  10  Longitude                                          44570 non-null  float64
#  11  Latitude                                           44570 non-null  float64
# dtypes: float64(4), int64(8)
# memory usage: 4.4 MB

# %%
# Build and train an SVM model on the training set
model = svm.SVR()

model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
# Assess your model performance on the test set using relevant evaluation metrics
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print('r2: ', r2)
print('mae: ', mae)
print('mse: ', mse)
# Out:
# r2:  0.044134282834088046
# mae:  19.802475798497976
# mse:  626.3987432244543

# %%
# Discuss with your cohort alternative ways to improve your model performance
model = svm.SVR(kernel="poly", C=100, gamma="auto", degree=3)

model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print('r2: ', r2)
print('mae: ', mae)
print('mse: ', mse)

# %%
model
# Out:
# SVR()

# %%
# yr_2022 = data[data['Model Year'] == 2022.0]
# yr_2022.head()

# %%
# yr_2022_ford = data.loc[(data['Electric Vehicle Type'] == 'Plug-in Hybrid Electric Vehicle (PHEV)') & (data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] == 'Clean Alternative Fuel Vehicle Eligible') &
#                              (data['Make'] == 'FORD')]

# yr_2022_ford.head()

# %%
# yr_2022_ford = yr_2022_ford[yr_2022_ford['Expected Price ($1k)'] != 'N/']
# yr_2022_ford['Expected Price ($1k)'] = yr_2022_ford['Expected Price ($1k)'].astype(int)
# yr_2022_ford['Expected Price ($1k)'].mean()

# %%
# yr_2022 = data[data['Model Year'] == 2022.0]
# yr_2022_ford = data.loc[(data['Electric Vehicle Type'] == 'Plug-in Hybrid Electric Vehicle (PHEV)') & (data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] == 'Clean Alternative Fuel Vehicle Eligible') &
#                              (data['Make'] == 'FORD')]
# yr_2022_ford = yr_2022_ford[yr_2022_ford['Expected Price ($1k)'] != 'N/']
# yr_2022_ford['Expected Price ($1k)'] = yr_2022_ford['Expected Price ($1k)'].astype(int)
# yr_2022_ford['Expected Price ($1k)'].mean()
