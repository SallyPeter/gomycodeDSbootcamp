# %% [markdown]
# <a href="https://colab.research.google.com/github/SallyPeter/gomycodeDSbootcamp/blob/main/ML/API_to_Pandas_Dataframe_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **What You're Aiming For**
#
# In this checkpoint, we are going to practice consuming public APIs through the [NASA public APIs portal](https://api.nasa.gov/).
#
# **Portal description:** The objective of this portal is to make NASA data, including imagery, eminently accessible to application developers and data professionals. Before starting to use its APIs endpoints, it's mandatory that you generate your API KEY and store it somewhere for later use. The API key acts as the user identifier when requesting the API. To get your KEY, fill in the provided form with your personal information, and then we shall receive an email containing your personal API KEY.
#
# ➡️ [NASA API PORTAL](https://api.nasa.gov/)
#
# https://i.imgur.com/hisTmpk.png
#
#
#
#
# ## **Instructions**
#
# - Go to the NASA API portal and generate your API KEY
# - Import the requests package and store your API KEY in variable
# - Go back to portal website and click on 'browse APIs'
# - Click on the first dropdown menu, named 'APOD' and read its documentation
# - Follow the provided documentation to ask the API endpoint for the astronomy picture of the day. Get then display the image on your notebook.
# - Go through the list of the provided API endpoints once again and select 'Astronomy Picture of the Day' option. Store the results in a pandas dataframe
# - Do the necessary data pre-processing tasks on the previous result in order to get a clean dataframe with the following columns :
#   - Asteroid ID
#   - Asteroid name
#   - The Minimal estimated diameter in Kilometre
#   - Absolute_magnitude
#   - Relative_velocity(km/s)
# - Try to export the new dataframe into a CSV file and share it with your colleagues

# %%
import requests as re

# %%
url = 'https://api.nasa.gov/'
response = re.get(url)
response.status_code
# Out:
# 200

# %%
response
# Out:
# <Response [200]>

# %%
# Go to the NASA API portal and generate your API KEY
api_key = '4vDWEVIkDM3sLyklrCXpC1HrWdnOM*********'

# %%
# Import the requests package and store your API KEY in variable
# done in the above cell

# %%
# Go back to portal website and click on 'browse APIs'
# Click on the first dropdown menu, named 'APOD' and read its documentation
# Follow the provided documentation to ask the API endpoint for the astronomy picture of the day. Get then display the image on your notebook.


url = 'https://api.nasa.gov/planetary/apod'
response_api = re.get(''.join([url, f"?api_key={api_key}"]))
response_api.status_code
# Out:
# 200

# %%
response_api.json()
# Out:
# {'copyright': 'Patrick Winkler',
#  'date': '2024-10-24',
#  'explanation': "A mere seven hundred light years from Earth toward the constellation Aquarius, a star is dying. The once sun-like star's last few thousand years have produced the Helix Nebula. Also known as NGC 7293, the cosmic Helix is a well studied and nearby example of a Planetary Nebula, typical of this final phase of stellar evolution.  Combining narrow band data from emission lines of hydrogen atoms in red and oxygen atoms in blue-green hues, this deep image shows tantalizing details of the Helix, including its bright inner region about 3 light-years across. The white dot at the Helix's center is this Planetary Nebula's hot, dying central star. A simple looking nebula at first glance, the Helix is now understood to have a surprisingly complex geometry.",
#  'hdurl': 'https://apod.nasa.gov/apod/image/2410/NGC7293_preview.png',
#  'media_type': 'image',
#  'service_version': 'v1',
#  'title': 'NGC 7293: The Helix Nebula',
#  'url': 'https://apod.nasa.gov/apod/image/2410/NGC7293_preview1024.png'}

# %%
from IPython.display import Image, display

# %%
response_api.json()['url']
# Out:
# 'https://apod.nasa.gov/apod/image/2410/NGC7293_preview1024.png'

# %%
display(Image(url= response_api.json()['url'], width=400, height=250))
# Out:
# <img src="https://apod.nasa.gov/apod/image/2410/NGC7293_preview1024.png" width="400" height="250"/>

# %%
# Go through the list of the provided API endpoints once again and select 'Astronomy Picture of the Day' option. Store the results in a pandas dataframe
# My understanding of this is to fetch a number of days and store them in a df

start_date = "2024-10-01"
end_date = "2024-10-24"

response_api = re.get(''.join([url, "?api_key={}&start_date={}&end_date={}".format(api_key, start_date, end_date)]))
response_api.status_code
# Out:
# 200

# %%
import pandas as pd

# %%
apod_df = pd.DataFrame(response_api.json())
apod_df.head()
# Out:
#          date                                        explanation media_type  \
# 0  2024-10-01  How far can black hole jets extend? A new reco...      video
# 1  2024-10-02  It is the largest satellite galaxy of our home...      image
# 2  2024-10-03  The second solar eclipse of 2024 began in the ...      image
# 3  2024-10-04  Comet C/2023 A3 (Tsuchinshan–ATLAS) is growing...      image
# 4  2024-10-05  While hunting for comets in the skies above 18...      image
#
#   service_version                                          title  \
# 0              v1  Porphyrion: The Longest Known Black Hole Jets
# 1              v1              The Large Magellanic Cloud Galaxy
# 2              v1                             Eclipse at Sunrise
# 3              v1                              Comet at Moonrise
# 4              v1                               M27: Not a Comet
#
#                                                  url  \
# 0    https://www.youtube.com/embed/ExGvwNuKyMc?rel=0
# 1  https://apod.nasa.gov/apod/image/2410/LMC_Nowa...
# 2  https://apod.nasa.gov/apod/image/2410/earliest...
# 3  https://apod.nasa.gov/apod/image/2410/zaparoll...
# 4  https://apod.nasa.gov/apod/image/2410/m27_RGB_...
#
#                                            copyright  \
# 0                                                NaN
# 1  \nIreneusz Nowak;  \nText: Natalia Lewandowska...
# 2                                        Wang Letian
# 3                                  Gabriel Zaparolli
# 4               Francesco Sferlazza, Franco Sgueglia
#
#                                                hdurl
# 0                                                NaN
# 1  https://apod.nasa.gov/apod/image/2410/LMC_Nowa...
# 2  https://apod.nasa.gov/apod/image/2410/earliest...
# 3  https://apod.nasa.gov/apod/image/2410/zaparoll...
# 4  https://apod.nasa.gov/apod/image/2410/m27_RGB_...

# %%
response_api.json()[1]
# Out:
# {'copyright': '\nIreneusz Nowak;  \nText: Natalia Lewandowska \n(SUNY Oswego)\n',
#  'date': '2024-10-02',
#  'explanation': "It is the largest satellite galaxy of our home Milky Way Galaxy. If you live in the south, the Large Magellanic Cloud (LMC) is quite noticeable, spanning about 10 degrees across the night sky, which is 20 times larger than the full moon towards the southern constellation of the dolphinfish (Dorado). Being only about 160,000 light years away, many details of the LMC's structure can be seen, such as its central bar and its single spiral arm. The LMC harbors numerous stellar nurseries where new stars are being born, which appear in pink in the featured image. It is home to the Tarantula Nebula, the currently most active star forming region in the entire Local Group, a small collection of nearby galaxies dominated by the massive Andromeda and Milky Way galaxies. Studies of the LMC and the Small Magellanic Cloud (SMC) by Henrietta Swan Leavitt led to the discovery of the period-luminosity relationship of Cepheid variable stars that are used to measure distances across the nearby universe.   Survey: Color Blindness and Astronomical Images",
#  'hdurl': 'https://apod.nasa.gov/apod/image/2410/LMC_Nowak_2160.jpg',
#  'media_type': 'image',
#  'service_version': 'v1',
#  'title': 'The Large Magellanic Cloud Galaxy',
#  'url': 'https://apod.nasa.gov/apod/image/2410/LMC_Nowak_1080.jpg'}

# %%
# Do the necessary data pre-processing tasks on the previous result in order to get a clean dataframe with the following columns :
# Asteroid ID
# Asteroid name
# The Minimal estimated diameter in Kilometre
# Absolute_magnitude
# Relative_velocity(km/s)

asteroid_url = "https://api.nasa.gov/neo/rest/v1/feed"
start_date = "2024-10-18"
end_date = "2024-10-24"

asteroid_api = re.get("{}?api_key={}&start_date={}&end_date={}".format(asteroid_url, api_key,  start_date, end_date)) # the asteroid API has a limit of 7 days

asteroid_api.status_code
# Out:
# 200

# %%
asteroid_api.json()[ 'near_earth_objects']
# Out:
# {'2024-10-20': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2412977?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '2412977',
#    'neo_reference_id': '2412977',
#    'name': '412977 (1990 UO)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2412977',
#    'absolute_magnitude_h': 19.57,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3240074354,
#      'estimated_diameter_max': 0.7245026508},
#     'meters': {'estimated_diameter_min': 324.0074353942,
#      'estimated_diameter_max': 724.5026507569},
#     'miles': {'estimated_diameter_min': 0.2013288241,
#      'estimated_diameter_max': 0.4501849366},
#     'feet': {'estimated_diameter_min': 1063.0165543388,
#      'estimated_diameter_max': 2376.9772767092}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 10:19',
#      'epoch_date_close_approach': 1729419540000,
#      'relative_velocity': {'kilometers_per_second': '41.1627077851',
#       'kilometers_per_hour': '148185.7480262956',
#       'miles_per_hour': '92076.8610444501'},
#      'miss_distance': {'astronomical': '0.4671664393',
#       'lunar': '181.7277448877',
#       'kilometers': '69887104.254764291',
#       'miles': '43425832.9012815758'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2495615?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '2495615',
#    'neo_reference_id': '2495615',
#    'name': '495615 (2015 PQ291)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2495615',
#    'absolute_magnitude_h': 17.7,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.7665755735,
#      'estimated_diameter_max': 1.7141150923},
#     'meters': {'estimated_diameter_min': 766.5755735311,
#      'estimated_diameter_max': 1714.1150923063},
#     'miles': {'estimated_diameter_min': 0.4763278307,
#      'estimated_diameter_max': 1.065101409},
#     'feet': {'estimated_diameter_min': 2515.0118046636,
#      'estimated_diameter_max': 5623.7373594423}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 02:46',
#      'epoch_date_close_approach': 1729392360000,
#      'relative_velocity': {'kilometers_per_second': '22.8658455755',
#       'kilometers_per_hour': '82317.0440716297',
#       'miles_per_hour': '51148.6099677301'},
#      'miss_distance': {'astronomical': '0.3502323914',
#       'lunar': '136.2404002546',
#       'kilometers': '52394019.758446318',
#       'miles': '32556134.2298944684'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2526742?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '2526742',
#    'neo_reference_id': '2526742',
#    'name': '526742 (2006 WR127)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2526742',
#    'absolute_magnitude_h': 20.49,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2121069879,
#      'estimated_diameter_max': 0.4742856434},
#     'meters': {'estimated_diameter_min': 212.1069878758,
#      'estimated_diameter_max': 474.2856433931},
#     'miles': {'estimated_diameter_min': 0.1317971312,
#      'estimated_diameter_max': 0.2947073445},
#     'feet': {'estimated_diameter_min': 695.8890901025,
#      'estimated_diameter_max': 1556.0553102697}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 17:36',
#      'epoch_date_close_approach': 1729445760000,
#      'relative_velocity': {'kilometers_per_second': '14.8481835153',
#       'kilometers_per_hour': '53453.4606550249',
#       'miles_per_hour': '33213.9017053403'},
#      'miss_distance': {'astronomical': '0.2754597714',
#       'lunar': '107.1538510746',
#       'kilometers': '41208195.072126918',
#       'miles': '25605585.0710627484'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3694787?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '3694787',
#    'neo_reference_id': '3694787',
#    'name': '(2014 US115)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3694787',
#    'absolute_magnitude_h': 24.6,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0319561887,
#      'estimated_diameter_max': 0.0714562102},
#     'meters': {'estimated_diameter_min': 31.9561886721,
#      'estimated_diameter_max': 71.4562101727},
#     'miles': {'estimated_diameter_min': 0.0198566489,
#      'estimated_diameter_max': 0.0444008168},
#     'feet': {'estimated_diameter_min': 104.8431420431,
#      'estimated_diameter_max': 234.436392583}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 04:15',
#      'epoch_date_close_approach': 1729397700000,
#      'relative_velocity': {'kilometers_per_second': '19.1626339588',
#       'kilometers_per_hour': '68985.4822516714',
#       'miles_per_hour': '42864.8959024344'},
#      'miss_distance': {'astronomical': '0.3832701874',
#       'lunar': '149.0921028986',
#       'kilometers': '57336403.669540838',
#       'miles': '35627189.1855380444'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3719472?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '3719472',
#    'neo_reference_id': '3719472',
#    'name': '(2015 KG19)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3719472',
#    'absolute_magnitude_h': 23.39,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0557898221,
#      'estimated_diameter_max': 0.1247498347},
#     'meters': {'estimated_diameter_min': 55.7898221067,
#      'estimated_diameter_max': 124.7498346832},
#     'miles': {'estimated_diameter_min': 0.0346661776,
#      'estimated_diameter_max': 0.0775159295},
#     'feet': {'estimated_diameter_min': 183.0374799606,
#      'estimated_diameter_max': 409.2842476221}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 09:27',
#      'epoch_date_close_approach': 1729416420000,
#      'relative_velocity': {'kilometers_per_second': '7.6123070871',
#       'kilometers_per_hour': '27404.305513672',
#       'miles_per_hour': '17027.9697232036'},
#      'miss_distance': {'astronomical': '0.2265469633',
#       'lunar': '88.1267687237',
#       'kilometers': '33890943.164648171',
#       'miles': '21058855.5704039198'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3753370?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '3753370',
#    'neo_reference_id': '3753370',
#    'name': '(2016 JT33)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3753370',
#    'absolute_magnitude_h': 23.6,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0506471459,
#      'estimated_diameter_max': 0.1132504611},
#     'meters': {'estimated_diameter_min': 50.6471458835,
#      'estimated_diameter_max': 113.2504610618},
#     'miles': {'estimated_diameter_min': 0.0314706677,
#      'estimated_diameter_max': 0.0703705522},
#     'feet': {'estimated_diameter_min': 166.1651821003,
#      'estimated_diameter_max': 371.5566426699}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 09:28',
#      'epoch_date_close_approach': 1729416480000,
#      'relative_velocity': {'kilometers_per_second': '20.8083092387',
#       'kilometers_per_hour': '74909.9132592034',
#       'miles_per_hour': '46546.1069359756'},
#      'miss_distance': {'astronomical': '0.4216894681',
#       'lunar': '164.0372030909',
#       'kilometers': '63083846.229192947',
#       'miles': '39198484.3889467886'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3785780?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '3785780',
#    'neo_reference_id': '3785780',
#    'name': '(2017 TV4)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3785780',
#    'absolute_magnitude_h': 19.01,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.4193290755,
#      'estimated_diameter_max': 0.9376483177},
#     'meters': {'estimated_diameter_min': 419.3290754861,
#      'estimated_diameter_max': 937.648317729},
#     'miles': {'estimated_diameter_min': 0.260558927,
#      'estimated_diameter_max': 0.5826274728},
#     'feet': {'estimated_diameter_min': 1375.7516040178,
#      'estimated_diameter_max': 3076.2741067381}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 07:37',
#      'epoch_date_close_approach': 1729409820000,
#      'relative_velocity': {'kilometers_per_second': '24.4491247759',
#       'kilometers_per_hour': '88016.8491933235',
#       'miles_per_hour': '54690.2472112626'},
#      'miss_distance': {'astronomical': '0.3371198126',
#       'lunar': '131.1396071014',
#       'kilometers': '50432405.899759162',
#       'miles': '31337243.8988019556'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3841535?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '3841535',
#    'neo_reference_id': '3841535',
#    'name': '(2019 HS)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3841535',
#    'absolute_magnitude_h': 27.2,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0096506147,
#      'estimated_diameter_max': 0.0215794305},
#     'meters': {'estimated_diameter_min': 9.6506146958,
#      'estimated_diameter_max': 21.5794304844},
#     'miles': {'estimated_diameter_min': 0.0059966121,
#      'estimated_diameter_max': 0.0134088323},
#     'feet': {'estimated_diameter_min': 31.6621227185,
#      'estimated_diameter_max': 70.7986587106}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 14:53',
#      'epoch_date_close_approach': 1729435980000,
#      'relative_velocity': {'kilometers_per_second': '14.7005634795',
#       'kilometers_per_hour': '52922.0285262839',
#       'miles_per_hour': '32883.6904473457'},
#      'miss_distance': {'astronomical': '0.4021934881',
#       'lunar': '156.4532668709',
#       'kilometers': '60167289.147630347',
#       'miles': '37386219.8542869086'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54134398?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54134398',
#    'neo_reference_id': '54134398',
#    'name': '(2021 GJ)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54134398',
#    'absolute_magnitude_h': 25.84,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0180532326,
#      'estimated_diameter_max': 0.0403682552},
#     'meters': {'estimated_diameter_min': 18.053232555,
#      'estimated_diameter_max': 40.3682552065},
#     'miles': {'estimated_diameter_min': 0.0112177552,
#      'estimated_diameter_max': 0.0250836631},
#     'feet': {'estimated_diameter_min': 59.2297674956,
#      'estimated_diameter_max': 132.4417864117}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 08:27',
#      'epoch_date_close_approach': 1729412820000,
#      'relative_velocity': {'kilometers_per_second': '17.0227179004',
#       'kilometers_per_hour': '61281.7844413975',
#       'miles_per_hour': '38078.1176713784'},
#      'miss_distance': {'astronomical': '0.3227737944',
#       'lunar': '125.5590060216',
#       'kilometers': '48286272.134057928',
#       'miles': '30003698.2141302864'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54394003?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54394003',
#    'neo_reference_id': '54394003',
#    'name': '(2023 TX19)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54394003',
#    'absolute_magnitude_h': 25.51,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0210162379,
#      'estimated_diameter_max': 0.0469937366},
#     'meters': {'estimated_diameter_min': 21.0162379322,
#      'estimated_diameter_max': 46.9937366478},
#     'miles': {'estimated_diameter_min': 0.0130588808,
#      'estimated_diameter_max': 0.0292005451},
#     'feet': {'estimated_diameter_min': 68.9509140576,
#      'estimated_diameter_max': 154.1789309435}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 07:25',
#      'epoch_date_close_approach': 1729409100000,
#      'relative_velocity': {'kilometers_per_second': '23.1047165143',
#       'kilometers_per_hour': '83176.9794516355',
#       'miles_per_hour': '51682.9403709343'},
#      'miss_distance': {'astronomical': '0.3023014999',
#       'lunar': '117.5952834611',
#       'kilometers': '45223660.482845213',
#       'miles': '28100679.5782134194'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54454238?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54454238',
#    'neo_reference_id': '54454238',
#    'name': '(2024 MB1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54454238',
#    'absolute_magnitude_h': 27.23,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0095182033,
#      'estimated_diameter_max': 0.0212833496},
#     'meters': {'estimated_diameter_min': 9.5182032982,
#      'estimated_diameter_max': 21.2833495984},
#     'miles': {'estimated_diameter_min': 0.0059143355,
#      'estimated_diameter_max': 0.0132248562},
#     'feet': {'estimated_diameter_min': 31.2277021088,
#      'estimated_diameter_max': 69.8272646965}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 03:29',
#      'epoch_date_close_approach': 1729394940000,
#      'relative_velocity': {'kilometers_per_second': '3.8517001288',
#       'kilometers_per_hour': '13866.1204636198',
#       'miles_per_hour': '8615.8680180753'},
#      'miss_distance': {'astronomical': '0.205885944',
#       'lunar': '80.089632216',
#       'kilometers': '30800098.68533928',
#       'miles': '19138293.868590864'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': True,
#    'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54454238?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54468797?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54468797',
#    'neo_reference_id': '54468797',
#    'name': '(2024 RB5)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54468797',
#    'absolute_magnitude_h': 22.38,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0888290416,
#      'estimated_diameter_max': 0.1986277755},
#     'meters': {'estimated_diameter_min': 88.8290416389,
#      'estimated_diameter_max': 198.6277754808},
#     'miles': {'estimated_diameter_min': 0.0551957904,
#      'estimated_diameter_max': 0.1234215395},
#     'feet': {'estimated_diameter_min': 291.4338729707,
#      'estimated_diameter_max': 651.6659509085}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 05:41',
#      'epoch_date_close_approach': 1729402860000,
#      'relative_velocity': {'kilometers_per_second': '5.3294067115',
#       'kilometers_per_hour': '19185.8641613708',
#       'miles_per_hour': '11921.3498729362'},
#      'miss_distance': {'astronomical': '0.2004585638',
#       'lunar': '77.9783813182',
#       'kilometers': '29988174.167739106',
#       'miles': '18633787.3676314228'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54481741?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54481741',
#    'neo_reference_id': '54481741',
#    'name': '(2024 SH1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54481741',
#    'absolute_magnitude_h': 26.84,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0113908197,
#      'estimated_diameter_max': 0.0254706471},
#     'meters': {'estimated_diameter_min': 11.3908196722,
#      'estimated_diameter_max': 25.4706471064},
#     'miles': {'estimated_diameter_min': 0.007077925,
#      'estimated_diameter_max': 0.0158267215},
#     'feet': {'estimated_diameter_min': 37.3714568132,
#      'estimated_diameter_max': 83.5651178526}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 18:15',
#      'epoch_date_close_approach': 1729448100000,
#      'relative_velocity': {'kilometers_per_second': '2.6746352379',
#       'kilometers_per_hour': '9628.6868565576',
#       'miles_per_hour': '5982.8915637316'},
#      'miss_distance': {'astronomical': '0.0164049026',
#       'lunar': '6.3815071114',
#       'kilometers': '2454138.486517462',
#       'miles': '1524930.9435344956'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54485961?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54485961',
#    'neo_reference_id': '54485961',
#    'name': '(2024 SC8)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54485961',
#    'absolute_magnitude_h': 25.86,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0178877195,
#      'estimated_diameter_max': 0.0399981568},
#     'meters': {'estimated_diameter_min': 17.887719524,
#      'estimated_diameter_max': 39.9981568182},
#     'miles': {'estimated_diameter_min': 0.0111149102,
#      'estimated_diameter_max': 0.0248536947},
#     'feet': {'estimated_diameter_min': 58.6867457232,
#      'estimated_diameter_max': 131.2275528154}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 05:46',
#      'epoch_date_close_approach': 1729403160000,
#      'relative_velocity': {'kilometers_per_second': '3.6942966806',
#       'kilometers_per_hour': '13299.4680502881',
#       'miles_per_hour': '8263.7722449137'},
#      'miss_distance': {'astronomical': '0.0629380342',
#       'lunar': '24.4828953038',
#       'kilometers': '9415395.858307154',
#       'miles': '5850455.6971165652'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54494151?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54494151',
#    'neo_reference_id': '54494151',
#    'name': '(2024 UE)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54494151',
#    'absolute_magnitude_h': 26.401,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0139429598,
#      'estimated_diameter_max': 0.031177406},
#     'meters': {'estimated_diameter_min': 13.9429598444,
#      'estimated_diameter_max': 31.1774060197},
#     'miles': {'estimated_diameter_min': 0.0086637509,
#      'estimated_diameter_max': 0.019372736},
#     'feet': {'estimated_diameter_min': 45.744620376,
#      'estimated_diameter_max': 102.2880807657}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 22:53',
#      'epoch_date_close_approach': 1729464780000,
#      'relative_velocity': {'kilometers_per_second': '21.9780840558',
#       'kilometers_per_hour': '79121.1026008534',
#       'miles_per_hour': '49162.7762244025'},
#      'miss_distance': {'astronomical': '0.0062682632',
#       'lunar': '2.4383543848',
#       'kilometers': '937718.823319384',
#       'miles': '582671.4579761392'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54494256?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54494256',
#    'neo_reference_id': '54494256',
#    'name': '(2024 UN)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54494256',
#    'absolute_magnitude_h': 26.553,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.013000348,
#      'estimated_diameter_max': 0.0290696618},
#     'meters': {'estimated_diameter_min': 13.0003479619,
#      'estimated_diameter_max': 29.0696617739},
#     'miles': {'estimated_diameter_min': 0.0080780392,
#      'estimated_diameter_max': 0.0180630448},
#     'feet': {'estimated_diameter_min': 42.6520616072,
#      'estimated_diameter_max': 95.3729091343}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 14:58',
#      'epoch_date_close_approach': 1729436280000,
#      'relative_velocity': {'kilometers_per_second': '14.1013238982',
#       'kilometers_per_hour': '50764.7660333425',
#       'miles_per_hour': '31543.2514277733'},
#      'miss_distance': {'astronomical': '0.0062938463',
#       'lunar': '2.4483062107',
#       'kilometers': '941546.000587381',
#       'miles': '585049.5556566178'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': True,
#    'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54494256?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}],
#  '2024-10-18': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2483547?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '2483547',
#    'neo_reference_id': '2483547',
#    'name': '483547 (2003 WM25)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2483547',
#    'absolute_magnitude_h': 17.65,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.7844314124,
#      'estimated_diameter_max': 1.7540419619},
#     'meters': {'estimated_diameter_min': 784.4314124479,
#      'estimated_diameter_max': 1754.0419619197},
#     'miles': {'estimated_diameter_min': 0.4874229312,
#      'estimated_diameter_max': 1.0899108079},
#     'feet': {'estimated_diameter_min': 2573.5939552157,
#      'estimated_diameter_max': 5754.7310303447}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 20:50',
#      'epoch_date_close_approach': 1729284600000,
#      'relative_velocity': {'kilometers_per_second': '9.3986936436',
#       'kilometers_per_hour': '33835.2971167893',
#       'miles_per_hour': '21023.9378112627'},
#      'miss_distance': {'astronomical': '0.2423446388',
#       'lunar': '94.2720644932',
#       'kilometers': '36254241.770399356',
#       'miles': '22527341.2294328728'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3137843?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '3137843',
#    'neo_reference_id': '3137843',
#    'name': '(2002 RD27)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3137843',
#    'absolute_magnitude_h': 18.14,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.6259720997,
#      'estimated_diameter_max': 1.3997161669},
#     'meters': {'estimated_diameter_min': 625.9720996596,
#      'estimated_diameter_max': 1399.716166857},
#     'miles': {'estimated_diameter_min': 0.3889609095,
#      'estimated_diameter_max': 0.8697430343},
#     'feet': {'estimated_diameter_min': 2053.7143034471,
#      'estimated_diameter_max': 4592.2447888713}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 05:54',
#      'epoch_date_close_approach': 1729230840000,
#      'relative_velocity': {'kilometers_per_second': '12.6975398503',
#       'kilometers_per_hour': '45711.1434609508',
#       'miles_per_hour': '28403.1268910558'},
#      'miss_distance': {'astronomical': '0.466144442',
#       'lunar': '181.330187938',
#       'kilometers': '69734215.63553854',
#       'miles': '43330832.318530252'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3145497?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '3145497',
#    'neo_reference_id': '3145497',
#    'name': '(2002 YO2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3145497',
#    'absolute_magnitude_h': 22.7,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0766575574,
#      'estimated_diameter_max': 0.1714115092},
#     'meters': {'estimated_diameter_min': 76.6575573531,
#      'estimated_diameter_max': 171.4115092306},
#     'miles': {'estimated_diameter_min': 0.0476327831,
#      'estimated_diameter_max': 0.1065101409},
#     'feet': {'estimated_diameter_min': 251.5011804664,
#      'estimated_diameter_max': 562.3737359442}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 18:09',
#      'epoch_date_close_approach': 1729274940000,
#      'relative_velocity': {'kilometers_per_second': '4.4510357534',
#       'kilometers_per_hour': '16023.7287122918',
#       'miles_per_hour': '9956.5218768126'},
#      'miss_distance': {'astronomical': '0.4614589274',
#       'lunar': '179.5075227586',
#       'kilometers': '69033272.631524638',
#       'miles': '42895286.5323624844'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3529626?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '3529626',
#    'neo_reference_id': '3529626',
#    'name': '(2010 MA)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3529626',
#    'absolute_magnitude_h': 25.7,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0192555078,
#      'estimated_diameter_max': 0.0430566244},
#     'meters': {'estimated_diameter_min': 19.2555078188,
#      'estimated_diameter_max': 43.0566244241},
#     'miles': {'estimated_diameter_min': 0.0119648141,
#      'estimated_diameter_max': 0.0267541378},
#     'feet': {'estimated_diameter_min': 63.1742402722,
#      'estimated_diameter_max': 141.2618956756}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 21:59',
#      'epoch_date_close_approach': 1729288740000,
#      'relative_velocity': {'kilometers_per_second': '8.5877838298',
#       'kilometers_per_hour': '30916.0217873705',
#       'miles_per_hour': '19210.0136489359'},
#      'miss_distance': {'astronomical': '0.3083990408',
#       'lunar': '119.9672268712',
#       'kilometers': '46135839.613723096',
#       'miles': '28667481.4071908848'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3761647?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '3761647',
#    'neo_reference_id': '3761647',
#    'name': '(2016 UY35)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3761647',
#    'absolute_magnitude_h': 24.7,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0305179233,
#      'estimated_diameter_max': 0.0682401509},
#     'meters': {'estimated_diameter_min': 30.5179232594,
#      'estimated_diameter_max': 68.2401509401},
#     'miles': {'estimated_diameter_min': 0.0189629525,
#      'estimated_diameter_max': 0.0424024508},
#     'feet': {'estimated_diameter_min': 100.1244233463,
#      'estimated_diameter_max': 223.8850168104}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 19:25',
#      'epoch_date_close_approach': 1729279500000,
#      'relative_velocity': {'kilometers_per_second': '18.0779724934',
#       'kilometers_per_hour': '65080.70097628',
#       'miles_per_hour': '40438.6166705113'},
#      'miss_distance': {'astronomical': '0.388914732',
#       'lunar': '151.287830748',
#       'kilometers': '58180815.51882084',
#       'miles': '36151882.378333992'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54016334?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54016334',
#    'neo_reference_id': '54016334',
#    'name': '(2020 FV3)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54016334',
#    'absolute_magnitude_h': 27.7,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0076657557,
#      'estimated_diameter_max': 0.0171411509},
#     'meters': {'estimated_diameter_min': 7.6657557353,
#      'estimated_diameter_max': 17.1411509231},
#     'miles': {'estimated_diameter_min': 0.0047632783,
#      'estimated_diameter_max': 0.0106510141},
#     'feet': {'estimated_diameter_min': 25.1501180466,
#      'estimated_diameter_max': 56.2373735944}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 02:36',
#      'epoch_date_close_approach': 1729218960000,
#      'relative_velocity': {'kilometers_per_second': '17.4745586299',
#       'kilometers_per_hour': '62908.4110676954',
#       'miles_per_hour': '39088.8401992578'},
#      'miss_distance': {'astronomical': '0.3951498466',
#       'lunar': '153.7132903274',
#       'kilometers': '59113575.382186742',
#       'miles': '36731472.4814793596'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54051583?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54051583',
#    'neo_reference_id': '54051583',
#    'name': '(2020 QP6)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54051583',
#    'absolute_magnitude_h': 20.73,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1899131235,
#      'estimated_diameter_max': 0.4246586539},
#     'meters': {'estimated_diameter_min': 189.9131234709,
#      'estimated_diameter_max': 424.6586539002},
#     'miles': {'estimated_diameter_min': 0.1180065074,
#      'estimated_diameter_max': 0.2638705724},
#     'feet': {'estimated_diameter_min': 623.0745720082,
#      'estimated_diameter_max': 1393.2370980619}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 12:02',
#      'epoch_date_close_approach': 1729252920000,
#      'relative_velocity': {'kilometers_per_second': '9.1153088486',
#       'kilometers_per_hour': '32815.1118550544',
#       'miles_per_hour': '20390.034363492'},
#      'miss_distance': {'astronomical': '0.2111664912',
#       'lunar': '82.1437650768',
#       'kilometers': '31590057.298893744',
#       'miles': '19629151.3896879072'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54055117?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54055117',
#    'neo_reference_id': '54055117',
#    'name': '(2020 TN3)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54055117',
#    'absolute_magnitude_h': 24.2,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0384197891,
#      'estimated_diameter_max': 0.0859092601},
#     'meters': {'estimated_diameter_min': 38.4197891064,
#      'estimated_diameter_max': 85.9092601232},
#     'miles': {'estimated_diameter_min': 0.0238729428,
#      'estimated_diameter_max': 0.0533815229},
#     'feet': {'estimated_diameter_min': 126.0491808919,
#      'estimated_diameter_max': 281.8545369825}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 23:34',
#      'epoch_date_close_approach': 1729294440000,
#      'relative_velocity': {'kilometers_per_second': '18.9916021102',
#       'kilometers_per_hour': '68369.7675966044',
#       'miles_per_hour': '42482.3147602346'},
#      'miss_distance': {'astronomical': '0.1866409181',
#       'lunar': '72.6033171409',
#       'kilometers': '27921083.802604447',
#       'miles': '17349356.9745654886'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54316690?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54316690',
#    'neo_reference_id': '54316690',
#    'name': '(2022 UO)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54316690',
#    'absolute_magnitude_h': 26.53,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0131387781,
#      'estimated_diameter_max': 0.0293792009},
#     'meters': {'estimated_diameter_min': 13.1387780601,
#      'estimated_diameter_max': 29.3792008837},
#     'miles': {'estimated_diameter_min': 0.0081640557,
#      'estimated_diameter_max': 0.0182553834},
#     'feet': {'estimated_diameter_min': 43.1062286107,
#      'estimated_diameter_max': 96.3884574272}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 21:59',
#      'epoch_date_close_approach': 1729288740000,
#      'relative_velocity': {'kilometers_per_second': '16.29423043',
#       'kilometers_per_hour': '58659.2295480436',
#       'miles_per_hour': '36448.5640488941'},
#      'miss_distance': {'astronomical': '0.3065798839',
#       'lunar': '119.2595748371',
#       'kilometers': '45863697.616287293',
#       'miles': '28498380.2113109234'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54320707?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54320707',
#    'neo_reference_id': '54320707',
#    'name': '(2022 UO10)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54320707',
#    'absolute_magnitude_h': 26.76,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0118182991,
#      'estimated_diameter_max': 0.0264265201},
#     'meters': {'estimated_diameter_min': 11.8182990893,
#      'estimated_diameter_max': 26.4265201422},
#     'miles': {'estimated_diameter_min': 0.0073435483,
#      'estimated_diameter_max': 0.0164206732},
#     'feet': {'estimated_diameter_min': 38.7739483842,
#      'estimated_diameter_max': 86.7011843432}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 21:56',
#      'epoch_date_close_approach': 1729288560000,
#      'relative_velocity': {'kilometers_per_second': '10.3025532627',
#       'kilometers_per_hour': '37089.191745598',
#       'miles_per_hour': '23045.7813932578'},
#      'miss_distance': {'astronomical': '0.0522513469',
#       'lunar': '20.3257739441',
#       'kilometers': '7816690.200871103',
#       'miles': '4857066.0656751014'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54347994?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54347994',
#    'neo_reference_id': '54347994',
#    'name': '(2023 EN2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54347994',
#    'absolute_magnitude_h': 23.12,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0631764148,
#      'estimated_diameter_max': 0.1412667581},
#     'meters': {'estimated_diameter_min': 63.1764148185,
#      'estimated_diameter_max': 141.2667581089},
#     'miles': {'estimated_diameter_min': 0.0392559921,
#      'estimated_diameter_max': 0.0877790668},
#     'feet': {'estimated_diameter_min': 207.2717087931,
#      'estimated_diameter_max': 463.4736306739}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 13:57',
#      'epoch_date_close_approach': 1729259820000,
#      'relative_velocity': {'kilometers_per_second': '23.4907483903',
#       'kilometers_per_hour': '84566.6942049158',
#       'miles_per_hour': '52546.4550741601'},
#      'miss_distance': {'astronomical': '0.4623701184',
#       'lunar': '179.8619760576',
#       'kilometers': '69169584.864287808',
#       'miles': '42979987.0261874304'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54445848?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54445848',
#    'neo_reference_id': '54445848',
#    'name': '(2024 LE1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54445848',
#    'absolute_magnitude_h': 26.31,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0145396843,
#      'estimated_diameter_max': 0.0325117225},
#     'meters': {'estimated_diameter_min': 14.5396842937,
#      'estimated_diameter_max': 32.5117224521},
#     'miles': {'estimated_diameter_min': 0.0090345382,
#      'estimated_diameter_max': 0.0202018415},
#     'feet': {'estimated_diameter_min': 47.7023778182,
#      'estimated_diameter_max': 106.6657594899}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 10:04',
#      'epoch_date_close_approach': 1729245840000,
#      'relative_velocity': {'kilometers_per_second': '7.7794602138',
#       'kilometers_per_hour': '28006.0567697649',
#       'miles_per_hour': '17401.874552302'},
#      'miss_distance': {'astronomical': '0.3314508579',
#       'lunar': '128.9343837231',
#       'kilometers': '49584342.351512673',
#       'miles': '30810281.6454859674'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54482434?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54482434',
#    'neo_reference_id': '54482434',
#    'name': '(2024 RV50)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54482434',
#    'absolute_magnitude_h': 20.97,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1700415193,
#      'estimated_diameter_max': 0.3802243961},
#     'meters': {'estimated_diameter_min': 170.0415192713,
#      'estimated_diameter_max': 380.2243960879},
#     'miles': {'estimated_diameter_min': 0.1056588689,
#      'estimated_diameter_max': 0.2362604132},
#     'feet': {'estimated_diameter_min': 557.879018086,
#      'estimated_diameter_max': 1247.4554076612}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 17:02',
#      'epoch_date_close_approach': 1729270920000,
#      'relative_velocity': {'kilometers_per_second': '15.5740330005',
#       'kilometers_per_hour': '56066.5188018022',
#       'miles_per_hour': '34837.5544188198'},
#      'miss_distance': {'astronomical': '0.0495817849',
#       'lunar': '19.2873143261',
#       'kilometers': '7417329.411838163',
#       'miles': '4608914.7782981294'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54487286?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54487286',
#    'neo_reference_id': '54487286',
#    'name': '(2024 TX2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54487286',
#    'absolute_magnitude_h': 23.82,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0457672667,
#      'estimated_diameter_max': 0.1023387195},
#     'meters': {'estimated_diameter_min': 45.7672667231,
#      'estimated_diameter_max': 102.3387195373},
#     'miles': {'estimated_diameter_min': 0.0284384523,
#      'estimated_diameter_max': 0.0635903125},
#     'feet': {'estimated_diameter_min': 150.1550793559,
#      'estimated_diameter_max': 335.7569646067}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 03:16',
#      'epoch_date_close_approach': 1729221360000,
#      'relative_velocity': {'kilometers_per_second': '13.529856677',
#       'kilometers_per_hour': '48707.4840371428',
#       'miles_per_hour': '30264.9364007457'},
#      'miss_distance': {'astronomical': '0.0762628543',
#       'lunar': '29.6662503227',
#       'kilometers': '11408760.563400341',
#       'miles': '7089075.0893170658'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54487954?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54487954',
#    'neo_reference_id': '54487954',
#    'name': '(2024 TN4)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54487954',
#    'absolute_magnitude_h': 22.57,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0813869881,
#      'estimated_diameter_max': 0.1819868378},
#     'meters': {'estimated_diameter_min': 81.3869880675,
#      'estimated_diameter_max': 181.9868378029},
#     'miles': {'estimated_diameter_min': 0.0505715142,
#      'estimated_diameter_max': 0.1130813434},
#     'feet': {'estimated_diameter_min': 267.0176859314,
#      'estimated_diameter_max': 597.0696969372}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 15:04',
#      'epoch_date_close_approach': 1729263840000,
#      'relative_velocity': {'kilometers_per_second': '11.9292301322',
#       'kilometers_per_hour': '42945.2284758631',
#       'miles_per_hour': '26684.4948826828'},
#      'miss_distance': {'astronomical': '0.2847790422',
#       'lunar': '110.7790474158',
#       'kilometers': '42602338.133760114',
#       'miles': '26471865.3996090132'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54489676?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54489676',
#    'neo_reference_id': '54489676',
#    'name': '(2024 TX8)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54489676',
#    'absolute_magnitude_h': 24.23,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0378926498,
#      'estimated_diameter_max': 0.0847305409},
#     'meters': {'estimated_diameter_min': 37.8926498379,
#      'estimated_diameter_max': 84.7305408852},
#     'miles': {'estimated_diameter_min': 0.0235453937,
#      'estimated_diameter_max': 0.0526491009},
#     'feet': {'estimated_diameter_min': 124.3197212943,
#      'estimated_diameter_max': 277.9873477579}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 18:01',
#      'epoch_date_close_approach': 1729274460000,
#      'relative_velocity': {'kilometers_per_second': '12.545700091',
#       'kilometers_per_hour': '45164.5203276457',
#       'miles_per_hour': '28063.4765335863'},
#      'miss_distance': {'astronomical': '0.0946360851',
#       'lunar': '36.8134371039',
#       'kilometers': '14157356.756098737',
#       'miles': '8796973.5671550906'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54490132?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54490132',
#    'neo_reference_id': '54490132',
#    'name': '(2024 TT9)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54490132',
#    'absolute_magnitude_h': 24.2,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0384197891,
#      'estimated_diameter_max': 0.0859092601},
#     'meters': {'estimated_diameter_min': 38.4197891064,
#      'estimated_diameter_max': 85.9092601232},
#     'miles': {'estimated_diameter_min': 0.0238729428,
#      'estimated_diameter_max': 0.0533815229},
#     'feet': {'estimated_diameter_min': 126.0491808919,
#      'estimated_diameter_max': 281.8545369825}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 07:04',
#      'epoch_date_close_approach': 1729235040000,
#      'relative_velocity': {'kilometers_per_second': '14.6824105786',
#       'kilometers_per_hour': '52856.6780829204',
#       'miles_per_hour': '32843.0842232457'},
#      'miss_distance': {'astronomical': '0.0649841378',
#       'lunar': '25.2788296042',
#       'kilometers': '9721488.598666486',
#       'miles': '6040652.9064140668'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54494098?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54494098',
#    'neo_reference_id': '54494098',
#    'name': '(2024 TB22)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54494098',
#    'absolute_magnitude_h': 19.339,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3603752665,
#      'estimated_diameter_max': 0.8058235934},
#     'meters': {'estimated_diameter_min': 360.3752665386,
#      'estimated_diameter_max': 805.82359339},
#     'miles': {'estimated_diameter_min': 0.2239267397,
#      'estimated_diameter_max': 0.500715412},
#     'feet': {'estimated_diameter_min': 1182.3335894706,
#      'estimated_diameter_max': 2643.7782781376}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 01:51',
#      'epoch_date_close_approach': 1729216260000,
#      'relative_velocity': {'kilometers_per_second': '21.9619650835',
#       'kilometers_per_hour': '79063.0743007336',
#       'miles_per_hour': '49126.7196953641'},
#      'miss_distance': {'astronomical': '0.0762762142',
#       'lunar': '29.6714473238',
#       'kilometers': '11410759.175983754',
#       'miles': '7090316.9695896452'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54494481?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54494481',
#    'neo_reference_id': '54494481',
#    'name': '(2024 UB1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54494481',
#    'absolute_magnitude_h': 28.437,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0054595265,
#      'estimated_diameter_max': 0.0122078723},
#     'meters': {'estimated_diameter_min': 5.459526478,
#      'estimated_diameter_max': 12.2078723298},
#     'miles': {'estimated_diameter_min': 0.0033923914,
#      'estimated_diameter_max': 0.0075856178},
#     'feet': {'estimated_diameter_min': 17.9118328502,
#      'estimated_diameter_max': 40.0520758546}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 05:14',
#      'epoch_date_close_approach': 1729228440000,
#      'relative_velocity': {'kilometers_per_second': '8.0060966917',
#       'kilometers_per_hour': '28821.9480901613',
#       'miles_per_hour': '17908.8376896894'},
#      'miss_distance': {'astronomical': '0.0024898845',
#       'lunar': '0.9685650705',
#       'kilometers': '372481.417746015',
#       'miles': '231449.220544407'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': True,
# ...
#     'meters': {'estimated_diameter_min': 37.8926498379,
#      'estimated_diameter_max': 84.7305408852},
#     'miles': {'estimated_diameter_min': 0.0235453937,
#      'estimated_diameter_max': 0.0526491009},
#     'feet': {'estimated_diameter_min': 124.3197212943,
#      'estimated_diameter_max': 277.9873477579}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 07:17',
#      'epoch_date_close_approach': 1729581420000,
#      'relative_velocity': {'kilometers_per_second': '9.6750353984',
#       'kilometers_per_hour': '34830.1274343933',
#       'miles_per_hour': '21642.0866827762'},
#      'miss_distance': {'astronomical': '0.095304915',
#       'lunar': '37.073611935',
#       'kilometers': '14257412.28453105',
#       'miles': '8859145.18958649'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54248639?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54248639',
#    'neo_reference_id': '54248639',
#    'name': '(2022 DA4)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54248639',
#    'absolute_magnitude_h': 23.62,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0501828101,
#      'estimated_diameter_max': 0.1122121746},
#     'meters': {'estimated_diameter_min': 50.182810059,
#      'estimated_diameter_max': 112.2121745938},
#     'miles': {'estimated_diameter_min': 0.0311821429,
#      'estimated_diameter_max': 0.0697253911},
#     'feet': {'estimated_diameter_min': 164.6417705539,
#      'estimated_diameter_max': 368.1501908944}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 01:54',
#      'epoch_date_close_approach': 1729562040000,
#      'relative_velocity': {'kilometers_per_second': '20.0188562619',
#       'kilometers_per_hour': '72067.8825430117',
#       'miles_per_hour': '44780.1795723508'},
#      'miss_distance': {'astronomical': '0.4367091909',
#       'lunar': '169.8798752601',
#       'kilometers': '65330764.768063383',
#       'miles': '40594654.8277173654'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54279762?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54279762',
#    'neo_reference_id': '54279762',
#    'name': '(2022 KA)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54279762',
#    'absolute_magnitude_h': 25.15,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0248058993,
#      'estimated_diameter_max': 0.0554676771},
#     'meters': {'estimated_diameter_min': 24.8058993152,
#      'estimated_diameter_max': 55.4676771118},
#     'miles': {'estimated_diameter_min': 0.0154136665,
#      'estimated_diameter_max': 0.034466006},
#     'feet': {'estimated_diameter_min': 81.3841867092,
#      'estimated_diameter_max': 181.9805737754}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 04:15',
#      'epoch_date_close_approach': 1729570500000,
#      'relative_velocity': {'kilometers_per_second': '7.576107776',
#       'kilometers_per_hour': '27273.9879937278',
#       'miles_per_hour': '16946.9954842138'},
#      'miss_distance': {'astronomical': '0.2265747261',
#       'lunar': '88.1375684529',
#       'kilometers': '33895096.420393407',
#       'miles': '21061436.2838547366'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54340101?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54340101',
#    'neo_reference_id': '54340101',
#    'name': '(2023 BA4)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54340101',
#    'absolute_magnitude_h': 24.78,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0294140602,
#      'estimated_diameter_max': 0.0657718381},
#     'meters': {'estimated_diameter_min': 29.4140601781,
#      'estimated_diameter_max': 65.7718380526},
#     'miles': {'estimated_diameter_min': 0.018277044,
#      'estimated_diameter_max': 0.0408687128},
#     'feet': {'estimated_diameter_min': 96.5028251948,
#      'estimated_diameter_max': 215.7868771564}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 05:25',
#      'epoch_date_close_approach': 1729574700000,
#      'relative_velocity': {'kilometers_per_second': '11.2870116407',
#       'kilometers_per_hour': '40633.2419064232',
#       'miles_per_hour': '25247.9163390217'},
#      'miss_distance': {'astronomical': '0.4276145266',
#       'lunar': '166.3420508474',
#       'kilometers': '63970222.360418342',
#       'miles': '39749252.9774114396'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54439432?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54439432',
#    'neo_reference_id': '54439432',
#    'name': '(2024 JC1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54439432',
#    'absolute_magnitude_h': 25.1,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0253837029,
#      'estimated_diameter_max': 0.0567596853},
#     'meters': {'estimated_diameter_min': 25.3837029364,
#      'estimated_diameter_max': 56.7596852866},
#     'miles': {'estimated_diameter_min': 0.0157726969,
#      'estimated_diameter_max': 0.0352688224},
#     'feet': {'estimated_diameter_min': 83.279867942,
#      'estimated_diameter_max': 186.2194458756}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 17:18',
#      'epoch_date_close_approach': 1729617480000,
#      'relative_velocity': {'kilometers_per_second': '4.2551641015',
#       'kilometers_per_hour': '15318.5907654466',
#       'miles_per_hour': '9518.3765786743'},
#      'miss_distance': {'astronomical': '0.2200279263',
#       'lunar': '85.5908633307',
#       'kilometers': '32915709.114996981',
#       'miles': '20452873.2317250978'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54483151?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54483151',
#    'neo_reference_id': '54483151',
#    'name': '(2024 SO3)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54483151',
#    'absolute_magnitude_h': 21.99,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1063053145,
#      'estimated_diameter_max': 0.2377059096},
#     'meters': {'estimated_diameter_min': 106.3053144865,
#      'estimated_diameter_max': 237.7059095613},
#     'miles': {'estimated_diameter_min': 0.0660550396,
#      'estimated_diameter_max': 0.1477035587},
#     'feet': {'estimated_diameter_min': 348.7707279799,
#      'estimated_diameter_max': 779.8750563251}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 12:36',
#      'epoch_date_close_approach': 1729600560000,
#      'relative_velocity': {'kilometers_per_second': '10.3180818117',
#       'kilometers_per_hour': '37145.0945220577',
#       'miles_per_hour': '23080.517204553'},
#      'miss_distance': {'astronomical': '0.2804482707',
#       'lunar': '109.0943773023',
#       'kilometers': '41954463.941903409',
#       'miles': '26069295.0442246842'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54483861?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54483861',
#    'neo_reference_id': '54483861',
#    'name': '(2024 SE4)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54483861',
#    'absolute_magnitude_h': 27.72,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0075954757,
#      'estimated_diameter_max': 0.0169839999},
#     'meters': {'estimated_diameter_min': 7.5954756643,
#      'estimated_diameter_max': 16.9839999068},
#     'miles': {'estimated_diameter_min': 0.0047196083,
#      'estimated_diameter_max': 0.010553365},
#     'feet': {'estimated_diameter_min': 24.9195403784,
#      'estimated_diameter_max': 55.7217862542}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 17:16',
#      'epoch_date_close_approach': 1729617360000,
#      'relative_velocity': {'kilometers_per_second': '2.2164283877',
#       'kilometers_per_hour': '7979.1421958716',
#       'miles_per_hour': '4957.9286605403'},
#      'miss_distance': {'astronomical': '0.0177065839',
#       'lunar': '6.8878611371',
#       'kilometers': '2648867.236416293',
#       'miles': '1645929.7779311234'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54485966?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54485966',
#    'neo_reference_id': '54485966',
#    'name': '(2024 SM8)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54485966',
#    'absolute_magnitude_h': 24.78,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0294140602,
#      'estimated_diameter_max': 0.0657718381},
#     'meters': {'estimated_diameter_min': 29.4140601781,
#      'estimated_diameter_max': 65.7718380526},
#     'miles': {'estimated_diameter_min': 0.018277044,
#      'estimated_diameter_max': 0.0408687128},
#     'feet': {'estimated_diameter_min': 96.5028251948,
#      'estimated_diameter_max': 215.7868771564}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 16:40',
#      'epoch_date_close_approach': 1729615200000,
#      'relative_velocity': {'kilometers_per_second': '5.1020416329',
#       'kilometers_per_hour': '18367.3498785665',
#       'miles_per_hour': '11412.7569287126'},
#      'miss_distance': {'astronomical': '0.1262356504',
#       'lunar': '49.1056680056',
#       'kilometers': '18884584.417904648',
#       'miles': '11734336.6288662224'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54487941?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54487941',
#    'neo_reference_id': '54487941',
#    'name': '(2024 TQ3)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54487941',
#    'absolute_magnitude_h': 23.37,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.056306039,
#      'estimated_diameter_max': 0.1259041307},
#     'meters': {'estimated_diameter_min': 56.3060389749,
#      'estimated_diameter_max': 125.9041306916},
#     'miles': {'estimated_diameter_min': 0.0349869397,
#      'estimated_diameter_max': 0.0782331756},
#     'feet': {'estimated_diameter_min': 184.7311049104,
#      'estimated_diameter_max': 413.0713081384}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 00:34',
#      'epoch_date_close_approach': 1729557240000,
#      'relative_velocity': {'kilometers_per_second': '8.4878997567',
#       'kilometers_per_hour': '30556.439124071',
#       'miles_per_hour': '18986.5829657318'},
#      'miss_distance': {'astronomical': '0.1611183345',
#       'lunar': '62.6750321205',
#       'kilometers': '24102959.659147515',
#       'miles': '14976884.644825107'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54494254?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54494254',
#    'neo_reference_id': '54494254',
#    'name': '(2024 UL)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54494254',
#    'absolute_magnitude_h': 23.293,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0583384622,
#      'estimated_diameter_max': 0.1304487671},
#     'meters': {'estimated_diameter_min': 58.3384621542,
#      'estimated_diameter_max': 130.4487670795},
#     'miles': {'estimated_diameter_min': 0.0362498286,
#      'estimated_diameter_max': 0.0810570808},
#     'feet': {'estimated_diameter_min': 191.3991601739,
#      'estimated_diameter_max': 427.9815329851}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 07:10',
#      'epoch_date_close_approach': 1729581000000,
#      'relative_velocity': {'kilometers_per_second': '12.5206891473',
#       'kilometers_per_hour': '45074.4809303927',
#       'miles_per_hour': '28007.5295536654'},
#      'miss_distance': {'astronomical': '0.0853073317',
#       'lunar': '33.1845520313',
#       'kilometers': '12761795.117703479',
#       'miles': '7929811.7758828502'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54494470?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54494470',
#    'neo_reference_id': '54494470',
#    'name': '(2024 UR)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54494470',
#    'absolute_magnitude_h': 24.354,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0357894461,
#      'estimated_diameter_max': 0.0800276343},
#     'meters': {'estimated_diameter_min': 35.7894460653,
#      'estimated_diameter_max': 80.0276342792},
#     'miles': {'estimated_diameter_min': 0.0222385239,
#      'estimated_diameter_max': 0.0497268511},
#     'feet': {'estimated_diameter_min': 117.419446229,
#      'estimated_diameter_max': 262.5578636485}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 03:18',
#      'epoch_date_close_approach': 1729567080000,
#      'relative_velocity': {'kilometers_per_second': '16.3145387939',
#       'kilometers_per_hour': '58732.3396579061',
#       'miles_per_hour': '36493.9918279917'},
#      'miss_distance': {'astronomical': '0.014096281',
#       'lunar': '5.483453309',
#       'kilometers': '2108773.61252147',
#       'miles': '1310331.161957486'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54494471?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54494471',
#    'neo_reference_id': '54494471',
#    'name': '(2024 US)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54494471',
#    'absolute_magnitude_h': 27.969,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.006772593,
#      'estimated_diameter_max': 0.0151439783},
#     'meters': {'estimated_diameter_min': 6.7725929877,
#      'estimated_diameter_max': 15.1439783043},
#     'miles': {'estimated_diameter_min': 0.0042082929,
#      'estimated_diameter_max': 0.0094100289},
#     'feet': {'estimated_diameter_min': 22.2197939776,
#      'estimated_diameter_max': 49.68496978}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 01:08',
#      'epoch_date_close_approach': 1729559280000,
#      'relative_velocity': {'kilometers_per_second': '7.8250602009',
#       'kilometers_per_hour': '28170.2167233555',
#       'miles_per_hour': '17503.8771634649'},
#      'miss_distance': {'astronomical': '0.0024224001',
#       'lunar': '0.9423136389',
#       'kilometers': '362385.895247787',
#       'miles': '225176.1537499806'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': True,
#    'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54494471?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}]}

# %%
# [Asteroid ID, Asteroid name, The Minimal estimated diameter in Kilometre, Absolute_magnitude, Relative_velocity(km/s)]
asteroid_data = pd.DataFrame(columns=['date', 'id', 'name', 'est_diam_km', 'abs_mag', 'rel_vel(km/s)'])

for date in asteroid_api.json()['near_earth_objects']:         #['2024-10-20']
  for  asteroid in asteroid_api.json()['near_earth_objects'][date]:
    #print(asteroid)
    id = asteroid['id']
    name = asteroid['name']
    est_diam_km = asteroid['estimated_diameter']['kilometers']['estimated_diameter_min']
    abs_mag = asteroid['absolute_magnitude_h']
    rel_vel = asteroid['close_approach_data'][0]['relative_velocity']['kilometers_per_second']

    ast_dict = {'date': date, 'name':name, 'id':id, 'est_diam_km':est_diam_km, 'abs_mag':abs_mag, 'rel_vel(km/s)':rel_vel}
    asteroid_data = asteroid_data._append(ast_dict, ignore_index=True)


# asteroid_data = pd.DataFrame(asteroid_api.json()[ 'near_earth_objects'])
asteroid_data.head()
# Out:
# <ipython-input-32-61026bea0d33>:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   asteroid_data = asteroid_data._append(ast_dict, ignore_index=True)
#          date       id                 name  est_diam_km  abs_mag  \
# 0  2024-10-20  2412977     412977 (1990 UO)     0.324007    19.57
# 1  2024-10-20  2495615  495615 (2015 PQ291)     0.766576    17.70
# 2  2024-10-20  2526742  526742 (2006 WR127)     0.212107    20.49
# 3  2024-10-20  3694787         (2014 US115)     0.031956    24.60
# 4  2024-10-20  3719472          (2015 KG19)     0.055790    23.39
#
#    rel_vel(km/s)
# 0  41.1627077851
# 1  22.8658455755
# 2  14.8481835153
# 3  19.1626339588
# 4   7.6123070871

# %%
asteroid_data.date.unique()
# Out:
# array(['2024-10-20', '2024-10-18', '2024-10-19', '2024-10-23',
#        '2024-10-24', '2024-10-21', '2024-10-22'], dtype=object)

# %%
asteroid_data.shape
# Out:
# (136, 6)

# %%
# Try to export the new dataframe into a CSV file and share it with your colleagues

asteroid_data.to_csv("AsteroidDataOct18-Oct24.csv")

# %%
#Test Code




count = 1
for date in asteroid_api.json()['near_earth_objects']:         #['2024-10-20']
  print(date)
  for  asteroid in asteroid_api.json()['near_earth_objects'][date]:
    if count <=1:
      print(asteroid)
      print(asteroid['id'])
      print(asteroid['estimated_diameter']['kilometers']['estimated_diameter_min'])
      print(asteroid['absolute_magnitude_h'])
      print(asteroid['close_approach_data'][0]['relative_velocity']['kilometers_per_second'])
  count+=1
  break
# Out:
# 2024-10-20
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2412977?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}, 'id': '2412977', 'neo_reference_id': '2412977', 'name': '412977 (1990 UO)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2412977', 'absolute_magnitude_h': 19.57, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3240074354, 'estimated_diameter_max': 0.7245026508}, 'meters': {'estimated_diameter_min': 324.0074353942, 'estimated_diameter_max': 724.5026507569}, 'miles': {'estimated_diameter_min': 0.2013288241, 'estimated_diameter_max': 0.4501849366}, 'feet': {'estimated_diameter_min': 1063.0165543388, 'estimated_diameter_max': 2376.9772767092}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-10-20', 'close_approach_date_full': '2024-Oct-20 10:19', 'epoch_date_close_approach': 1729419540000, 'relative_velocity': {'kilometers_per_second': '41.1627077851', 'kilometers_per_hour': '148185.7480262956', 'miles_per_hour': '92076.8610444501'}, 'miss_distance': {'astronomical': '0.4671664393', 'lunar': '181.7277448877', 'kilometers': '69887104.254764291', 'miles': '43425832.9012815758'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}
# 2412977
# 0.3240074354
# 19.57
# 41.1627077851
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2495615?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}, 'id': '2495615', 'neo_reference_id': '2495615', 'name': '495615 (2015 PQ291)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2495615', 'absolute_magnitude_h': 17.7, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.7665755735, 'estimated_diameter_max': 1.7141150923}, 'meters': {'estimated_diameter_min': 766.5755735311, 'estimated_diameter_max': 1714.1150923063}, 'miles': {'estimated_diameter_min': 0.4763278307, 'estimated_diameter_max': 1.065101409}, 'feet': {'estimated_diameter_min': 2515.0118046636, 'estimated_diameter_max': 5623.7373594423}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-10-20', 'close_approach_date_full': '2024-Oct-20 02:46', 'epoch_date_close_approach': 1729392360000, 'relative_velocity': {'kilometers_per_second': '22.8658455755', 'kilometers_per_hour': '82317.0440716297', 'miles_per_hour': '51148.6099677301'}, 'miss_distance': {'astronomical': '0.3502323914', 'lunar': '136.2404002546', 'kilometers': '52394019.758446318', 'miles': '32556134.2298944684'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}
# 2495615
# 0.7665755735
# 17.7
# 22.8658455755
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2526742?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}, 'id': '2526742', 'neo_reference_id': '2526742', 'name': '526742 (2006 WR127)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2526742', 'absolute_magnitude_h': 20.49, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2121069879, 'estimated_diameter_max': 0.4742856434}, 'meters': {'estimated_diameter_min': 212.1069878758, 'estimated_diameter_max': 474.2856433931}, 'miles': {'estimated_diameter_min': 0.1317971312, 'estimated_diameter_max': 0.2947073445}, 'feet': {'estimated_diameter_min': 695.8890901025, 'estimated_diameter_max': 1556.0553102697}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-10-20', 'close_approach_date_full': '2024-Oct-20 17:36', 'epoch_date_close_approach': 1729445760000, 'relative_velocity': {'kilometers_per_second': '14.8481835153', 'kilometers_per_hour': '53453.4606550249', 'miles_per_hour': '33213.9017053403'}, 'miss_distance': {'astronomical': '0.2754597714', 'lunar': '107.1538510746', 'kilometers': '41208195.072126918', 'miles': '25605585.0710627484'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}
# 2526742
# 0.2121069879
# 20.49
# 14.8481835153
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3694787?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}, 'id': '3694787', 'neo_reference_id': '3694787', 'name': '(2014 US115)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3694787', 'absolute_magnitude_h': 24.6, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0319561887, 'estimated_diameter_max': 0.0714562102}, 'meters': {'estimated_diameter_min': 31.9561886721, 'estimated_diameter_max': 71.4562101727}, 'miles': {'estimated_diameter_min': 0.0198566489, 'estimated_diameter_max': 0.0444008168}, 'feet': {'estimated_diameter_min': 104.8431420431, 'estimated_diameter_max': 234.436392583}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-10-20', 'close_approach_date_full': '2024-Oct-20 04:15', 'epoch_date_close_approach': 1729397700000, 'relative_velocity': {'kilometers_per_second': '19.1626339588', 'kilometers_per_hour': '68985.4822516714', 'miles_per_hour': '42864.8959024344'}, 'miss_distance': {'astronomical': '0.3832701874', 'lunar': '149.0921028986', 'kilometers': '57336403.669540838', 'miles': '35627189.1855380444'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}
# 3694787
# 0.0319561887
# 24.6
# 19.1626339588
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3719472?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}, 'id': '3719472', 'neo_reference_id': '3719472', 'name': '(2015 KG19)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3719472', 'absolute_magnitude_h': 23.39, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0557898221, 'estimated_diameter_max': 0.1247498347}, 'meters': {'estimated_diameter_min': 55.7898221067, 'estimated_diameter_max': 124.7498346832}, 'miles': {'estimated_diameter_min': 0.0346661776, 'estimated_diameter_max': 0.0775159295}, 'feet': {'estimated_diameter_min': 183.0374799606, 'estimated_diameter_max': 409.2842476221}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-10-20', 'close_approach_date_full': '2024-Oct-20 09:27', 'epoch_date_close_approach': 1729416420000, 'relative_velocity': {'kilometers_per_second': '7.6123070871', 'kilometers_per_hour': '27404.305513672', 'miles_per_hour': '17027.9697232036'}, 'miss_distance': {'astronomical': '0.2265469633', 'lunar': '88.1267687237', 'kilometers': '33890943.164648171', 'miles': '21058855.5704039198'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}
# 3719472
# 0.0557898221
# 23.39
# 7.6123070871
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3753370?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}, 'id': '3753370', 'neo_reference_id': '3753370', 'name': '(2016 JT33)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3753370', 'absolute_magnitude_h': 23.6, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0506471459, 'estimated_diameter_max': 0.1132504611}, 'meters': {'estimated_diameter_min': 50.6471458835, 'estimated_diameter_max': 113.2504610618}, 'miles': {'estimated_diameter_min': 0.0314706677, 'estimated_diameter_max': 0.0703705522}, 'feet': {'estimated_diameter_min': 166.1651821003, 'estimated_diameter_max': 371.5566426699}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-10-20', 'close_approach_date_full': '2024-Oct-20 09:28', 'epoch_date_close_approach': 1729416480000, 'relative_velocity': {'kilometers_per_second': '20.8083092387', 'kilometers_per_hour': '74909.9132592034', 'miles_per_hour': '46546.1069359756'}, 'miss_distance': {'astronomical': '0.4216894681', 'lunar': '164.0372030909', 'kilometers': '63083846.229192947', 'miles': '39198484.3889467886'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}
# 3753370
# 0.0506471459
# 23.6
# 20.8083092387
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3785780?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}, 'id': '3785780', 'neo_reference_id': '3785780', 'name': '(2017 TV4)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3785780', 'absolute_magnitude_h': 19.01, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.4193290755, 'estimated_diameter_max': 0.9376483177}, 'meters': {'estimated_diameter_min': 419.3290754861, 'estimated_diameter_max': 937.648317729}, 'miles': {'estimated_diameter_min': 0.260558927, 'estimated_diameter_max': 0.5826274728}, 'feet': {'estimated_diameter_min': 1375.7516040178, 'estimated_diameter_max': 3076.2741067381}}, 'is_potentially_hazardous_asteroid': True, 'close_approach_data': [{'close_approach_date': '2024-10-20', 'close_approach_date_full': '2024-Oct-20 07:37', 'epoch_date_close_approach': 1729409820000, 'relative_velocity': {'kilometers_per_second': '24.4491247759', 'kilometers_per_hour': '88016.8491933235', 'miles_per_hour': '54690.2472112626'}, 'miss_distance': {'astronomical': '0.3371198126', 'lunar': '131.1396071014', 'kilometers': '50432405.899759162', 'miles': '31337243.8988019556'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}
# 3785780
# 0.4193290755
# 19.01
# 24.4491247759
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3841535?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}, 'id': '3841535', 'neo_reference_id': '3841535', 'name': '(2019 HS)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3841535', 'absolute_magnitude_h': 27.2, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0096506147, 'estimated_diameter_max': 0.0215794305}, 'meters': {'estimated_diameter_min': 9.6506146958, 'estimated_diameter_max': 21.5794304844}, 'miles': {'estimated_diameter_min': 0.0059966121, 'estimated_diameter_max': 0.0134088323}, 'feet': {'estimated_diameter_min': 31.6621227185, 'estimated_diameter_max': 70.7986587106}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-10-20', 'close_approach_date_full': '2024-Oct-20 14:53', 'epoch_date_close_approach': 1729435980000, 'relative_velocity': {'kilometers_per_second': '14.7005634795', 'kilometers_per_hour': '52922.0285262839', 'miles_per_hour': '32883.6904473457'}, 'miss_distance': {'astronomical': '0.4021934881', 'lunar': '156.4532668709', 'kilometers': '60167289.147630347', 'miles': '37386219.8542869086'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}
# 3841535
# 0.0096506147
# 27.2
# 14.7005634795
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54134398?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}, 'id': '54134398', 'neo_reference_id': '54134398', 'name': '(2021 GJ)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54134398', 'absolute_magnitude_h': 25.84, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0180532326, 'estimated_diameter_max': 0.0403682552}, 'meters': {'estimated_diameter_min': 18.053232555, 'estimated_diameter_max': 40.3682552065}, 'miles': {'estimated_diameter_min': 0.0112177552, 'estimated_diameter_max': 0.0250836631}, 'feet': {'estimated_diameter_min': 59.2297674956, 'estimated_diameter_max': 132.4417864117}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-10-20', 'close_approach_date_full': '2024-Oct-20 08:27', 'epoch_date_close_approach': 1729412820000, 'relative_velocity': {'kilometers_per_second': '17.0227179004', 'kilometers_per_hour': '61281.7844413975', 'miles_per_hour': '38078.1176713784'}, 'miss_distance': {'astronomical': '0.3227737944', 'lunar': '125.5590060216', 'kilometers': '48286272.134057928', 'miles': '30003698.2141302864'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}
# 54134398
# 0.0180532326
# 25.84
# 17.0227179004
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54394003?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}, 'id': '54394003', 'neo_reference_id': '54394003', 'name': '(2023 TX19)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54394003', 'absolute_magnitude_h': 25.51, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0210162379, 'estimated_diameter_max': 0.0469937366}, 'meters': {'estimated_diameter_min': 21.0162379322, 'estimated_diameter_max': 46.9937366478}, 'miles': {'estimated_diameter_min': 0.0130588808, 'estimated_diameter_max': 0.0292005451}, 'feet': {'estimated_diameter_min': 68.9509140576, 'estimated_diameter_max': 154.1789309435}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-10-20', 'close_approach_date_full': '2024-Oct-20 07:25', 'epoch_date_close_approach': 1729409100000, 'relative_velocity': {'kilometers_per_second': '23.1047165143', 'kilometers_per_hour': '83176.9794516355', 'miles_per_hour': '51682.9403709343'}, 'miss_distance': {'astronomical': '0.3023014999', 'lunar': '117.5952834611', 'kilometers': '45223660.482845213', 'miles': '28100679.5782134194'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}
# 54394003
# 0.0210162379
# 25.51
# 23.1047165143
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54454238?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}, 'id': '54454238', 'neo_reference_id': '54454238', 'name': '(2024 MB1)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54454238', 'absolute_magnitude_h': 27.23, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0095182033, 'estimated_diameter_max': 0.0212833496}, 'meters': {'estimated_diameter_min': 9.5182032982, 'estimated_diameter_max': 21.2833495984}, 'miles': {'estimated_diameter_min': 0.0059143355, 'estimated_diameter_max': 0.0132248562}, 'feet': {'estimated_diameter_min': 31.2277021088, 'estimated_diameter_max': 69.8272646965}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-10-20', 'close_approach_date_full': '2024-Oct-20 03:29', 'epoch_date_close_approach': 1729394940000, 'relative_velocity': {'kilometers_per_second': '3.8517001288', 'kilometers_per_hour': '13866.1204636198', 'miles_per_hour': '8615.8680180753'}, 'miss_distance': {'astronomical': '0.205885944', 'lunar': '80.089632216', 'kilometers': '30800098.68533928', 'miles': '19138293.868590864'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': True, 'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54454238?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}
# 54454238
# 0.0095182033
# 27.23
# 3.8517001288
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54468797?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}, 'id': '54468797', 'neo_reference_id': '54468797', 'name': '(2024 RB5)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54468797', 'absolute_magnitude_h': 22.38, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0888290416, 'estimated_diameter_max': 0.1986277755}, 'meters': {'estimated_diameter_min': 88.8290416389, 'estimated_diameter_max': 198.6277754808}, 'miles': {'estimated_diameter_min': 0.0551957904, 'estimated_diameter_max': 0.1234215395}, 'feet': {'estimated_diameter_min': 291.4338729707, 'estimated_diameter_max': 651.6659509085}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-10-20', 'close_approach_date_full': '2024-Oct-20 05:41', 'epoch_date_close_approach': 1729402860000, 'relative_velocity': {'kilometers_per_second': '5.3294067115', 'kilometers_per_hour': '19185.8641613708', 'miles_per_hour': '11921.3498729362'}, 'miss_distance': {'astronomical': '0.2004585638', 'lunar': '77.9783813182', 'kilometers': '29988174.167739106', 'miles': '18633787.3676314228'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}
# 54468797
# 0.0888290416
# 22.38
# 5.3294067115
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54481741?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}, 'id': '54481741', 'neo_reference_id': '54481741', 'name': '(2024 SH1)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54481741', 'absolute_magnitude_h': 26.84, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0113908197, 'estimated_diameter_max': 0.0254706471}, 'meters': {'estimated_diameter_min': 11.3908196722, 'estimated_diameter_max': 25.4706471064}, 'miles': {'estimated_diameter_min': 0.007077925, 'estimated_diameter_max': 0.0158267215}, 'feet': {'estimated_diameter_min': 37.3714568132, 'estimated_diameter_max': 83.5651178526}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-10-20', 'close_approach_date_full': '2024-Oct-20 18:15', 'epoch_date_close_approach': 1729448100000, 'relative_velocity': {'kilometers_per_second': '2.6746352379', 'kilometers_per_hour': '9628.6868565576', 'miles_per_hour': '5982.8915637316'}, 'miss_distance': {'astronomical': '0.0164049026', 'lunar': '6.3815071114', 'kilometers': '2454138.486517462', 'miles': '1524930.9435344956'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}
# 54481741
# 0.0113908197
# 26.84
# 2.6746352379
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54485961?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}, 'id': '54485961', 'neo_reference_id': '54485961', 'name': '(2024 SC8)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54485961', 'absolute_magnitude_h': 25.86, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0178877195, 'estimated_diameter_max': 0.0399981568}, 'meters': {'estimated_diameter_min': 17.887719524, 'estimated_diameter_max': 39.9981568182}, 'miles': {'estimated_diameter_min': 0.0111149102, 'estimated_diameter_max': 0.0248536947}, 'feet': {'estimated_diameter_min': 58.6867457232, 'estimated_diameter_max': 131.2275528154}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-10-20', 'close_approach_date_full': '2024-Oct-20 05:46', 'epoch_date_close_approach': 1729403160000, 'relative_velocity': {'kilometers_per_second': '3.6942966806', 'kilometers_per_hour': '13299.4680502881', 'miles_per_hour': '8263.7722449137'}, 'miss_distance': {'astronomical': '0.0629380342', 'lunar': '24.4828953038', 'kilometers': '9415395.858307154', 'miles': '5850455.6971165652'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}
# 54485961
# 0.0178877195
# 25.86
# 3.6942966806
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54494151?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}, 'id': '54494151', 'neo_reference_id': '54494151', 'name': '(2024 UE)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54494151', 'absolute_magnitude_h': 26.401, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0139429598, 'estimated_diameter_max': 0.031177406}, 'meters': {'estimated_diameter_min': 13.9429598444, 'estimated_diameter_max': 31.1774060197}, 'miles': {'estimated_diameter_min': 0.0086637509, 'estimated_diameter_max': 0.019372736}, 'feet': {'estimated_diameter_min': 45.744620376, 'estimated_diameter_max': 102.2880807657}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-10-20', 'close_approach_date_full': '2024-Oct-20 22:53', 'epoch_date_close_approach': 1729464780000, 'relative_velocity': {'kilometers_per_second': '21.9780840558', 'kilometers_per_hour': '79121.1026008534', 'miles_per_hour': '49162.7762244025'}, 'miss_distance': {'astronomical': '0.0062682632', 'lunar': '2.4383543848', 'kilometers': '937718.823319384', 'miles': '582671.4579761392'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}
# 54494151
# 0.0139429598
# 26.401
# 21.9780840558
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54494256?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}, 'id': '54494256', 'neo_reference_id': '54494256', 'name': '(2024 UN)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54494256', 'absolute_magnitude_h': 26.553, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.013000348, 'estimated_diameter_max': 0.0290696618}, 'meters': {'estimated_diameter_min': 13.0003479619, 'estimated_diameter_max': 29.0696617739}, 'miles': {'estimated_diameter_min': 0.0080780392, 'estimated_diameter_max': 0.0180630448}, 'feet': {'estimated_diameter_min': 42.6520616072, 'estimated_diameter_max': 95.3729091343}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-10-20', 'close_approach_date_full': '2024-Oct-20 14:58', 'epoch_date_close_approach': 1729436280000, 'relative_velocity': {'kilometers_per_second': '14.1013238982', 'kilometers_per_hour': '50764.7660333425', 'miles_per_hour': '31543.2514277733'}, 'miss_distance': {'astronomical': '0.0062938463', 'lunar': '2.4483062107', 'kilometers': '941546.000587381', 'miles': '585049.5556566178'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': True, 'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54494256?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}
# 54494256
# 0.013000348
# 26.553
# 14.1013238982

# %%
asteroid_api.json()[ 'near_earth_objects']['2024-10-20'][0]['close_approach_data'][0]['relative_velocity']['kilometers_per_second']
# Out:
# '41.1627077851'

# %%
asteroid_api.json()[ 'near_earth_objects']
# Out:
# {'2024-10-20': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2412977?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '2412977',
#    'neo_reference_id': '2412977',
#    'name': '412977 (1990 UO)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2412977',
#    'absolute_magnitude_h': 19.57,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3240074354,
#      'estimated_diameter_max': 0.7245026508},
#     'meters': {'estimated_diameter_min': 324.0074353942,
#      'estimated_diameter_max': 724.5026507569},
#     'miles': {'estimated_diameter_min': 0.2013288241,
#      'estimated_diameter_max': 0.4501849366},
#     'feet': {'estimated_diameter_min': 1063.0165543388,
#      'estimated_diameter_max': 2376.9772767092}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 10:19',
#      'epoch_date_close_approach': 1729419540000,
#      'relative_velocity': {'kilometers_per_second': '41.1627077851',
#       'kilometers_per_hour': '148185.7480262956',
#       'miles_per_hour': '92076.8610444501'},
#      'miss_distance': {'astronomical': '0.4671664393',
#       'lunar': '181.7277448877',
#       'kilometers': '69887104.254764291',
#       'miles': '43425832.9012815758'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2495615?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '2495615',
#    'neo_reference_id': '2495615',
#    'name': '495615 (2015 PQ291)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2495615',
#    'absolute_magnitude_h': 17.7,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.7665755735,
#      'estimated_diameter_max': 1.7141150923},
#     'meters': {'estimated_diameter_min': 766.5755735311,
#      'estimated_diameter_max': 1714.1150923063},
#     'miles': {'estimated_diameter_min': 0.4763278307,
#      'estimated_diameter_max': 1.065101409},
#     'feet': {'estimated_diameter_min': 2515.0118046636,
#      'estimated_diameter_max': 5623.7373594423}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 02:46',
#      'epoch_date_close_approach': 1729392360000,
#      'relative_velocity': {'kilometers_per_second': '22.8658455755',
#       'kilometers_per_hour': '82317.0440716297',
#       'miles_per_hour': '51148.6099677301'},
#      'miss_distance': {'astronomical': '0.3502323914',
#       'lunar': '136.2404002546',
#       'kilometers': '52394019.758446318',
#       'miles': '32556134.2298944684'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2526742?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '2526742',
#    'neo_reference_id': '2526742',
#    'name': '526742 (2006 WR127)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2526742',
#    'absolute_magnitude_h': 20.49,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2121069879,
#      'estimated_diameter_max': 0.4742856434},
#     'meters': {'estimated_diameter_min': 212.1069878758,
#      'estimated_diameter_max': 474.2856433931},
#     'miles': {'estimated_diameter_min': 0.1317971312,
#      'estimated_diameter_max': 0.2947073445},
#     'feet': {'estimated_diameter_min': 695.8890901025,
#      'estimated_diameter_max': 1556.0553102697}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 17:36',
#      'epoch_date_close_approach': 1729445760000,
#      'relative_velocity': {'kilometers_per_second': '14.8481835153',
#       'kilometers_per_hour': '53453.4606550249',
#       'miles_per_hour': '33213.9017053403'},
#      'miss_distance': {'astronomical': '0.2754597714',
#       'lunar': '107.1538510746',
#       'kilometers': '41208195.072126918',
#       'miles': '25605585.0710627484'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3694787?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '3694787',
#    'neo_reference_id': '3694787',
#    'name': '(2014 US115)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3694787',
#    'absolute_magnitude_h': 24.6,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0319561887,
#      'estimated_diameter_max': 0.0714562102},
#     'meters': {'estimated_diameter_min': 31.9561886721,
#      'estimated_diameter_max': 71.4562101727},
#     'miles': {'estimated_diameter_min': 0.0198566489,
#      'estimated_diameter_max': 0.0444008168},
#     'feet': {'estimated_diameter_min': 104.8431420431,
#      'estimated_diameter_max': 234.436392583}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 04:15',
#      'epoch_date_close_approach': 1729397700000,
#      'relative_velocity': {'kilometers_per_second': '19.1626339588',
#       'kilometers_per_hour': '68985.4822516714',
#       'miles_per_hour': '42864.8959024344'},
#      'miss_distance': {'astronomical': '0.3832701874',
#       'lunar': '149.0921028986',
#       'kilometers': '57336403.669540838',
#       'miles': '35627189.1855380444'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3719472?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '3719472',
#    'neo_reference_id': '3719472',
#    'name': '(2015 KG19)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3719472',
#    'absolute_magnitude_h': 23.39,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0557898221,
#      'estimated_diameter_max': 0.1247498347},
#     'meters': {'estimated_diameter_min': 55.7898221067,
#      'estimated_diameter_max': 124.7498346832},
#     'miles': {'estimated_diameter_min': 0.0346661776,
#      'estimated_diameter_max': 0.0775159295},
#     'feet': {'estimated_diameter_min': 183.0374799606,
#      'estimated_diameter_max': 409.2842476221}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 09:27',
#      'epoch_date_close_approach': 1729416420000,
#      'relative_velocity': {'kilometers_per_second': '7.6123070871',
#       'kilometers_per_hour': '27404.305513672',
#       'miles_per_hour': '17027.9697232036'},
#      'miss_distance': {'astronomical': '0.2265469633',
#       'lunar': '88.1267687237',
#       'kilometers': '33890943.164648171',
#       'miles': '21058855.5704039198'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3753370?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '3753370',
#    'neo_reference_id': '3753370',
#    'name': '(2016 JT33)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3753370',
#    'absolute_magnitude_h': 23.6,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0506471459,
#      'estimated_diameter_max': 0.1132504611},
#     'meters': {'estimated_diameter_min': 50.6471458835,
#      'estimated_diameter_max': 113.2504610618},
#     'miles': {'estimated_diameter_min': 0.0314706677,
#      'estimated_diameter_max': 0.0703705522},
#     'feet': {'estimated_diameter_min': 166.1651821003,
#      'estimated_diameter_max': 371.5566426699}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 09:28',
#      'epoch_date_close_approach': 1729416480000,
#      'relative_velocity': {'kilometers_per_second': '20.8083092387',
#       'kilometers_per_hour': '74909.9132592034',
#       'miles_per_hour': '46546.1069359756'},
#      'miss_distance': {'astronomical': '0.4216894681',
#       'lunar': '164.0372030909',
#       'kilometers': '63083846.229192947',
#       'miles': '39198484.3889467886'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3785780?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '3785780',
#    'neo_reference_id': '3785780',
#    'name': '(2017 TV4)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3785780',
#    'absolute_magnitude_h': 19.01,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.4193290755,
#      'estimated_diameter_max': 0.9376483177},
#     'meters': {'estimated_diameter_min': 419.3290754861,
#      'estimated_diameter_max': 937.648317729},
#     'miles': {'estimated_diameter_min': 0.260558927,
#      'estimated_diameter_max': 0.5826274728},
#     'feet': {'estimated_diameter_min': 1375.7516040178,
#      'estimated_diameter_max': 3076.2741067381}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 07:37',
#      'epoch_date_close_approach': 1729409820000,
#      'relative_velocity': {'kilometers_per_second': '24.4491247759',
#       'kilometers_per_hour': '88016.8491933235',
#       'miles_per_hour': '54690.2472112626'},
#      'miss_distance': {'astronomical': '0.3371198126',
#       'lunar': '131.1396071014',
#       'kilometers': '50432405.899759162',
#       'miles': '31337243.8988019556'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3841535?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '3841535',
#    'neo_reference_id': '3841535',
#    'name': '(2019 HS)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3841535',
#    'absolute_magnitude_h': 27.2,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0096506147,
#      'estimated_diameter_max': 0.0215794305},
#     'meters': {'estimated_diameter_min': 9.6506146958,
#      'estimated_diameter_max': 21.5794304844},
#     'miles': {'estimated_diameter_min': 0.0059966121,
#      'estimated_diameter_max': 0.0134088323},
#     'feet': {'estimated_diameter_min': 31.6621227185,
#      'estimated_diameter_max': 70.7986587106}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 14:53',
#      'epoch_date_close_approach': 1729435980000,
#      'relative_velocity': {'kilometers_per_second': '14.7005634795',
#       'kilometers_per_hour': '52922.0285262839',
#       'miles_per_hour': '32883.6904473457'},
#      'miss_distance': {'astronomical': '0.4021934881',
#       'lunar': '156.4532668709',
#       'kilometers': '60167289.147630347',
#       'miles': '37386219.8542869086'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54134398?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54134398',
#    'neo_reference_id': '54134398',
#    'name': '(2021 GJ)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54134398',
#    'absolute_magnitude_h': 25.84,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0180532326,
#      'estimated_diameter_max': 0.0403682552},
#     'meters': {'estimated_diameter_min': 18.053232555,
#      'estimated_diameter_max': 40.3682552065},
#     'miles': {'estimated_diameter_min': 0.0112177552,
#      'estimated_diameter_max': 0.0250836631},
#     'feet': {'estimated_diameter_min': 59.2297674956,
#      'estimated_diameter_max': 132.4417864117}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 08:27',
#      'epoch_date_close_approach': 1729412820000,
#      'relative_velocity': {'kilometers_per_second': '17.0227179004',
#       'kilometers_per_hour': '61281.7844413975',
#       'miles_per_hour': '38078.1176713784'},
#      'miss_distance': {'astronomical': '0.3227737944',
#       'lunar': '125.5590060216',
#       'kilometers': '48286272.134057928',
#       'miles': '30003698.2141302864'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54394003?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54394003',
#    'neo_reference_id': '54394003',
#    'name': '(2023 TX19)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54394003',
#    'absolute_magnitude_h': 25.51,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0210162379,
#      'estimated_diameter_max': 0.0469937366},
#     'meters': {'estimated_diameter_min': 21.0162379322,
#      'estimated_diameter_max': 46.9937366478},
#     'miles': {'estimated_diameter_min': 0.0130588808,
#      'estimated_diameter_max': 0.0292005451},
#     'feet': {'estimated_diameter_min': 68.9509140576,
#      'estimated_diameter_max': 154.1789309435}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 07:25',
#      'epoch_date_close_approach': 1729409100000,
#      'relative_velocity': {'kilometers_per_second': '23.1047165143',
#       'kilometers_per_hour': '83176.9794516355',
#       'miles_per_hour': '51682.9403709343'},
#      'miss_distance': {'astronomical': '0.3023014999',
#       'lunar': '117.5952834611',
#       'kilometers': '45223660.482845213',
#       'miles': '28100679.5782134194'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54454238?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54454238',
#    'neo_reference_id': '54454238',
#    'name': '(2024 MB1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54454238',
#    'absolute_magnitude_h': 27.23,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0095182033,
#      'estimated_diameter_max': 0.0212833496},
#     'meters': {'estimated_diameter_min': 9.5182032982,
#      'estimated_diameter_max': 21.2833495984},
#     'miles': {'estimated_diameter_min': 0.0059143355,
#      'estimated_diameter_max': 0.0132248562},
#     'feet': {'estimated_diameter_min': 31.2277021088,
#      'estimated_diameter_max': 69.8272646965}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 03:29',
#      'epoch_date_close_approach': 1729394940000,
#      'relative_velocity': {'kilometers_per_second': '3.8517001288',
#       'kilometers_per_hour': '13866.1204636198',
#       'miles_per_hour': '8615.8680180753'},
#      'miss_distance': {'astronomical': '0.205885944',
#       'lunar': '80.089632216',
#       'kilometers': '30800098.68533928',
#       'miles': '19138293.868590864'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': True,
#    'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54454238?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54468797?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54468797',
#    'neo_reference_id': '54468797',
#    'name': '(2024 RB5)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54468797',
#    'absolute_magnitude_h': 22.38,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0888290416,
#      'estimated_diameter_max': 0.1986277755},
#     'meters': {'estimated_diameter_min': 88.8290416389,
#      'estimated_diameter_max': 198.6277754808},
#     'miles': {'estimated_diameter_min': 0.0551957904,
#      'estimated_diameter_max': 0.1234215395},
#     'feet': {'estimated_diameter_min': 291.4338729707,
#      'estimated_diameter_max': 651.6659509085}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 05:41',
#      'epoch_date_close_approach': 1729402860000,
#      'relative_velocity': {'kilometers_per_second': '5.3294067115',
#       'kilometers_per_hour': '19185.8641613708',
#       'miles_per_hour': '11921.3498729362'},
#      'miss_distance': {'astronomical': '0.2004585638',
#       'lunar': '77.9783813182',
#       'kilometers': '29988174.167739106',
#       'miles': '18633787.3676314228'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54481741?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54481741',
#    'neo_reference_id': '54481741',
#    'name': '(2024 SH1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54481741',
#    'absolute_magnitude_h': 26.84,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0113908197,
#      'estimated_diameter_max': 0.0254706471},
#     'meters': {'estimated_diameter_min': 11.3908196722,
#      'estimated_diameter_max': 25.4706471064},
#     'miles': {'estimated_diameter_min': 0.007077925,
#      'estimated_diameter_max': 0.0158267215},
#     'feet': {'estimated_diameter_min': 37.3714568132,
#      'estimated_diameter_max': 83.5651178526}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 18:15',
#      'epoch_date_close_approach': 1729448100000,
#      'relative_velocity': {'kilometers_per_second': '2.6746352379',
#       'kilometers_per_hour': '9628.6868565576',
#       'miles_per_hour': '5982.8915637316'},
#      'miss_distance': {'astronomical': '0.0164049026',
#       'lunar': '6.3815071114',
#       'kilometers': '2454138.486517462',
#       'miles': '1524930.9435344956'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54485961?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54485961',
#    'neo_reference_id': '54485961',
#    'name': '(2024 SC8)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54485961',
#    'absolute_magnitude_h': 25.86,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0178877195,
#      'estimated_diameter_max': 0.0399981568},
#     'meters': {'estimated_diameter_min': 17.887719524,
#      'estimated_diameter_max': 39.9981568182},
#     'miles': {'estimated_diameter_min': 0.0111149102,
#      'estimated_diameter_max': 0.0248536947},
#     'feet': {'estimated_diameter_min': 58.6867457232,
#      'estimated_diameter_max': 131.2275528154}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 05:46',
#      'epoch_date_close_approach': 1729403160000,
#      'relative_velocity': {'kilometers_per_second': '3.6942966806',
#       'kilometers_per_hour': '13299.4680502881',
#       'miles_per_hour': '8263.7722449137'},
#      'miss_distance': {'astronomical': '0.0629380342',
#       'lunar': '24.4828953038',
#       'kilometers': '9415395.858307154',
#       'miles': '5850455.6971165652'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54494151?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54494151',
#    'neo_reference_id': '54494151',
#    'name': '(2024 UE)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54494151',
#    'absolute_magnitude_h': 26.401,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0139429598,
#      'estimated_diameter_max': 0.031177406},
#     'meters': {'estimated_diameter_min': 13.9429598444,
#      'estimated_diameter_max': 31.1774060197},
#     'miles': {'estimated_diameter_min': 0.0086637509,
#      'estimated_diameter_max': 0.019372736},
#     'feet': {'estimated_diameter_min': 45.744620376,
#      'estimated_diameter_max': 102.2880807657}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 22:53',
#      'epoch_date_close_approach': 1729464780000,
#      'relative_velocity': {'kilometers_per_second': '21.9780840558',
#       'kilometers_per_hour': '79121.1026008534',
#       'miles_per_hour': '49162.7762244025'},
#      'miss_distance': {'astronomical': '0.0062682632',
#       'lunar': '2.4383543848',
#       'kilometers': '937718.823319384',
#       'miles': '582671.4579761392'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54494256?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54494256',
#    'neo_reference_id': '54494256',
#    'name': '(2024 UN)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54494256',
#    'absolute_magnitude_h': 26.553,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.013000348,
#      'estimated_diameter_max': 0.0290696618},
#     'meters': {'estimated_diameter_min': 13.0003479619,
#      'estimated_diameter_max': 29.0696617739},
#     'miles': {'estimated_diameter_min': 0.0080780392,
#      'estimated_diameter_max': 0.0180630448},
#     'feet': {'estimated_diameter_min': 42.6520616072,
#      'estimated_diameter_max': 95.3729091343}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-20',
#      'close_approach_date_full': '2024-Oct-20 14:58',
#      'epoch_date_close_approach': 1729436280000,
#      'relative_velocity': {'kilometers_per_second': '14.1013238982',
#       'kilometers_per_hour': '50764.7660333425',
#       'miles_per_hour': '31543.2514277733'},
#      'miss_distance': {'astronomical': '0.0062938463',
#       'lunar': '2.4483062107',
#       'kilometers': '941546.000587381',
#       'miles': '585049.5556566178'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': True,
#    'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54494256?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}],
#  '2024-10-18': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2483547?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '2483547',
#    'neo_reference_id': '2483547',
#    'name': '483547 (2003 WM25)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2483547',
#    'absolute_magnitude_h': 17.65,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.7844314124,
#      'estimated_diameter_max': 1.7540419619},
#     'meters': {'estimated_diameter_min': 784.4314124479,
#      'estimated_diameter_max': 1754.0419619197},
#     'miles': {'estimated_diameter_min': 0.4874229312,
#      'estimated_diameter_max': 1.0899108079},
#     'feet': {'estimated_diameter_min': 2573.5939552157,
#      'estimated_diameter_max': 5754.7310303447}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 20:50',
#      'epoch_date_close_approach': 1729284600000,
#      'relative_velocity': {'kilometers_per_second': '9.3986936436',
#       'kilometers_per_hour': '33835.2971167893',
#       'miles_per_hour': '21023.9378112627'},
#      'miss_distance': {'astronomical': '0.2423446388',
#       'lunar': '94.2720644932',
#       'kilometers': '36254241.770399356',
#       'miles': '22527341.2294328728'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3137843?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '3137843',
#    'neo_reference_id': '3137843',
#    'name': '(2002 RD27)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3137843',
#    'absolute_magnitude_h': 18.14,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.6259720997,
#      'estimated_diameter_max': 1.3997161669},
#     'meters': {'estimated_diameter_min': 625.9720996596,
#      'estimated_diameter_max': 1399.716166857},
#     'miles': {'estimated_diameter_min': 0.3889609095,
#      'estimated_diameter_max': 0.8697430343},
#     'feet': {'estimated_diameter_min': 2053.7143034471,
#      'estimated_diameter_max': 4592.2447888713}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 05:54',
#      'epoch_date_close_approach': 1729230840000,
#      'relative_velocity': {'kilometers_per_second': '12.6975398503',
#       'kilometers_per_hour': '45711.1434609508',
#       'miles_per_hour': '28403.1268910558'},
#      'miss_distance': {'astronomical': '0.466144442',
#       'lunar': '181.330187938',
#       'kilometers': '69734215.63553854',
#       'miles': '43330832.318530252'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3145497?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '3145497',
#    'neo_reference_id': '3145497',
#    'name': '(2002 YO2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3145497',
#    'absolute_magnitude_h': 22.7,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0766575574,
#      'estimated_diameter_max': 0.1714115092},
#     'meters': {'estimated_diameter_min': 76.6575573531,
#      'estimated_diameter_max': 171.4115092306},
#     'miles': {'estimated_diameter_min': 0.0476327831,
#      'estimated_diameter_max': 0.1065101409},
#     'feet': {'estimated_diameter_min': 251.5011804664,
#      'estimated_diameter_max': 562.3737359442}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 18:09',
#      'epoch_date_close_approach': 1729274940000,
#      'relative_velocity': {'kilometers_per_second': '4.4510357534',
#       'kilometers_per_hour': '16023.7287122918',
#       'miles_per_hour': '9956.5218768126'},
#      'miss_distance': {'astronomical': '0.4614589274',
#       'lunar': '179.5075227586',
#       'kilometers': '69033272.631524638',
#       'miles': '42895286.5323624844'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3529626?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '3529626',
#    'neo_reference_id': '3529626',
#    'name': '(2010 MA)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3529626',
#    'absolute_magnitude_h': 25.7,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0192555078,
#      'estimated_diameter_max': 0.0430566244},
#     'meters': {'estimated_diameter_min': 19.2555078188,
#      'estimated_diameter_max': 43.0566244241},
#     'miles': {'estimated_diameter_min': 0.0119648141,
#      'estimated_diameter_max': 0.0267541378},
#     'feet': {'estimated_diameter_min': 63.1742402722,
#      'estimated_diameter_max': 141.2618956756}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 21:59',
#      'epoch_date_close_approach': 1729288740000,
#      'relative_velocity': {'kilometers_per_second': '8.5877838298',
#       'kilometers_per_hour': '30916.0217873705',
#       'miles_per_hour': '19210.0136489359'},
#      'miss_distance': {'astronomical': '0.3083990408',
#       'lunar': '119.9672268712',
#       'kilometers': '46135839.613723096',
#       'miles': '28667481.4071908848'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3761647?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '3761647',
#    'neo_reference_id': '3761647',
#    'name': '(2016 UY35)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3761647',
#    'absolute_magnitude_h': 24.7,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0305179233,
#      'estimated_diameter_max': 0.0682401509},
#     'meters': {'estimated_diameter_min': 30.5179232594,
#      'estimated_diameter_max': 68.2401509401},
#     'miles': {'estimated_diameter_min': 0.0189629525,
#      'estimated_diameter_max': 0.0424024508},
#     'feet': {'estimated_diameter_min': 100.1244233463,
#      'estimated_diameter_max': 223.8850168104}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 19:25',
#      'epoch_date_close_approach': 1729279500000,
#      'relative_velocity': {'kilometers_per_second': '18.0779724934',
#       'kilometers_per_hour': '65080.70097628',
#       'miles_per_hour': '40438.6166705113'},
#      'miss_distance': {'astronomical': '0.388914732',
#       'lunar': '151.287830748',
#       'kilometers': '58180815.51882084',
#       'miles': '36151882.378333992'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54016334?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54016334',
#    'neo_reference_id': '54016334',
#    'name': '(2020 FV3)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54016334',
#    'absolute_magnitude_h': 27.7,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0076657557,
#      'estimated_diameter_max': 0.0171411509},
#     'meters': {'estimated_diameter_min': 7.6657557353,
#      'estimated_diameter_max': 17.1411509231},
#     'miles': {'estimated_diameter_min': 0.0047632783,
#      'estimated_diameter_max': 0.0106510141},
#     'feet': {'estimated_diameter_min': 25.1501180466,
#      'estimated_diameter_max': 56.2373735944}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 02:36',
#      'epoch_date_close_approach': 1729218960000,
#      'relative_velocity': {'kilometers_per_second': '17.4745586299',
#       'kilometers_per_hour': '62908.4110676954',
#       'miles_per_hour': '39088.8401992578'},
#      'miss_distance': {'astronomical': '0.3951498466',
#       'lunar': '153.7132903274',
#       'kilometers': '59113575.382186742',
#       'miles': '36731472.4814793596'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54051583?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54051583',
#    'neo_reference_id': '54051583',
#    'name': '(2020 QP6)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54051583',
#    'absolute_magnitude_h': 20.73,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1899131235,
#      'estimated_diameter_max': 0.4246586539},
#     'meters': {'estimated_diameter_min': 189.9131234709,
#      'estimated_diameter_max': 424.6586539002},
#     'miles': {'estimated_diameter_min': 0.1180065074,
#      'estimated_diameter_max': 0.2638705724},
#     'feet': {'estimated_diameter_min': 623.0745720082,
#      'estimated_diameter_max': 1393.2370980619}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 12:02',
#      'epoch_date_close_approach': 1729252920000,
#      'relative_velocity': {'kilometers_per_second': '9.1153088486',
#       'kilometers_per_hour': '32815.1118550544',
#       'miles_per_hour': '20390.034363492'},
#      'miss_distance': {'astronomical': '0.2111664912',
#       'lunar': '82.1437650768',
#       'kilometers': '31590057.298893744',
#       'miles': '19629151.3896879072'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54055117?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54055117',
#    'neo_reference_id': '54055117',
#    'name': '(2020 TN3)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54055117',
#    'absolute_magnitude_h': 24.2,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0384197891,
#      'estimated_diameter_max': 0.0859092601},
#     'meters': {'estimated_diameter_min': 38.4197891064,
#      'estimated_diameter_max': 85.9092601232},
#     'miles': {'estimated_diameter_min': 0.0238729428,
#      'estimated_diameter_max': 0.0533815229},
#     'feet': {'estimated_diameter_min': 126.0491808919,
#      'estimated_diameter_max': 281.8545369825}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 23:34',
#      'epoch_date_close_approach': 1729294440000,
#      'relative_velocity': {'kilometers_per_second': '18.9916021102',
#       'kilometers_per_hour': '68369.7675966044',
#       'miles_per_hour': '42482.3147602346'},
#      'miss_distance': {'astronomical': '0.1866409181',
#       'lunar': '72.6033171409',
#       'kilometers': '27921083.802604447',
#       'miles': '17349356.9745654886'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54316690?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54316690',
#    'neo_reference_id': '54316690',
#    'name': '(2022 UO)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54316690',
#    'absolute_magnitude_h': 26.53,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0131387781,
#      'estimated_diameter_max': 0.0293792009},
#     'meters': {'estimated_diameter_min': 13.1387780601,
#      'estimated_diameter_max': 29.3792008837},
#     'miles': {'estimated_diameter_min': 0.0081640557,
#      'estimated_diameter_max': 0.0182553834},
#     'feet': {'estimated_diameter_min': 43.1062286107,
#      'estimated_diameter_max': 96.3884574272}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 21:59',
#      'epoch_date_close_approach': 1729288740000,
#      'relative_velocity': {'kilometers_per_second': '16.29423043',
#       'kilometers_per_hour': '58659.2295480436',
#       'miles_per_hour': '36448.5640488941'},
#      'miss_distance': {'astronomical': '0.3065798839',
#       'lunar': '119.2595748371',
#       'kilometers': '45863697.616287293',
#       'miles': '28498380.2113109234'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54320707?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54320707',
#    'neo_reference_id': '54320707',
#    'name': '(2022 UO10)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54320707',
#    'absolute_magnitude_h': 26.76,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0118182991,
#      'estimated_diameter_max': 0.0264265201},
#     'meters': {'estimated_diameter_min': 11.8182990893,
#      'estimated_diameter_max': 26.4265201422},
#     'miles': {'estimated_diameter_min': 0.0073435483,
#      'estimated_diameter_max': 0.0164206732},
#     'feet': {'estimated_diameter_min': 38.7739483842,
#      'estimated_diameter_max': 86.7011843432}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 21:56',
#      'epoch_date_close_approach': 1729288560000,
#      'relative_velocity': {'kilometers_per_second': '10.3025532627',
#       'kilometers_per_hour': '37089.191745598',
#       'miles_per_hour': '23045.7813932578'},
#      'miss_distance': {'astronomical': '0.0522513469',
#       'lunar': '20.3257739441',
#       'kilometers': '7816690.200871103',
#       'miles': '4857066.0656751014'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54347994?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54347994',
#    'neo_reference_id': '54347994',
#    'name': '(2023 EN2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54347994',
#    'absolute_magnitude_h': 23.12,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0631764148,
#      'estimated_diameter_max': 0.1412667581},
#     'meters': {'estimated_diameter_min': 63.1764148185,
#      'estimated_diameter_max': 141.2667581089},
#     'miles': {'estimated_diameter_min': 0.0392559921,
#      'estimated_diameter_max': 0.0877790668},
#     'feet': {'estimated_diameter_min': 207.2717087931,
#      'estimated_diameter_max': 463.4736306739}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 13:57',
#      'epoch_date_close_approach': 1729259820000,
#      'relative_velocity': {'kilometers_per_second': '23.4907483903',
#       'kilometers_per_hour': '84566.6942049158',
#       'miles_per_hour': '52546.4550741601'},
#      'miss_distance': {'astronomical': '0.4623701184',
#       'lunar': '179.8619760576',
#       'kilometers': '69169584.864287808',
#       'miles': '42979987.0261874304'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54445848?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54445848',
#    'neo_reference_id': '54445848',
#    'name': '(2024 LE1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54445848',
#    'absolute_magnitude_h': 26.31,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0145396843,
#      'estimated_diameter_max': 0.0325117225},
#     'meters': {'estimated_diameter_min': 14.5396842937,
#      'estimated_diameter_max': 32.5117224521},
#     'miles': {'estimated_diameter_min': 0.0090345382,
#      'estimated_diameter_max': 0.0202018415},
#     'feet': {'estimated_diameter_min': 47.7023778182,
#      'estimated_diameter_max': 106.6657594899}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 10:04',
#      'epoch_date_close_approach': 1729245840000,
#      'relative_velocity': {'kilometers_per_second': '7.7794602138',
#       'kilometers_per_hour': '28006.0567697649',
#       'miles_per_hour': '17401.874552302'},
#      'miss_distance': {'astronomical': '0.3314508579',
#       'lunar': '128.9343837231',
#       'kilometers': '49584342.351512673',
#       'miles': '30810281.6454859674'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54482434?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54482434',
#    'neo_reference_id': '54482434',
#    'name': '(2024 RV50)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54482434',
#    'absolute_magnitude_h': 20.97,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1700415193,
#      'estimated_diameter_max': 0.3802243961},
#     'meters': {'estimated_diameter_min': 170.0415192713,
#      'estimated_diameter_max': 380.2243960879},
#     'miles': {'estimated_diameter_min': 0.1056588689,
#      'estimated_diameter_max': 0.2362604132},
#     'feet': {'estimated_diameter_min': 557.879018086,
#      'estimated_diameter_max': 1247.4554076612}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 17:02',
#      'epoch_date_close_approach': 1729270920000,
#      'relative_velocity': {'kilometers_per_second': '15.5740330005',
#       'kilometers_per_hour': '56066.5188018022',
#       'miles_per_hour': '34837.5544188198'},
#      'miss_distance': {'astronomical': '0.0495817849',
#       'lunar': '19.2873143261',
#       'kilometers': '7417329.411838163',
#       'miles': '4608914.7782981294'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54487286?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54487286',
#    'neo_reference_id': '54487286',
#    'name': '(2024 TX2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54487286',
#    'absolute_magnitude_h': 23.82,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0457672667,
#      'estimated_diameter_max': 0.1023387195},
#     'meters': {'estimated_diameter_min': 45.7672667231,
#      'estimated_diameter_max': 102.3387195373},
#     'miles': {'estimated_diameter_min': 0.0284384523,
#      'estimated_diameter_max': 0.0635903125},
#     'feet': {'estimated_diameter_min': 150.1550793559,
#      'estimated_diameter_max': 335.7569646067}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 03:16',
#      'epoch_date_close_approach': 1729221360000,
#      'relative_velocity': {'kilometers_per_second': '13.529856677',
#       'kilometers_per_hour': '48707.4840371428',
#       'miles_per_hour': '30264.9364007457'},
#      'miss_distance': {'astronomical': '0.0762628543',
#       'lunar': '29.6662503227',
#       'kilometers': '11408760.563400341',
#       'miles': '7089075.0893170658'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54487954?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54487954',
#    'neo_reference_id': '54487954',
#    'name': '(2024 TN4)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54487954',
#    'absolute_magnitude_h': 22.57,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0813869881,
#      'estimated_diameter_max': 0.1819868378},
#     'meters': {'estimated_diameter_min': 81.3869880675,
#      'estimated_diameter_max': 181.9868378029},
#     'miles': {'estimated_diameter_min': 0.0505715142,
#      'estimated_diameter_max': 0.1130813434},
#     'feet': {'estimated_diameter_min': 267.0176859314,
#      'estimated_diameter_max': 597.0696969372}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 15:04',
#      'epoch_date_close_approach': 1729263840000,
#      'relative_velocity': {'kilometers_per_second': '11.9292301322',
#       'kilometers_per_hour': '42945.2284758631',
#       'miles_per_hour': '26684.4948826828'},
#      'miss_distance': {'astronomical': '0.2847790422',
#       'lunar': '110.7790474158',
#       'kilometers': '42602338.133760114',
#       'miles': '26471865.3996090132'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54489676?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54489676',
#    'neo_reference_id': '54489676',
#    'name': '(2024 TX8)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54489676',
#    'absolute_magnitude_h': 24.23,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0378926498,
#      'estimated_diameter_max': 0.0847305409},
#     'meters': {'estimated_diameter_min': 37.8926498379,
#      'estimated_diameter_max': 84.7305408852},
#     'miles': {'estimated_diameter_min': 0.0235453937,
#      'estimated_diameter_max': 0.0526491009},
#     'feet': {'estimated_diameter_min': 124.3197212943,
#      'estimated_diameter_max': 277.9873477579}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 18:01',
#      'epoch_date_close_approach': 1729274460000,
#      'relative_velocity': {'kilometers_per_second': '12.545700091',
#       'kilometers_per_hour': '45164.5203276457',
#       'miles_per_hour': '28063.4765335863'},
#      'miss_distance': {'astronomical': '0.0946360851',
#       'lunar': '36.8134371039',
#       'kilometers': '14157356.756098737',
#       'miles': '8796973.5671550906'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54490132?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54490132',
#    'neo_reference_id': '54490132',
#    'name': '(2024 TT9)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54490132',
#    'absolute_magnitude_h': 24.2,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0384197891,
#      'estimated_diameter_max': 0.0859092601},
#     'meters': {'estimated_diameter_min': 38.4197891064,
#      'estimated_diameter_max': 85.9092601232},
#     'miles': {'estimated_diameter_min': 0.0238729428,
#      'estimated_diameter_max': 0.0533815229},
#     'feet': {'estimated_diameter_min': 126.0491808919,
#      'estimated_diameter_max': 281.8545369825}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 07:04',
#      'epoch_date_close_approach': 1729235040000,
#      'relative_velocity': {'kilometers_per_second': '14.6824105786',
#       'kilometers_per_hour': '52856.6780829204',
#       'miles_per_hour': '32843.0842232457'},
#      'miss_distance': {'astronomical': '0.0649841378',
#       'lunar': '25.2788296042',
#       'kilometers': '9721488.598666486',
#       'miles': '6040652.9064140668'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54494098?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54494098',
#    'neo_reference_id': '54494098',
#    'name': '(2024 TB22)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54494098',
#    'absolute_magnitude_h': 19.339,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3603752665,
#      'estimated_diameter_max': 0.8058235934},
#     'meters': {'estimated_diameter_min': 360.3752665386,
#      'estimated_diameter_max': 805.82359339},
#     'miles': {'estimated_diameter_min': 0.2239267397,
#      'estimated_diameter_max': 0.500715412},
#     'feet': {'estimated_diameter_min': 1182.3335894706,
#      'estimated_diameter_max': 2643.7782781376}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 01:51',
#      'epoch_date_close_approach': 1729216260000,
#      'relative_velocity': {'kilometers_per_second': '21.9619650835',
#       'kilometers_per_hour': '79063.0743007336',
#       'miles_per_hour': '49126.7196953641'},
#      'miss_distance': {'astronomical': '0.0762762142',
#       'lunar': '29.6714473238',
#       'kilometers': '11410759.175983754',
#       'miles': '7090316.9695896452'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54494481?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54494481',
#    'neo_reference_id': '54494481',
#    'name': '(2024 UB1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54494481',
#    'absolute_magnitude_h': 28.437,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0054595265,
#      'estimated_diameter_max': 0.0122078723},
#     'meters': {'estimated_diameter_min': 5.459526478,
#      'estimated_diameter_max': 12.2078723298},
#     'miles': {'estimated_diameter_min': 0.0033923914,
#      'estimated_diameter_max': 0.0075856178},
#     'feet': {'estimated_diameter_min': 17.9118328502,
#      'estimated_diameter_max': 40.0520758546}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 05:14',
#      'epoch_date_close_approach': 1729228440000,
#      'relative_velocity': {'kilometers_per_second': '8.0060966917',
#       'kilometers_per_hour': '28821.9480901613',
#       'miles_per_hour': '17908.8376896894'},
#      'miss_distance': {'astronomical': '0.0024898845',
#       'lunar': '0.9685650705',
#       'kilometers': '372481.417746015',
#       'miles': '231449.220544407'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': True,
# ...
#     'meters': {'estimated_diameter_min': 37.8926498379,
#      'estimated_diameter_max': 84.7305408852},
#     'miles': {'estimated_diameter_min': 0.0235453937,
#      'estimated_diameter_max': 0.0526491009},
#     'feet': {'estimated_diameter_min': 124.3197212943,
#      'estimated_diameter_max': 277.9873477579}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 07:17',
#      'epoch_date_close_approach': 1729581420000,
#      'relative_velocity': {'kilometers_per_second': '9.6750353984',
#       'kilometers_per_hour': '34830.1274343933',
#       'miles_per_hour': '21642.0866827762'},
#      'miss_distance': {'astronomical': '0.095304915',
#       'lunar': '37.073611935',
#       'kilometers': '14257412.28453105',
#       'miles': '8859145.18958649'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54248639?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54248639',
#    'neo_reference_id': '54248639',
#    'name': '(2022 DA4)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54248639',
#    'absolute_magnitude_h': 23.62,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0501828101,
#      'estimated_diameter_max': 0.1122121746},
#     'meters': {'estimated_diameter_min': 50.182810059,
#      'estimated_diameter_max': 112.2121745938},
#     'miles': {'estimated_diameter_min': 0.0311821429,
#      'estimated_diameter_max': 0.0697253911},
#     'feet': {'estimated_diameter_min': 164.6417705539,
#      'estimated_diameter_max': 368.1501908944}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 01:54',
#      'epoch_date_close_approach': 1729562040000,
#      'relative_velocity': {'kilometers_per_second': '20.0188562619',
#       'kilometers_per_hour': '72067.8825430117',
#       'miles_per_hour': '44780.1795723508'},
#      'miss_distance': {'astronomical': '0.4367091909',
#       'lunar': '169.8798752601',
#       'kilometers': '65330764.768063383',
#       'miles': '40594654.8277173654'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54279762?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54279762',
#    'neo_reference_id': '54279762',
#    'name': '(2022 KA)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54279762',
#    'absolute_magnitude_h': 25.15,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0248058993,
#      'estimated_diameter_max': 0.0554676771},
#     'meters': {'estimated_diameter_min': 24.8058993152,
#      'estimated_diameter_max': 55.4676771118},
#     'miles': {'estimated_diameter_min': 0.0154136665,
#      'estimated_diameter_max': 0.034466006},
#     'feet': {'estimated_diameter_min': 81.3841867092,
#      'estimated_diameter_max': 181.9805737754}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 04:15',
#      'epoch_date_close_approach': 1729570500000,
#      'relative_velocity': {'kilometers_per_second': '7.576107776',
#       'kilometers_per_hour': '27273.9879937278',
#       'miles_per_hour': '16946.9954842138'},
#      'miss_distance': {'astronomical': '0.2265747261',
#       'lunar': '88.1375684529',
#       'kilometers': '33895096.420393407',
#       'miles': '21061436.2838547366'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54340101?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54340101',
#    'neo_reference_id': '54340101',
#    'name': '(2023 BA4)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54340101',
#    'absolute_magnitude_h': 24.78,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0294140602,
#      'estimated_diameter_max': 0.0657718381},
#     'meters': {'estimated_diameter_min': 29.4140601781,
#      'estimated_diameter_max': 65.7718380526},
#     'miles': {'estimated_diameter_min': 0.018277044,
#      'estimated_diameter_max': 0.0408687128},
#     'feet': {'estimated_diameter_min': 96.5028251948,
#      'estimated_diameter_max': 215.7868771564}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 05:25',
#      'epoch_date_close_approach': 1729574700000,
#      'relative_velocity': {'kilometers_per_second': '11.2870116407',
#       'kilometers_per_hour': '40633.2419064232',
#       'miles_per_hour': '25247.9163390217'},
#      'miss_distance': {'astronomical': '0.4276145266',
#       'lunar': '166.3420508474',
#       'kilometers': '63970222.360418342',
#       'miles': '39749252.9774114396'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54439432?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54439432',
#    'neo_reference_id': '54439432',
#    'name': '(2024 JC1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54439432',
#    'absolute_magnitude_h': 25.1,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0253837029,
#      'estimated_diameter_max': 0.0567596853},
#     'meters': {'estimated_diameter_min': 25.3837029364,
#      'estimated_diameter_max': 56.7596852866},
#     'miles': {'estimated_diameter_min': 0.0157726969,
#      'estimated_diameter_max': 0.0352688224},
#     'feet': {'estimated_diameter_min': 83.279867942,
#      'estimated_diameter_max': 186.2194458756}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 17:18',
#      'epoch_date_close_approach': 1729617480000,
#      'relative_velocity': {'kilometers_per_second': '4.2551641015',
#       'kilometers_per_hour': '15318.5907654466',
#       'miles_per_hour': '9518.3765786743'},
#      'miss_distance': {'astronomical': '0.2200279263',
#       'lunar': '85.5908633307',
#       'kilometers': '32915709.114996981',
#       'miles': '20452873.2317250978'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54483151?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54483151',
#    'neo_reference_id': '54483151',
#    'name': '(2024 SO3)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54483151',
#    'absolute_magnitude_h': 21.99,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1063053145,
#      'estimated_diameter_max': 0.2377059096},
#     'meters': {'estimated_diameter_min': 106.3053144865,
#      'estimated_diameter_max': 237.7059095613},
#     'miles': {'estimated_diameter_min': 0.0660550396,
#      'estimated_diameter_max': 0.1477035587},
#     'feet': {'estimated_diameter_min': 348.7707279799,
#      'estimated_diameter_max': 779.8750563251}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 12:36',
#      'epoch_date_close_approach': 1729600560000,
#      'relative_velocity': {'kilometers_per_second': '10.3180818117',
#       'kilometers_per_hour': '37145.0945220577',
#       'miles_per_hour': '23080.517204553'},
#      'miss_distance': {'astronomical': '0.2804482707',
#       'lunar': '109.0943773023',
#       'kilometers': '41954463.941903409',
#       'miles': '26069295.0442246842'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54483861?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54483861',
#    'neo_reference_id': '54483861',
#    'name': '(2024 SE4)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54483861',
#    'absolute_magnitude_h': 27.72,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0075954757,
#      'estimated_diameter_max': 0.0169839999},
#     'meters': {'estimated_diameter_min': 7.5954756643,
#      'estimated_diameter_max': 16.9839999068},
#     'miles': {'estimated_diameter_min': 0.0047196083,
#      'estimated_diameter_max': 0.010553365},
#     'feet': {'estimated_diameter_min': 24.9195403784,
#      'estimated_diameter_max': 55.7217862542}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 17:16',
#      'epoch_date_close_approach': 1729617360000,
#      'relative_velocity': {'kilometers_per_second': '2.2164283877',
#       'kilometers_per_hour': '7979.1421958716',
#       'miles_per_hour': '4957.9286605403'},
#      'miss_distance': {'astronomical': '0.0177065839',
#       'lunar': '6.8878611371',
#       'kilometers': '2648867.236416293',
#       'miles': '1645929.7779311234'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54485966?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54485966',
#    'neo_reference_id': '54485966',
#    'name': '(2024 SM8)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54485966',
#    'absolute_magnitude_h': 24.78,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0294140602,
#      'estimated_diameter_max': 0.0657718381},
#     'meters': {'estimated_diameter_min': 29.4140601781,
#      'estimated_diameter_max': 65.7718380526},
#     'miles': {'estimated_diameter_min': 0.018277044,
#      'estimated_diameter_max': 0.0408687128},
#     'feet': {'estimated_diameter_min': 96.5028251948,
#      'estimated_diameter_max': 215.7868771564}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 16:40',
#      'epoch_date_close_approach': 1729615200000,
#      'relative_velocity': {'kilometers_per_second': '5.1020416329',
#       'kilometers_per_hour': '18367.3498785665',
#       'miles_per_hour': '11412.7569287126'},
#      'miss_distance': {'astronomical': '0.1262356504',
#       'lunar': '49.1056680056',
#       'kilometers': '18884584.417904648',
#       'miles': '11734336.6288662224'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54487941?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54487941',
#    'neo_reference_id': '54487941',
#    'name': '(2024 TQ3)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54487941',
#    'absolute_magnitude_h': 23.37,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.056306039,
#      'estimated_diameter_max': 0.1259041307},
#     'meters': {'estimated_diameter_min': 56.3060389749,
#      'estimated_diameter_max': 125.9041306916},
#     'miles': {'estimated_diameter_min': 0.0349869397,
#      'estimated_diameter_max': 0.0782331756},
#     'feet': {'estimated_diameter_min': 184.7311049104,
#      'estimated_diameter_max': 413.0713081384}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 00:34',
#      'epoch_date_close_approach': 1729557240000,
#      'relative_velocity': {'kilometers_per_second': '8.4878997567',
#       'kilometers_per_hour': '30556.439124071',
#       'miles_per_hour': '18986.5829657318'},
#      'miss_distance': {'astronomical': '0.1611183345',
#       'lunar': '62.6750321205',
#       'kilometers': '24102959.659147515',
#       'miles': '14976884.644825107'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54494254?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54494254',
#    'neo_reference_id': '54494254',
#    'name': '(2024 UL)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54494254',
#    'absolute_magnitude_h': 23.293,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0583384622,
#      'estimated_diameter_max': 0.1304487671},
#     'meters': {'estimated_diameter_min': 58.3384621542,
#      'estimated_diameter_max': 130.4487670795},
#     'miles': {'estimated_diameter_min': 0.0362498286,
#      'estimated_diameter_max': 0.0810570808},
#     'feet': {'estimated_diameter_min': 191.3991601739,
#      'estimated_diameter_max': 427.9815329851}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 07:10',
#      'epoch_date_close_approach': 1729581000000,
#      'relative_velocity': {'kilometers_per_second': '12.5206891473',
#       'kilometers_per_hour': '45074.4809303927',
#       'miles_per_hour': '28007.5295536654'},
#      'miss_distance': {'astronomical': '0.0853073317',
#       'lunar': '33.1845520313',
#       'kilometers': '12761795.117703479',
#       'miles': '7929811.7758828502'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54494470?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54494470',
#    'neo_reference_id': '54494470',
#    'name': '(2024 UR)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54494470',
#    'absolute_magnitude_h': 24.354,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0357894461,
#      'estimated_diameter_max': 0.0800276343},
#     'meters': {'estimated_diameter_min': 35.7894460653,
#      'estimated_diameter_max': 80.0276342792},
#     'miles': {'estimated_diameter_min': 0.0222385239,
#      'estimated_diameter_max': 0.0497268511},
#     'feet': {'estimated_diameter_min': 117.419446229,
#      'estimated_diameter_max': 262.5578636485}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 03:18',
#      'epoch_date_close_approach': 1729567080000,
#      'relative_velocity': {'kilometers_per_second': '16.3145387939',
#       'kilometers_per_hour': '58732.3396579061',
#       'miles_per_hour': '36493.9918279917'},
#      'miss_distance': {'astronomical': '0.014096281',
#       'lunar': '5.483453309',
#       'kilometers': '2108773.61252147',
#       'miles': '1310331.161957486'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54494471?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'},
#    'id': '54494471',
#    'neo_reference_id': '54494471',
#    'name': '(2024 US)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54494471',
#    'absolute_magnitude_h': 27.969,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.006772593,
#      'estimated_diameter_max': 0.0151439783},
#     'meters': {'estimated_diameter_min': 6.7725929877,
#      'estimated_diameter_max': 15.1439783043},
#     'miles': {'estimated_diameter_min': 0.0042082929,
#      'estimated_diameter_max': 0.0094100289},
#     'feet': {'estimated_diameter_min': 22.2197939776,
#      'estimated_diameter_max': 49.68496978}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-22',
#      'close_approach_date_full': '2024-Oct-22 01:08',
#      'epoch_date_close_approach': 1729559280000,
#      'relative_velocity': {'kilometers_per_second': '7.8250602009',
#       'kilometers_per_hour': '28170.2167233555',
#       'miles_per_hour': '17503.8771634649'},
#      'miss_distance': {'astronomical': '0.0024224001',
#       'lunar': '0.9423136389',
#       'kilometers': '362385.895247787',
#       'miles': '225176.1537499806'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': True,
#    'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54494471?api_key=4vDWEVIkDM3sLyklrCXpC1HrWdnOMHyjRFXcOcrh'}]}
